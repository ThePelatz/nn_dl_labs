# %% [markdown]
# # NEURAL NETWORKS AND DEEP LEARNING
#
# ---
# A.A. 2024/25 (6 CFU) - Prof. Michele Rossi, Prof. Jacopo Pegoraro, Dr. Gianmaria Ventura, Dr. Pietro Talli
# ---
#
#
# ## Lab. 02 - Least Squares with NumPy and PyTorch

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %% [markdown]
# # Part 1: Least Squares with NumPy

# %% [markdown]
# ## Define the true model and generate some noisy samples

# %% [markdown]
# Let's define a simple quadratic model
#
# $$
# y = a + b * x + c * x^2 + \text{noise}\\
# Y=X \beta + \text{noise}\\
# X=[1, x, x^2], \quad
# \beta =
# \begin{bmatrix}
#   a\\
#   b\\
#   c
# \end{bmatrix} =
# \begin{bmatrix}
#   -1.45\\
#   1.12\\
#   2.3
# \end{bmatrix}
# $$

# %%
def poly_model(x, beta, noise_std=0):
    """
    INPUT
        x: x vector
        beta: polynomial parameters
        noise_std: enable noisy sampling (gaussian noise, zero mean, noise_std std)
    """
    pol_order = len(beta)
    x_matrix = np.array([x**i for i in range(pol_order)]).transpose()
    print(x_matrix)
    y = np.matmul(x_matrix, beta)
    noise = np.random.randn(len(y)) * noise_std
    return y + noise

# %%
# TEST
beta = [-1.45, 1.12, 2.3]
x = np.array([1, 2, 3])
expected_y = np.array([1.97, 9.99, 22.61])
if np.array_equal(poly_model(x, beta, noise_std=0), expected_y):
  print('OK!')
else:
  print('Something is wrong')
# Out:
# [[1 1 1]
#  [1 2 4]
#  [1 3 9]]
# OK!

# %% [markdown]
# Generate 10 training points and 10 test points. Add a gaussian noise with zero mean and 0.2 std (set a random seed for reproducible results).

# %%
### True parameter values
beta_true = [-1.45, 1.12, 2.3]

### Set random seed
np.random.seed(3)

### Generate 10 train points
num_train_points = 10
x_train = np.random.rand(num_train_points)
y_train = poly_model(x_train, beta_true, noise_std=0.2)

### Generate 10 test points
num_test_points = 10
x_test = np.random.rand(num_test_points)
y_test = poly_model(x_test, beta_true, noise_std=0.2)

### Plot-1, 2
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Train data points')
plt.plot(x_test, y_test, color='g', ls='', marker='.', label='Test data points')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [[1.         0.5507979  0.30337833]
#  [1.         0.70814782 0.50147334]
#  [1.         0.29090474 0.08462557]
#  [1.         0.51082761 0.26094484]
#  [1.         0.89294695 0.79735426]
#  [1.         0.89629309 0.8033413 ]
#  [1.         0.12558531 0.01577167]
#  [1.         0.20724288 0.04294961]
#  [1.         0.0514672  0.00264887]
#  [1.         0.44080984 0.19431332]]
# [[1.         0.28352508 0.08038647]
#  [1.         0.69313792 0.48044017]
#  [1.         0.44045372 0.19399948]
#  [1.         0.15686774 0.02460749]
#  [1.         0.54464902 0.29664255]
#  [1.         0.78031476 0.60889113]
#  [1.         0.30636353 0.09385861]
#  [1.         0.22195788 0.0492653 ]
#  [1.         0.38797126 0.1505217 ]
#  [1.         0.93638365 0.87681434]]
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 1.00100100e-03 1.00200300e-06]
#  [1.00000000e+00 2.00200200e-03 4.00801202e-06]
#  ...
#  [1.00000000e+00 9.97997998e-01 9.96000004e-01]
#  [1.00000000e+00 9.98998999e-01 9.97999000e-01]
#  [1.00000000e+00 1.00000000e+00 1.00000000e+00]]

# %% [markdown]
# ## Least Squares Algorithm

# %% [markdown]
# ORDINARY LEAST SQUARES

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# REGULARIZED LEAST SQUARES

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let's define a function to implement the Regularized Least Square algorithm.
#
# NOTE: OLS is RLS with $\alpha=0$
#
#
# ---
#
#
# *HINTS*
#
# `np.matmul(x1, x2)` -> Matrix product of two arrays
#
# `np.linalg.inv(a)` -> Compute the inverse of a matrix
#
# `a.transpose()` -> Reverse or permute the axes of an array
#
# `a.squeeze()` -> Remove single-dimensional entries from the shape of an array
#
# `np.identity(n)` -> Return the $n \times  n$ identity array

# %%
def least_squares(x, y, pol_order, reg_term):
    """
    Implement the least square algorithm to fit a polynomial function of order "pol_order"
    INPUT
        x: training x data
        y: training y data
        pol_order: order of the fitting polynomial function
        reg_term: regularization term
    OUTPUT
        beta_est: estimated parameter vector
    """

    # Create the Y matrix
    Y = y.reshape(len(y), 1)
    # Create the X matrix
    X = np.array([x**i for i in range(pol_order+1)]).transpose()

    # RLS algorithm
    ### INSERT YOUR CODE HERE ###
    gram_matrix = np.matmul(X.T, X) + reg_term*np.identity(pol_order + 1)
    gram_matrix_inv = np.linalg.inv(gram_matrix)
    temp = np.matmul(gram_matrix_inv,X.T)
    beta_est = np.matmul(temp,Y)
    ### INSERT YOUR CODE HERE ###
    return beta_est.squeeze()

# %% [markdown]
# ### Ordinary Least Square (OLS) - No regularization - Model known

# %% [markdown]
# Let's suppose that we already know that the order of the underlying polynomial model is 2 (this is a very valuable **prior** information, and rarely happens in real world cases).

# %%
### Fit the model
beta_ols = least_squares(x_train, y_train, pol_order=2, reg_term=0)

print('True parameters', beta_true)
print('Inferred parameters', beta_ols)
# Out:
# True parameters [-1.45, 1.12, 2.3]
# Inferred parameters [-1.47163667  0.39838972  3.44032748]

# %%
### Plot
plt.close('all')
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Measured data points')
plt.plot(x_highres, poly_model(x_highres, beta_ols), color='g', ls='--', label='OLS inferred model')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 1.00100100e-03 1.00200300e-06]
#  [1.00000000e+00 2.00200200e-03 4.00801202e-06]
#  ...
#  [1.00000000e+00 9.97997998e-01 9.96000004e-01]
#  [1.00000000e+00 9.98998999e-01 9.97999000e-01]
#  [1.00000000e+00 1.00000000e+00 1.00000000e+00]]
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 1.00100100e-03 1.00200300e-06]
#  [1.00000000e+00 2.00200200e-03 4.00801202e-06]
#  ...
#  [1.00000000e+00 9.97997998e-01 9.96000004e-01]
#  [1.00000000e+00 9.98998999e-01 9.97999000e-01]
#  [1.00000000e+00 1.00000000e+00 1.00000000e+00]]

# %%
### Train and test loss
# Evaluate the average train MSE
y_train_ols = poly_model(x_train, beta_ols)
train_loss = np.mean((y_train_ols - y_train)**2)
print('Train loss:', train_loss)

# Evaluate the average test loss
y_test_ols = poly_model(x_test, beta_ols)
test_loss = np.mean((y_test_ols - y_test)**2)
print('Test loss:', test_loss)
# Out:
# [[1.         0.5507979  0.30337833]
#  [1.         0.70814782 0.50147334]
#  [1.         0.29090474 0.08462557]
#  [1.         0.51082761 0.26094484]
#  [1.         0.89294695 0.79735426]
#  [1.         0.89629309 0.8033413 ]
#  [1.         0.12558531 0.01577167]
#  [1.         0.20724288 0.04294961]
#  [1.         0.0514672  0.00264887]
#  [1.         0.44080984 0.19431332]]
# Train loss: 0.017660800078658986
# [[1.         0.28352508 0.08038647]
#  [1.         0.69313792 0.48044017]
#  [1.         0.44045372 0.19399948]
#  [1.         0.15686774 0.02460749]
#  [1.         0.54464902 0.29664255]
#  [1.         0.78031476 0.60889113]
#  [1.         0.30636353 0.09385861]
#  [1.         0.22195788 0.0492653 ]
#  [1.         0.38797126 0.1505217 ]
#  [1.         0.93638365 0.87681434]]
# Test loss: 0.08031750472826912

# %% [markdown]
# As you can see the model is pretty close to the true one, considering the low number of training points.
#
# Any knowledge about the true model is **very** helpful!

# %% [markdown]
# ### Ordinary Least Square (OLS) - No regularization - Model unknown

# %% [markdown]
# Now let's consider a more realistic scenario, where we know nothing about the true model. Since we do not have any information, we can try to fit a polynomial model with order 9.

# %%
### Fit the model with a higher order polynomial
beta_ols_ho = least_squares(x_train, y_train, pol_order=9, reg_term=0)

print('True parameters', beta_true)
print('Inferred parameters', beta_ols_ho)
# Out:
# True parameters [-1.45, 1.12, 2.3]
# Inferred parameters [-1.88474808e+01  7.47168109e+02 -1.19125162e+04  9.69081689e+04
#  -4.53210209e+05  1.28448805e+06 -2.23540146e+06  2.32901440e+06
#  -1.33048282e+06  3.20009480e+05]

# %%
### Plot
plt.close('all')
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Measured data points')
plt.plot(x_highres, poly_model(x_highres, beta_ols_ho), color='g', ls='--', label='OLS inferred model')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.ylim([-2.5,2.5])
plt.show()
# Out:
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 1.00100100e-03 1.00200300e-06]
#  [1.00000000e+00 2.00200200e-03 4.00801202e-06]
#  ...
#  [1.00000000e+00 9.97997998e-01 9.96000004e-01]
#  [1.00000000e+00 9.98998999e-01 9.97999000e-01]
#  [1.00000000e+00 1.00000000e+00 1.00000000e+00]]
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 1.00100100e-03 1.00200300e-06 ... 1.00702808e-21
#   1.00803612e-24 1.00904517e-27]
#  [1.00000000e+00 2.00200200e-03 4.00801202e-06 ... 1.28899595e-19
#   2.58057247e-22 5.16631125e-25]
#  ...
#  [1.00000000e+00 9.97997998e-01 9.96000004e-01 ... 9.86069874e-01
#   9.84095760e-01 9.82125598e-01]
#  [1.00000000e+00 9.98998999e-01 9.97999000e-01 ... 9.93014000e-01
#   9.92019992e-01 9.91026979e-01]
#  [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]]

# %%
### Train and test loss
# Evaluate the average train MSE
y_train_ols = poly_model(x_train, beta_ols_ho)
train_loss = np.mean((y_train_ols - y_train)**2)
print('Train loss:', train_loss)

# Evaluate the average test loss
y_test_ols = poly_model(x_test, beta_ols_ho)
test_loss = np.mean((y_test_ols - y_test)**2)
print('Test loss:', test_loss)
# Out:
# [[1.00000000e+00 5.50797903e-01 3.03378329e-01 1.67100148e-01
#   9.20384108e-02 5.06945636e-02 2.79224593e-02 1.53796320e-02
#   8.47106906e-03 4.66584707e-03]
#  [1.00000000e+00 7.08147823e-01 5.01473339e-01 3.55117253e-01
#   2.51475509e-01 1.78081834e-01 1.26108263e-01 8.93032921e-02
#   6.32399318e-02 4.47832200e-02]
#  [1.00000000e+00 2.90904739e-01 8.46255671e-02 2.46179785e-02
#   7.16148661e-03 2.08331039e-03 6.06044866e-04 1.76301323e-04
#   5.12868905e-05 1.49195995e-05]
#  [1.00000000e+00 5.10827605e-01 2.60944842e-01 1.33297829e-01
#   6.80922107e-02 3.47833809e-02 1.77683112e-02 9.07654385e-03
#   4.63654916e-03 2.36847730e-03]
#  [1.00000000e+00 8.92946954e-01 7.97354263e-01 7.11995061e-01
#   6.35773821e-01 5.67712297e-01 5.06936967e-01 4.52667821e-01
#   4.04208352e-01 3.60936617e-01]
#  [1.00000000e+00 8.96293089e-01 8.03341301e-01 7.20029256e-01
#   6.45357246e-01 5.78429240e-01 5.18442130e-01 4.64676098e-01
#   4.16485975e-01 3.73293501e-01]
#  [1.00000000e+00 1.25585310e-01 1.57716702e-02 1.98069010e-03
#   2.48745581e-04 3.12387910e-05 3.92313327e-06 4.92687910e-07
#   6.18743641e-08 7.77051122e-09]
#  [1.00000000e+00 2.07242878e-01 4.29496105e-02 8.90100090e-03
#   1.84466905e-03 3.82294522e-04 7.92278171e-05 1.64194008e-05
#   3.40280389e-06 7.05206871e-07]
#  [1.00000000e+00 5.14672033e-02 2.64887302e-03 1.36330086e-04
#   7.01652825e-06 3.61121086e-07 1.85858924e-08 9.56563900e-10
#   4.92316687e-11 2.53381630e-12]
#  [1.00000000e+00 4.40809844e-01 1.94313318e-01 8.56552234e-02
#   3.77576657e-02 1.66439507e-02 7.33681730e-03 3.23414129e-03
#   1.42564132e-03 6.28436725e-04]]
# Train loss: 6.720476082226203e-06
# [[1.00000000e+00 2.83525082e-01 8.03864720e-02 2.27915810e-02
#   6.46198488e-03 1.83213479e-03 5.19456167e-04 1.47278852e-04
#   4.17572486e-05 1.18392273e-05]
#  [1.00000000e+00 6.93137918e-01 4.80440174e-01 3.33011302e-01
#   2.30822761e-01 1.59992008e-01 1.10896527e-01 7.68665880e-02
#   5.32791468e-02 3.69297969e-02]
#  [1.00000000e+00 4.40453718e-01 1.93999477e-01 8.54477911e-02
#   3.76357972e-02 1.65768268e-02 7.30132500e-03 3.21589574e-03
#   1.41645323e-03 6.23882093e-04]
#  [1.00000000e+00 1.56867738e-01 2.46074874e-02 3.86012089e-03
#   6.05528435e-04 9.49878762e-05 1.49005333e-05 2.33741296e-06
#   3.66664685e-07 5.75178600e-08]
#  [1.00000000e+00 5.44649018e-01 2.96642553e-01 1.61566075e-01
#   8.79968042e-02 4.79273730e-02 2.61035966e-02 1.42172983e-02
#   7.74343754e-03 4.21745565e-03]
#  [1.00000000e+00 7.80314765e-01 6.08891132e-01 4.75126740e-01
#   3.70748410e-01 2.89300458e-01 2.25745419e-01 1.76152484e-01
#   1.37454384e-01 1.07257685e-01]
#  [1.00000000e+00 3.06363532e-01 9.38586140e-02 2.87548565e-02
#   8.80943942e-03 2.69889098e-03 8.26841773e-04 2.53314166e-04
#   7.76062228e-05 2.37757166e-05]
#  [1.00000000e+00 2.21957884e-01 4.92653022e-02 1.09348222e-02
#   2.42707000e-03 5.38707322e-04 1.19570337e-04 2.65395791e-05
#   5.89066881e-06 1.30748038e-06]
#  [1.00000000e+00 3.87971258e-01 1.50521697e-01 5.83980920e-02
#   2.26567812e-02 8.79017988e-03 3.41033714e-03 1.32311279e-03
#   5.13329733e-04 1.99157182e-04]
#  [1.00000000e+00 9.36383650e-01 8.76814340e-01 8.21034612e-01
#   7.68803386e-01 7.19894921e-01 6.74097834e-01 6.31214190e-01
#   5.91058647e-01 5.53457653e-01]]
# Test loss: 15.522608073580937

# %% [markdown]
# This is a typical case of **overfitting**. We are trying to fit a model that is much more complex than the real one.
#
# As you can see, the polynomial coefficients found are very large.
#
# To alleviate this effect, we can include a **regularization** term, which penalizes coefficients with large (quadratic) values.
#
# ---
#
# *NOTE*
#
# We are considering an L2 regularization (quadratic penalty term), which has an analitical solution.
#
# We can also consider the absolute values of the coefficient in the regularization term (L1 regularization).

# %% [markdown]
# ### Regularized Least Squares (RLS) - Model unknown

# %% [markdown]
# Let's fit the same model as before, but with a regularization term of $0.1$.

# %%
### Fit the model with a higher order polynomial
beta_rls = least_squares(x_train, y_train, pol_order=9, reg_term=0.1)

print('True parameters', beta_true)
print('Inferred parameters', beta_rls)
# Out:
# True parameters [-1.45, 1.12, 2.3]
# Inferred parameters [-1.40193978  1.11945046  1.00587865  0.69763917  0.46265449  0.31011377
#   0.21529531  0.15648382  0.11926821  0.09488916]

# %%
### Plot
plt.close('all')
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Measured data points')
plt.plot(x_highres, poly_model(x_highres, beta_rls), color='g', ls='--', label='OLS inferred model')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.ylim([-1.5,2])
plt.show()
# Out:
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 1.00100100e-03 1.00200300e-06]
#  [1.00000000e+00 2.00200200e-03 4.00801202e-06]
#  ...
#  [1.00000000e+00 9.97997998e-01 9.96000004e-01]
#  [1.00000000e+00 9.98998999e-01 9.97999000e-01]
#  [1.00000000e+00 1.00000000e+00 1.00000000e+00]]
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 1.00100100e-03 1.00200300e-06 ... 1.00702808e-21
#   1.00803612e-24 1.00904517e-27]
#  [1.00000000e+00 2.00200200e-03 4.00801202e-06 ... 1.28899595e-19
#   2.58057247e-22 5.16631125e-25]
#  ...
#  [1.00000000e+00 9.97997998e-01 9.96000004e-01 ... 9.86069874e-01
#   9.84095760e-01 9.82125598e-01]
#  [1.00000000e+00 9.98998999e-01 9.97999000e-01 ... 9.93014000e-01
#   9.92019992e-01 9.91026979e-01]
#  [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.00000000e+00
#   1.00000000e+00 1.00000000e+00]]

# %%
### Train and test loss
# Evaluate the average train MSE
y_train_ols = poly_model(x_train, beta_rls)
train_loss = np.mean((y_train_ols - y_train)**2)
print('Train loss:', train_loss)

# Evaluate the average test loss
y_test_ols = poly_model(x_test, beta_rls)
test_loss = np.mean((y_test_ols - y_test)**2)
print('Test loss:', test_loss)
# Out:
# [[1.00000000e+00 5.50797903e-01 3.03378329e-01 1.67100148e-01
#   9.20384108e-02 5.06945636e-02 2.79224593e-02 1.53796320e-02
#   8.47106906e-03 4.66584707e-03]
#  [1.00000000e+00 7.08147823e-01 5.01473339e-01 3.55117253e-01
#   2.51475509e-01 1.78081834e-01 1.26108263e-01 8.93032921e-02
#   6.32399318e-02 4.47832200e-02]
#  [1.00000000e+00 2.90904739e-01 8.46255671e-02 2.46179785e-02
#   7.16148661e-03 2.08331039e-03 6.06044866e-04 1.76301323e-04
#   5.12868905e-05 1.49195995e-05]
#  [1.00000000e+00 5.10827605e-01 2.60944842e-01 1.33297829e-01
#   6.80922107e-02 3.47833809e-02 1.77683112e-02 9.07654385e-03
#   4.63654916e-03 2.36847730e-03]
#  [1.00000000e+00 8.92946954e-01 7.97354263e-01 7.11995061e-01
#   6.35773821e-01 5.67712297e-01 5.06936967e-01 4.52667821e-01
#   4.04208352e-01 3.60936617e-01]
#  [1.00000000e+00 8.96293089e-01 8.03341301e-01 7.20029256e-01
#   6.45357246e-01 5.78429240e-01 5.18442130e-01 4.64676098e-01
#   4.16485975e-01 3.73293501e-01]
#  [1.00000000e+00 1.25585310e-01 1.57716702e-02 1.98069010e-03
#   2.48745581e-04 3.12387910e-05 3.92313327e-06 4.92687910e-07
#   6.18743641e-08 7.77051122e-09]
#  [1.00000000e+00 2.07242878e-01 4.29496105e-02 8.90100090e-03
#   1.84466905e-03 3.82294522e-04 7.92278171e-05 1.64194008e-05
#   3.40280389e-06 7.05206871e-07]
#  [1.00000000e+00 5.14672033e-02 2.64887302e-03 1.36330086e-04
#   7.01652825e-06 3.61121086e-07 1.85858924e-08 9.56563900e-10
#   4.92316687e-11 2.53381630e-12]
#  [1.00000000e+00 4.40809844e-01 1.94313318e-01 8.56552234e-02
#   3.77576657e-02 1.66439507e-02 7.33681730e-03 3.23414129e-03
#   1.42564132e-03 6.28436725e-04]]
# Train loss: 0.025804726797934985
# [[1.00000000e+00 2.83525082e-01 8.03864720e-02 2.27915810e-02
#   6.46198488e-03 1.83213479e-03 5.19456167e-04 1.47278852e-04
#   4.17572486e-05 1.18392273e-05]
#  [1.00000000e+00 6.93137918e-01 4.80440174e-01 3.33011302e-01
#   2.30822761e-01 1.59992008e-01 1.10896527e-01 7.68665880e-02
#   5.32791468e-02 3.69297969e-02]
#  [1.00000000e+00 4.40453718e-01 1.93999477e-01 8.54477911e-02
#   3.76357972e-02 1.65768268e-02 7.30132500e-03 3.21589574e-03
#   1.41645323e-03 6.23882093e-04]
#  [1.00000000e+00 1.56867738e-01 2.46074874e-02 3.86012089e-03
#   6.05528435e-04 9.49878762e-05 1.49005333e-05 2.33741296e-06
#   3.66664685e-07 5.75178600e-08]
#  [1.00000000e+00 5.44649018e-01 2.96642553e-01 1.61566075e-01
#   8.79968042e-02 4.79273730e-02 2.61035966e-02 1.42172983e-02
#   7.74343754e-03 4.21745565e-03]
#  [1.00000000e+00 7.80314765e-01 6.08891132e-01 4.75126740e-01
#   3.70748410e-01 2.89300458e-01 2.25745419e-01 1.76152484e-01
#   1.37454384e-01 1.07257685e-01]
#  [1.00000000e+00 3.06363532e-01 9.38586140e-02 2.87548565e-02
#   8.80943942e-03 2.69889098e-03 8.26841773e-04 2.53314166e-04
#   7.76062228e-05 2.37757166e-05]
#  [1.00000000e+00 2.21957884e-01 4.92653022e-02 1.09348222e-02
#   2.42707000e-03 5.38707322e-04 1.19570337e-04 2.65395791e-05
#   5.89066881e-06 1.30748038e-06]
#  [1.00000000e+00 3.87971258e-01 1.50521697e-01 5.83980920e-02
#   2.26567812e-02 8.79017988e-03 3.41033714e-03 1.32311279e-03
#   5.13329733e-04 1.99157182e-04]
#  [1.00000000e+00 9.36383650e-01 8.76814340e-01 8.21034612e-01
#   7.68803386e-01 7.19894921e-01 6.74097834e-01 6.31214190e-01
#   5.91058647e-01 5.53457653e-01]]
# Test loss: 0.09037839040251959

# %% [markdown]
# The result is much better! Keep in mind that we are fitting a polynomial model of **order 9** with data generated by a polynomial model of **order 2** , still achieving good results.

# %% [markdown]
# ## The generalization problem

# %% [markdown]
# But what happens if we extend the model just trained outside the range of the training points?
#
# Let's try.

# %%
### Plot
plt.close('all')
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,2,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Measured data points')
plt.plot(x_highres, poly_model(x_highres, beta_rls), color='g', ls='--', label='RLS inferred model')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 2.00200200e-03 4.00801202e-06]
#  [1.00000000e+00 4.00400400e-03 1.60320481e-05]
#  ...
#  [1.00000000e+00 1.99599600e+00 3.98400002e+00]
#  [1.00000000e+00 1.99799800e+00 3.99199600e+00]
#  [1.00000000e+00 2.00000000e+00 4.00000000e+00]]
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 2.00200200e-03 4.00801202e-06 ... 1.28899595e-19
#   2.58057247e-22 5.16631125e-25]
#  [1.00000000e+00 4.00400400e-03 1.60320481e-05 ... 1.64991481e-17
#   6.60626552e-20 2.64515136e-22]
#  ...
#  [1.00000000e+00 1.99599600e+00 3.98400002e+00 ... 1.26216944e+02
#   2.51928515e+02 5.02848306e+02]
#  [1.00000000e+00 1.99799800e+00 3.99199600e+00 ... 1.27105792e+02
#   2.53957118e+02 5.07405813e+02]
#  [1.00000000e+00 2.00000000e+00 4.00000000e+00 ... 1.28000000e+02
#   2.56000000e+02 5.12000000e+02]]

# %% [markdown]
# As you can see, the further we are from the region where we have training data, the worse the trained model approximates the true one. The inferred model does not **generalize** well outside the training space.
#
# Typically, simpler models generalize better than complex models. When two models perform the same, the best option is (almost) always to choose the simplest of the two.

# %% [markdown]
# ## Parameter optimization

# %% [markdown]
# In the previous training we used a regularization term $\alpha=0.1$. But how we choose this type of parameters?
#
# Most machine learning/deep learning algorithms have several hyper-parameters that considerably affect the results. To find a good set of hyper-parameters we need an additional set of data, referred to as **validation** data. Hyper-parameters are typically chosen by minimizing the error on the validation set (or better by performing a cross-validation).
#
# **TO SUMMARIZE:**
#
# *   **Always divide your dataset in a training set and a test set.**
# *   **Further divide your training set to have a validation set for hyper-parameter optimization (or perform a cross-validation)**
# *   **Never touch the test set during the optimization (this is cheating!). It can be used only at the end for the final test.**

# %% [markdown]
# # Part 2: Least Squares with PyTorch

# %% [markdown]
# We will now solve the same problem, however, instead of computing the solution using the closed form equation, we wil cast this problem as a regression task and we will solve it using a simple Neural Network implemented in PyTorch.

# %% [markdown]
# ## Data generation

# %% [markdown]
# Let's generate some data with our usual polynomial model, and save the data points in two csv files, one for training (train_data.csv), and one for validation (val_data.csv).
#
# You can find these files in the "Files" section of Colab, in the "content" folder. They are not stored in your local machine, but they are stored remotely in the Colab server.

# %%
def poly_model(x, beta, noise_std=0):
    """
    INPUT
        x: x vector
        beta: polynomial parameters
        noise_std: enable noisy sampling (gaussian noise, zero mean, noise_std std)
    """
    pol_order = len(beta)
    x_matrix = np.array([x**i for i in range(pol_order)]).transpose()
    y = np.matmul(x_matrix, beta)
    noise = np.random.randn(len(y)) * noise_std
    return y + noise

beta_true = [-1.45, 1.12, 2.3]
noise_std = 0.2
np.random.seed(4)

### Train data
num_train_points = 20
x_train = np.random.rand(num_train_points)
y_train = poly_model(x_train, beta_true, noise_std)
with open('train_data.csv', 'w') as f:
    data = [f"{x},{y}" for x, y in zip(x_train, y_train)]
    f.write('\n'.join(data))

### Validation data
num_val_points = 20
x_val = np.random.rand(num_val_points)
y_val = poly_model(x_val, beta_true, noise_std)
with open('val_data.csv', 'w') as f:
    data = [f"{x},{y}" for x, y in zip(x_val, y_val)]
    f.write('\n'.join(data))


### Plot
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Train data points')
plt.plot(x_val, y_val, color='g', ls='', marker='.', label='Validation data points')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Network Definition

# %% [markdown]
# Define a fully connected feed-forward network with 2 hidden layers.
#
# Use a sigmoid activation function.
#
# Since this is a regression, we do not want to limit the value of the output. For this reason, NO activation function should be used for the output layer.

# %%
class Net(nn.Module):

    def __init__(self, Ni, Nh1, Nh2, No):
        """
        Ni - Input size
        Nh1 - Neurons in the 1st hidden layer
        Nh2 - Neurons in the 2nd hidden layer
        No - Output size
        """
        super().__init__()

        print('Network initialized')
        ###################################################
        ### PUT YOR CODE HERE
        self.fc1 = nn.Linear(in_features=Ni, out_features=Nh1)
        self.fc2 = nn.Linear(in_features=Nh1, out_features=Nh2)
        self.out = nn.Linear(in_features=Nh2, out_features=No)
        self.act = nn.Sigmoid()
        ###################################################

    def forward(self, x, additional_out=False):
        ###################################################
        ### PUT YOR CODE HERE
        # don't forget the activations: not incuded by default!
        x = self.fc1(x)
        x = self.act(x)
        x = self.fc2(x)
        x = self.act(x)
        x = self.out(x)
        ###################################################
        return x

# %% [markdown]
# ## Dataset and Dataloader

# %% [markdown]
# We have already implemented the dataset class in the previous lab.

# %% [markdown]
# ### Dataset

# %%
class CsvDataset(Dataset):

    def __init__(self, csv_file, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.transform = transform
        # Read the file and split the lines in a list
        with open(csv_file, 'r') as f:
            lines = f.read().split('\n')
        # Get x and y values from each line and append to self.data
        self.data = []
        for line in lines:
            sample = line.split(',')
            self.data.append((float(sample[0]), float(sample[1])))
        # Now self.data contains all our dataset.
        # Each element of the list self.data is a tuple: (input, output)

    def __len__(self):
        # The length of the dataset is simply the length of the self.data list
        return len(self.data)

    def __getitem__(self, idx):
        # Our sample is the element idx of the list self.data
        sample = self.data[idx]
        if self.transform:
            sample = self.transform(sample)
        return sample

# %% [markdown]
# ### Transforms

# %%
class ToTensor(object):
    """Convert sample to Tensors."""

    def __call__(self, sample):
        x, y = sample
        return (torch.tensor([x]).float(),
                torch.tensor([y]).float())

# %%
composed_transform = transforms.Compose([ToTensor()])

train_dataset = CsvDataset('train_data.csv', transform=composed_transform)
val_dataset = CsvDataset('val_data.csv', transform=composed_transform)

# %% [markdown]
# ### Dataloader

# %% [markdown]
# For the dataloader:
#
# * enable the shuffling only for training data
# * try different values for batch size
# * disable the multiprocessing

# %%
train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=0)
val_dataloader  = DataLoader(val_dataset,  batch_size=len(val_dataset), shuffle=False, num_workers=0)

# %% [markdown]
# ## Training loop

# %% [markdown]
# Now we put together all the steps analyzed in the previous lab:

# %%
# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Training device: {device}")
# Out:
# Training device: cpu

# %%
# Initialize the network
torch.manual_seed(0)
Ni = 1
Nh1 = 128
Nh2 = 256
No = 1
net = Net(Ni, Nh1, Nh2, No)
net.to(device)
# Out:
# Network initialized
# Net(
#   (fc1): Linear(in_features=1, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (out): Linear(in_features=256, out_features=1, bias=True)
#   (act): Sigmoid()
# )

# %%
# Define the loss function
loss_fn = nn.MSELoss()

# %%
# Define the optimizer
optimizer = optim.Adam(net.parameters(), lr=1e-3)

# %%
num_epochs = 3000
train_loss_log = []
val_loss_log = []
for epoch_num in range(num_epochs):
    print('#################')
    print(f'# EPOCH {epoch_num}')
    print('#################')

    ### TRAIN
    train_loss= []
    net.train() # Training mode (e.g. enable dropout, batchnorm updates,...)
    for sample_batched in train_dataloader:
        # Move data to device
        x_batch = sample_batched[0].to(device)
        label_batch = sample_batched[1].to(device)

        ###########################################
        ### PUT YOUR CODE HERE
        # Forward pass
        out = net(x_batch)

        # Compute loss
        loss = loss_fn(out, label_batch)

        # Backpropagation
        net.zero_grad()
        loss.backward()

        # Update the weights
        optimizer.step()
        ###########################################

        # Save train loss for this batch
        loss_batch = loss.detach().cpu().numpy()
        train_loss.append(loss_batch)

    # Save average train loss
    train_loss = np.mean(train_loss)
    print(f"AVERAGE TRAIN LOSS: {train_loss}")
    train_loss_log.append(train_loss)

    ### VALIDATION
    val_loss= []
    net.eval() # Evaluation mode (e.g. disable dropout, batchnorm,...)
    with torch.no_grad(): # Disable gradient tracking
        for sample_batched in val_dataloader:
            # Move data to device
            x_batch = sample_batched[0].to(device)
            label_batch = sample_batched[1].to(device)

            ###########################################
            ### PUT YOUR CODE HERE
            # Forward pass
            out = net(x_batch)

            # Compute loss
            loss = loss_fn(out, label_batch)
            ###########################################

            # Save val loss for this batch
            loss_batch = loss.detach().cpu().numpy()
            val_loss.append(loss_batch)


        # Save average validation loss
        val_loss = np.mean(val_loss)
        print(f"AVERAGE VAL LOSS: {np.mean(val_loss)}")
        val_loss_log.append(val_loss)
# Out:
# Output streaming troncato alle ultime 5000 righe.
# #################
# # EPOCH 2000
# #################
# AVERAGE TRAIN LOSS: 0.030761176720261574
# AVERAGE VAL LOSS: 0.07925938069820404
# #################
# # EPOCH 2001
# #################
# AVERAGE TRAIN LOSS: 0.02385467104613781
# AVERAGE VAL LOSS: 0.05682026222348213
# #################
# # EPOCH 2002
# #################
# AVERAGE TRAIN LOSS: 0.023417336866259575
# AVERAGE VAL LOSS: 0.060226332396268845
# #################
# # EPOCH 2003
# #################
# AVERAGE TRAIN LOSS: 0.020440971478819847
# AVERAGE VAL LOSS: 0.06732533872127533
# #################
# # EPOCH 2004
# #################
# AVERAGE TRAIN LOSS: 0.020265020430088043
# AVERAGE VAL LOSS: 0.05813709646463394
# #################
# # EPOCH 2005
# #################
# AVERAGE TRAIN LOSS: 0.01976548135280609
# AVERAGE VAL LOSS: 0.05999646708369255
# #################
# # EPOCH 2006
# #################
# AVERAGE TRAIN LOSS: 0.02011236548423767
# AVERAGE VAL LOSS: 0.06144241243600845
# #################
# # EPOCH 2007
# #################
# AVERAGE TRAIN LOSS: 0.019653435796499252
# AVERAGE VAL LOSS: 0.06018006056547165
# #################
# # EPOCH 2008
# #################
# AVERAGE TRAIN LOSS: 0.019838472828269005
# AVERAGE VAL LOSS: 0.05899708345532417
# #################
# # EPOCH 2009
# #################
# AVERAGE TRAIN LOSS: 0.01958249881863594
# AVERAGE VAL LOSS: 0.06403426080942154
# #################
# # EPOCH 2010
# #################
# AVERAGE TRAIN LOSS: 0.02139190398156643
# AVERAGE VAL LOSS: 0.06110389158129692
# #################
# # EPOCH 2011
# #################
# AVERAGE TRAIN LOSS: 0.027714675292372704
# AVERAGE VAL LOSS: 0.05644984915852547
# #################
# # EPOCH 2012
# #################
# AVERAGE TRAIN LOSS: 0.02135426551103592
# AVERAGE VAL LOSS: 0.07433728873729706
# #################
# # EPOCH 2013
# #################
# AVERAGE TRAIN LOSS: 0.023614075034856796
# AVERAGE VAL LOSS: 0.06252352893352509
# #################
# # EPOCH 2014
# #################
# AVERAGE TRAIN LOSS: 0.02678772807121277
# AVERAGE VAL LOSS: 0.05863240361213684
# #################
# # EPOCH 2015
# #################
# AVERAGE TRAIN LOSS: 0.025500673800706863
# AVERAGE VAL LOSS: 0.0729912668466568
# #################
# # EPOCH 2016
# #################
# AVERAGE TRAIN LOSS: 0.02400653064250946
# AVERAGE VAL LOSS: 0.05880815535783768
# #################
# # EPOCH 2017
# #################
# AVERAGE TRAIN LOSS: 0.020000092685222626
# AVERAGE VAL LOSS: 0.061265598982572556
# #################
# # EPOCH 2018
# #################
# AVERAGE TRAIN LOSS: 0.019539350643754005
# AVERAGE VAL LOSS: 0.06132016330957413
# #################
# # EPOCH 2019
# #################
# AVERAGE TRAIN LOSS: 0.02130643092095852
# AVERAGE VAL LOSS: 0.05896405130624771
# #################
# # EPOCH 2020
# #################
# AVERAGE TRAIN LOSS: 0.019054900854825974
# AVERAGE VAL LOSS: 0.06231057643890381
# #################
# # EPOCH 2021
# #################
# AVERAGE TRAIN LOSS: 0.019911719486117363
# AVERAGE VAL LOSS: 0.06240454316139221
# #################
# # EPOCH 2022
# #################
# AVERAGE TRAIN LOSS: 0.020522015169262886
# AVERAGE VAL LOSS: 0.05934908986091614
# #################
# # EPOCH 2023
# #################
# AVERAGE TRAIN LOSS: 0.021598970517516136
# AVERAGE VAL LOSS: 0.06071780249476433
# #################
# # EPOCH 2024
# #################
# AVERAGE TRAIN LOSS: 0.023729074746370316
# AVERAGE VAL LOSS: 0.0704159289598465
# #################
# # EPOCH 2025
# #################
# AVERAGE TRAIN LOSS: 0.01964425854384899
# AVERAGE VAL LOSS: 0.056141309440135956
# #################
# # EPOCH 2026
# #################
# AVERAGE TRAIN LOSS: 0.023758267983794212
# AVERAGE VAL LOSS: 0.057574380189180374
# #################
# # EPOCH 2027
# #################
# AVERAGE TRAIN LOSS: 0.020679883658885956
# AVERAGE VAL LOSS: 0.07058235257863998
# #################
# # EPOCH 2028
# #################
# AVERAGE TRAIN LOSS: 0.022502476349473
# AVERAGE VAL LOSS: 0.06281930208206177
# #################
# # EPOCH 2029
# #################
# AVERAGE TRAIN LOSS: 0.019081275910139084
# AVERAGE VAL LOSS: 0.057730674743652344
# #################
# # EPOCH 2030
# #################
# AVERAGE TRAIN LOSS: 0.020618855953216553
# AVERAGE VAL LOSS: 0.06094575673341751
# #################
# # EPOCH 2031
# #################
# AVERAGE TRAIN LOSS: 0.020156830549240112
# AVERAGE VAL LOSS: 0.07038859277963638
# #################
# # EPOCH 2032
# #################
# AVERAGE TRAIN LOSS: 0.02065255492925644
# AVERAGE VAL LOSS: 0.05901104956865311
# #################
# # EPOCH 2033
# #################
# AVERAGE TRAIN LOSS: 0.01995854452252388
# AVERAGE VAL LOSS: 0.059751249849796295
# #################
# # EPOCH 2034
# #################
# AVERAGE TRAIN LOSS: 0.01911875046789646
# AVERAGE VAL LOSS: 0.06112396717071533
# #################
# # EPOCH 2035
# #################
# AVERAGE TRAIN LOSS: 0.020418759435415268
# AVERAGE VAL LOSS: 0.06588657200336456
# #################
# # EPOCH 2036
# #################
# AVERAGE TRAIN LOSS: 0.020058609545230865
# AVERAGE VAL LOSS: 0.05930458381772041
# #################
# # EPOCH 2037
# #################
# AVERAGE TRAIN LOSS: 0.021235287189483643
# AVERAGE VAL LOSS: 0.060570526868104935
# #################
# # EPOCH 2038
# #################
# AVERAGE TRAIN LOSS: 0.019066371023654938
# AVERAGE VAL LOSS: 0.0664534643292427
# #################
# # EPOCH 2039
# #################
# AVERAGE TRAIN LOSS: 0.019533973187208176
# AVERAGE VAL LOSS: 0.06031976267695427
# #################
# # EPOCH 2040
# #################
# AVERAGE TRAIN LOSS: 0.021370114758610725
# AVERAGE VAL LOSS: 0.05714981630444527
# #################
# # EPOCH 2041
# #################
# AVERAGE TRAIN LOSS: 0.018260519951581955
# AVERAGE VAL LOSS: 0.0643567144870758
# #################
# # EPOCH 2042
# #################
# AVERAGE TRAIN LOSS: 0.019863983616232872
# AVERAGE VAL LOSS: 0.06366214156150818
# #################
# # EPOCH 2043
# #################
# AVERAGE TRAIN LOSS: 0.01908380165696144
# AVERAGE VAL LOSS: 0.060714252293109894
# #################
# # EPOCH 2044
# #################
# AVERAGE TRAIN LOSS: 0.019568566232919693
# AVERAGE VAL LOSS: 0.05967559665441513
# #################
# # EPOCH 2045
# #################
# AVERAGE TRAIN LOSS: 0.018881745636463165
# AVERAGE VAL LOSS: 0.06252481788396835
# #################
# # EPOCH 2046
# #################
# AVERAGE TRAIN LOSS: 0.019670160487294197
# AVERAGE VAL LOSS: 0.06530778110027313
# #################
# # EPOCH 2047
# #################
# AVERAGE TRAIN LOSS: 0.02118965983390808
# AVERAGE VAL LOSS: 0.05958639457821846
# #################
# # EPOCH 2048
# #################
# AVERAGE TRAIN LOSS: 0.020806115120649338
# AVERAGE VAL LOSS: 0.059670545160770416
# #################
# # EPOCH 2049
# #################
# AVERAGE TRAIN LOSS: 0.025583416223526
# AVERAGE VAL LOSS: 0.057875484228134155
# #################
# # EPOCH 2050
# #################
# AVERAGE TRAIN LOSS: 0.02450670301914215
# AVERAGE VAL LOSS: 0.07726234197616577
# #################
# # EPOCH 2051
# #################
# AVERAGE TRAIN LOSS: 0.021185746416449547
# AVERAGE VAL LOSS: 0.05852892994880676
# #################
# # EPOCH 2052
# #################
# AVERAGE TRAIN LOSS: 0.021422138437628746
# AVERAGE VAL LOSS: 0.05731458216905594
# #################
# # EPOCH 2053
# #################
# AVERAGE TRAIN LOSS: 0.021219836547970772
# AVERAGE VAL LOSS: 0.06668846309185028
# #################
# # EPOCH 2054
# #################
# AVERAGE TRAIN LOSS: 0.01972264237701893
# AVERAGE VAL LOSS: 0.06243252754211426
# #################
# # EPOCH 2055
# #################
# AVERAGE TRAIN LOSS: 0.019211603328585625
# AVERAGE VAL LOSS: 0.05860552191734314
# #################
# # EPOCH 2056
# #################
# AVERAGE TRAIN LOSS: 0.020188303664326668
# AVERAGE VAL LOSS: 0.06297504901885986
# #################
# # EPOCH 2057
# #################
# AVERAGE TRAIN LOSS: 0.01928667351603508
# AVERAGE VAL LOSS: 0.06293982267379761
# #################
# # EPOCH 2058
# #################
# AVERAGE TRAIN LOSS: 0.019677134230732918
# AVERAGE VAL LOSS: 0.060741644352674484
# #################
# # EPOCH 2059
# #################
# AVERAGE TRAIN LOSS: 0.01989501714706421
# AVERAGE VAL LOSS: 0.06518815457820892
# #################
# # EPOCH 2060
# #################
# AVERAGE TRAIN LOSS: 0.019805554300546646
# AVERAGE VAL LOSS: 0.060494355857372284
# #################
# # EPOCH 2061
# #################
# AVERAGE TRAIN LOSS: 0.02481929399073124
# AVERAGE VAL LOSS: 0.06397566944360733
# #################
# # EPOCH 2062
# #################
# AVERAGE TRAIN LOSS: 0.020773084834218025
# AVERAGE VAL LOSS: 0.05871937796473503
# #################
# # EPOCH 2063
# #################
# AVERAGE TRAIN LOSS: 0.020123697817325592
# AVERAGE VAL LOSS: 0.057683300226926804
# #################
# # EPOCH 2064
# #################
# AVERAGE TRAIN LOSS: 0.02402551844716072
# AVERAGE VAL LOSS: 0.06819931417703629
# #################
# # EPOCH 2065
# #################
# AVERAGE TRAIN LOSS: 0.021055052056908607
# AVERAGE VAL LOSS: 0.06098773330450058
# #################
# # EPOCH 2066
# #################
# AVERAGE TRAIN LOSS: 0.01953129656612873
# AVERAGE VAL LOSS: 0.06158053129911423
# #################
# # EPOCH 2067
# #################
# AVERAGE TRAIN LOSS: 0.020032338798046112
# AVERAGE VAL LOSS: 0.06312019377946854
# #################
# # EPOCH 2068
# #################
# AVERAGE TRAIN LOSS: 0.020292915403842926
# AVERAGE VAL LOSS: 0.06034883111715317
# #################
# # EPOCH 2069
# #################
# AVERAGE TRAIN LOSS: 0.019232505932450294
# AVERAGE VAL LOSS: 0.06049147993326187
# #################
# # EPOCH 2070
# #################
# AVERAGE TRAIN LOSS: 0.019224397838115692
# AVERAGE VAL LOSS: 0.06100798770785332
# #################
# # EPOCH 2071
# #################
# AVERAGE TRAIN LOSS: 0.02058011293411255
# AVERAGE VAL LOSS: 0.06483541429042816
# #################
# # EPOCH 2072
# #################
# AVERAGE TRAIN LOSS: 0.019978033378720284
# AVERAGE VAL LOSS: 0.05880878120660782
# #################
# # EPOCH 2073
# #################
# AVERAGE TRAIN LOSS: 0.02251107431948185
# AVERAGE VAL LOSS: 0.06430499255657196
# #################
# # EPOCH 2074
# #################
# AVERAGE TRAIN LOSS: 0.020087314769625664
# AVERAGE VAL LOSS: 0.06005215644836426
# #################
# # EPOCH 2075
# #################
# AVERAGE TRAIN LOSS: 0.01979873515665531
# AVERAGE VAL LOSS: 0.06235251948237419
# #################
# # EPOCH 2076
# #################
# AVERAGE TRAIN LOSS: 0.020048215985298157
# AVERAGE VAL LOSS: 0.05889797955751419
# #################
# # EPOCH 2077
# #################
# AVERAGE TRAIN LOSS: 0.020624395459890366
# AVERAGE VAL LOSS: 0.06375022977590561
# #################
# # EPOCH 2078
# #################
# AVERAGE TRAIN LOSS: 0.020540958270430565
# AVERAGE VAL LOSS: 0.06056266278028488
# #################
# # EPOCH 2079
# #################
# AVERAGE TRAIN LOSS: 0.02011677622795105
# AVERAGE VAL LOSS: 0.06020671874284744
# #################
# # EPOCH 2080
# #################
# AVERAGE TRAIN LOSS: 0.02013610303401947
# AVERAGE VAL LOSS: 0.06317146122455597
# #################
# # EPOCH 2081
# #################
# AVERAGE TRAIN LOSS: 0.01948818936944008
# AVERAGE VAL LOSS: 0.06008685380220413
# #################
# # EPOCH 2082
# #################
# AVERAGE TRAIN LOSS: 0.022868726402521133
# AVERAGE VAL LOSS: 0.06016134098172188
# #################
# # EPOCH 2083
# #################
# AVERAGE TRAIN LOSS: 0.019153766334056854
# AVERAGE VAL LOSS: 0.07063905894756317
# #################
# # EPOCH 2084
# #################
# AVERAGE TRAIN LOSS: 0.021946776658296585
# AVERAGE VAL LOSS: 0.062078218907117844
# #################
# # EPOCH 2085
# #################
# AVERAGE TRAIN LOSS: 0.023677930235862732
# AVERAGE VAL LOSS: 0.058700717985630035
# #################
# # EPOCH 2086
# #################
# AVERAGE TRAIN LOSS: 0.018991798162460327
# AVERAGE VAL LOSS: 0.06659307330846786
# #################
# # EPOCH 2087
# #################
# AVERAGE TRAIN LOSS: 0.025545477867126465
# AVERAGE VAL LOSS: 0.06644056737422943
# #################
# # EPOCH 2088
# #################
# AVERAGE TRAIN LOSS: 0.02624983713030815
# AVERAGE VAL LOSS: 0.05764172598719597
# #################
# # EPOCH 2089
# #################
# AVERAGE TRAIN LOSS: 0.024481594562530518
# AVERAGE VAL LOSS: 0.07173516601324081
# #################
# # EPOCH 2090
# #################
# AVERAGE TRAIN LOSS: 0.025725623592734337
# AVERAGE VAL LOSS: 0.06347975134849548
# #################
# # EPOCH 2091
# #################
# AVERAGE TRAIN LOSS: 0.019693905487656593
# AVERAGE VAL LOSS: 0.059440165758132935
# #################
# # EPOCH 2092
# #################
# AVERAGE TRAIN LOSS: 0.021553421393036842
# AVERAGE VAL LOSS: 0.06136766076087952
# #################
# # EPOCH 2093
# #################
# AVERAGE TRAIN LOSS: 0.024003546684980392
# AVERAGE VAL LOSS: 0.07217558473348618
# #################
# # EPOCH 2094
# #################
# AVERAGE TRAIN LOSS: 0.021435627713799477
# AVERAGE VAL LOSS: 0.059135645627975464
# #################
# # EPOCH 2095
# #################
# AVERAGE TRAIN LOSS: 0.020204823464155197
# AVERAGE VAL LOSS: 0.058203428983688354
# #################
# # EPOCH 2096
# #################
# AVERAGE TRAIN LOSS: 0.020390141755342484
# AVERAGE VAL LOSS: 0.06216362863779068
# #################
# # EPOCH 2097
# #################
# AVERAGE TRAIN LOSS: 0.02077176608145237
# AVERAGE VAL LOSS: 0.058949023485183716
# #################
# # EPOCH 2098
# #################
# AVERAGE TRAIN LOSS: 0.02105247601866722
# AVERAGE VAL LOSS: 0.06334348022937775
# #################
# # EPOCH 2099
# #################
# AVERAGE TRAIN LOSS: 0.020325306802988052
# AVERAGE VAL LOSS: 0.05660592392086983
# #################
# # EPOCH 2100
# #################
# AVERAGE TRAIN LOSS: 0.020058732479810715
# AVERAGE VAL LOSS: 0.05958189442753792
# #################
# # EPOCH 2101
# #################
# AVERAGE TRAIN LOSS: 0.021733393892645836
# AVERAGE VAL LOSS: 0.06733735650777817
# #################
# # EPOCH 2102
# #################
# AVERAGE TRAIN LOSS: 0.01981288194656372
# AVERAGE VAL LOSS: 0.059995491057634354
# #################
# # EPOCH 2103
# #################
# AVERAGE TRAIN LOSS: 0.02246415987610817
# AVERAGE VAL LOSS: 0.058004043996334076
# #################
# # EPOCH 2104
# #################
# AVERAGE TRAIN LOSS: 0.01987891085445881
# AVERAGE VAL LOSS: 0.0655442625284195
# #################
# # EPOCH 2105
# #################
# AVERAGE TRAIN LOSS: 0.020771300420165062
# AVERAGE VAL LOSS: 0.06222018599510193
# #################
# # EPOCH 2106
# #################
# AVERAGE TRAIN LOSS: 0.02272702194750309
# AVERAGE VAL LOSS: 0.05587325245141983
# #################
# # EPOCH 2107
# #################
# AVERAGE TRAIN LOSS: 0.022362638264894485
# AVERAGE VAL LOSS: 0.06580983102321625
# #################
# # EPOCH 2108
# #################
# AVERAGE TRAIN LOSS: 0.020038126036524773
# AVERAGE VAL LOSS: 0.0591001883149147
# #################
# # EPOCH 2109
# #################
# AVERAGE TRAIN LOSS: 0.019469205290079117
# AVERAGE VAL LOSS: 0.059393204748630524
# #################
# # EPOCH 2110
# #################
# AVERAGE TRAIN LOSS: 0.01966833509504795
# AVERAGE VAL LOSS: 0.06175187975168228
# #################
# # EPOCH 2111
# #################
# AVERAGE TRAIN LOSS: 0.02021673694252968
# AVERAGE VAL LOSS: 0.05884973332285881
# #################
# # EPOCH 2112
# #################
# AVERAGE TRAIN LOSS: 0.01968355104327202
# AVERAGE VAL LOSS: 0.06273072212934494
# #################
# # EPOCH 2113
# #################
# AVERAGE TRAIN LOSS: 0.02254643104970455
# AVERAGE VAL LOSS: 0.07172049582004547
# #################
# # EPOCH 2114
# #################
# AVERAGE TRAIN LOSS: 0.022034792229533195
# AVERAGE VAL LOSS: 0.05881214141845703
# #################
# # EPOCH 2115
# #################
# AVERAGE TRAIN LOSS: 0.02007881924510002
# AVERAGE VAL LOSS: 0.061412960290908813
# #################
# # EPOCH 2116
# #################
# AVERAGE TRAIN LOSS: 0.0190432071685791
# AVERAGE VAL LOSS: 0.06448809802532196
# #################
# # EPOCH 2117
# #################
# AVERAGE TRAIN LOSS: 0.01970326155424118
# AVERAGE VAL LOSS: 0.06089223176240921
# #################
# # EPOCH 2118
# #################
# AVERAGE TRAIN LOSS: 0.021259326487779617
# AVERAGE VAL LOSS: 0.05848089978098869
# #################
# # EPOCH 2119
# #################
# AVERAGE TRAIN LOSS: 0.020901929587125778
# AVERAGE VAL LOSS: 0.06374479830265045
# #################
# # EPOCH 2120
# #################
# AVERAGE TRAIN LOSS: 0.022125715389847755
# AVERAGE VAL LOSS: 0.058783747255802155
# #################
# # EPOCH 2121
# #################
# AVERAGE TRAIN LOSS: 0.01942618563771248
# AVERAGE VAL LOSS: 0.06094653531908989
# #################
# # EPOCH 2122
# #################
# AVERAGE TRAIN LOSS: 0.02080206200480461
# AVERAGE VAL LOSS: 0.06909818947315216
# #################
# # EPOCH 2123
# #################
# AVERAGE TRAIN LOSS: 0.01945139281451702
# AVERAGE VAL LOSS: 0.0594305619597435
# #################
# # EPOCH 2124
# #################
# AVERAGE TRAIN LOSS: 0.01984204351902008
# AVERAGE VAL LOSS: 0.06050657480955124
# #################
# # EPOCH 2125
# #################
# AVERAGE TRAIN LOSS: 0.01910511776804924
# AVERAGE VAL LOSS: 0.061158012598752975
# #################
# # EPOCH 2126
# #################
# AVERAGE TRAIN LOSS: 0.020268581807613373
# AVERAGE VAL LOSS: 0.06477507948875427
# #################
# # EPOCH 2127
# #################
# AVERAGE TRAIN LOSS: 0.02043902687728405
# AVERAGE VAL LOSS: 0.05933399125933647
# #################
# # EPOCH 2128
# #################
# AVERAGE TRAIN LOSS: 0.02050277590751648
# AVERAGE VAL LOSS: 0.06365565955638885
# #################
# # EPOCH 2129
# #################
# AVERAGE TRAIN LOSS: 0.019070085138082504
# AVERAGE VAL LOSS: 0.06090039014816284
# #################
# # EPOCH 2130
# #################
# AVERAGE TRAIN LOSS: 0.02067457139492035
# AVERAGE VAL LOSS: 0.05650104954838753
# #################
# # EPOCH 2131
# #################
# AVERAGE TRAIN LOSS: 0.021273188292980194
# AVERAGE VAL LOSS: 0.0660460963845253
# #################
# # EPOCH 2132
# #################
# AVERAGE TRAIN LOSS: 0.020925432443618774
# AVERAGE VAL LOSS: 0.061164408922195435
# #################
# # EPOCH 2133
# #################
# AVERAGE TRAIN LOSS: 0.022702571004629135
# AVERAGE VAL LOSS: 0.05714055150747299
# #################
# # EPOCH 2134
# #################
# AVERAGE TRAIN LOSS: 0.018729347735643387
# AVERAGE VAL LOSS: 0.06357160955667496
# #################
# # EPOCH 2135
# #################
# AVERAGE TRAIN LOSS: 0.023134205490350723
# AVERAGE VAL LOSS: 0.07400114834308624
# #################
# # EPOCH 2136
# #################
# AVERAGE TRAIN LOSS: 0.019085753709077835
# AVERAGE VAL LOSS: 0.06019428372383118
# #################
# # EPOCH 2137
# #################
# AVERAGE TRAIN LOSS: 0.022120002657175064
# AVERAGE VAL LOSS: 0.058562785387039185
# #################
# # EPOCH 2138
# #################
# AVERAGE TRAIN LOSS: 0.021404847502708435
# AVERAGE VAL LOSS: 0.06738047301769257
# #################
# # EPOCH 2139
# #################
# AVERAGE TRAIN LOSS: 0.02042296901345253
# AVERAGE VAL LOSS: 0.05910562351346016
# #################
# # EPOCH 2140
# #################
# AVERAGE TRAIN LOSS: 0.020773809403181076
# AVERAGE VAL LOSS: 0.05864812061190605
# #################
# # EPOCH 2141
# #################
# AVERAGE TRAIN LOSS: 0.023149816319346428
# AVERAGE VAL LOSS: 0.07047341018915176
# #################
# # EPOCH 2142
# #################
# AVERAGE TRAIN LOSS: 0.019906286150217056
# AVERAGE VAL LOSS: 0.06221110373735428
# #################
# # EPOCH 2143
# #################
# AVERAGE TRAIN LOSS: 0.022530535236001015
# AVERAGE VAL LOSS: 0.05995500087738037
# #################
# # EPOCH 2144
# #################
# AVERAGE TRAIN LOSS: 0.022196631878614426
# AVERAGE VAL LOSS: 0.07139823585748672
# #################
# # EPOCH 2145
# #################
# AVERAGE TRAIN LOSS: 0.020560389384627342
# AVERAGE VAL LOSS: 0.06158372014760971
# #################
# # EPOCH 2146
# #################
# AVERAGE TRAIN LOSS: 0.02351403795182705
# AVERAGE VAL LOSS: 0.05636396259069443
# #################
# # EPOCH 2147
# #################
# AVERAGE TRAIN LOSS: 0.01977255381643772
# AVERAGE VAL LOSS: 0.06956310570240021
# #################
# # EPOCH 2148
# #################
# AVERAGE TRAIN LOSS: 0.02680937945842743
# AVERAGE VAL LOSS: 0.06920688599348068
# #################
# # EPOCH 2149
# #################
# AVERAGE TRAIN LOSS: 0.019406680017709732
# AVERAGE VAL LOSS: 0.061268359422683716
# #################
# # EPOCH 2150
# #################
# AVERAGE TRAIN LOSS: 0.02404073253273964
# AVERAGE VAL LOSS: 0.05901200696825981
# #################
# # EPOCH 2151
# #################
# AVERAGE TRAIN LOSS: 0.016460096463561058
# AVERAGE VAL LOSS: 0.0689101442694664
# #################
# # EPOCH 2152
# #################
# AVERAGE TRAIN LOSS: 0.025988250970840454
# AVERAGE VAL LOSS: 0.0692334771156311
# #################
# # EPOCH 2153
# #################
# AVERAGE TRAIN LOSS: 0.02904333546757698
# AVERAGE VAL LOSS: 0.05615432187914848
# #################
# # EPOCH 2154
# #################
# AVERAGE TRAIN LOSS: 0.020873015746474266
# AVERAGE VAL LOSS: 0.06493085622787476
# #################
# # EPOCH 2155
# #################
# AVERAGE TRAIN LOSS: 0.023394156247377396
# AVERAGE VAL LOSS: 0.07004867494106293
# #################
# # EPOCH 2156
# #################
# AVERAGE TRAIN LOSS: 0.02361445687711239
# AVERAGE VAL LOSS: 0.05782811716198921
# #################
# # EPOCH 2157
# #################
# AVERAGE TRAIN LOSS: 0.020277246832847595
# AVERAGE VAL LOSS: 0.060018859803676605
# #################
# # EPOCH 2158
# #################
# AVERAGE TRAIN LOSS: 0.021033387631177902
# AVERAGE VAL LOSS: 0.06609202921390533
# #################
# # EPOCH 2159
# #################
# AVERAGE TRAIN LOSS: 0.02185853384435177
# AVERAGE VAL LOSS: 0.0579715259373188
# #################
# # EPOCH 2160
# #################
# AVERAGE TRAIN LOSS: 0.019495243206620216
# AVERAGE VAL LOSS: 0.06027686595916748
# #################
# # EPOCH 2161
# #################
# AVERAGE TRAIN LOSS: 0.019536662846803665
# AVERAGE VAL LOSS: 0.06438611447811127
# #################
# # EPOCH 2162
# #################
# AVERAGE TRAIN LOSS: 0.018924787640571594
# AVERAGE VAL LOSS: 0.06001909822225571
# #################
# # EPOCH 2163
# #################
# AVERAGE TRAIN LOSS: 0.019489824771881104
# AVERAGE VAL LOSS: 0.06095234677195549
# #################
# # EPOCH 2164
# #################
# AVERAGE TRAIN LOSS: 0.0190853513777256
# AVERAGE VAL LOSS: 0.06222943216562271
# #################
# # EPOCH 2165
# #################
# AVERAGE TRAIN LOSS: 0.01973344385623932
# AVERAGE VAL LOSS: 0.06134865805506706
# #################
# # EPOCH 2166
# #################
# AVERAGE TRAIN LOSS: 0.02125164493918419
# AVERAGE VAL LOSS: 0.06651867926120758
# #################
# # EPOCH 2167
# #################
# AVERAGE TRAIN LOSS: 0.01973426714539528
# AVERAGE VAL LOSS: 0.057986050844192505
# #################
# # EPOCH 2168
# #################
# AVERAGE TRAIN LOSS: 0.02235354855656624
# AVERAGE VAL LOSS: 0.06139663606882095
# #################
# # EPOCH 2169
# #################
# AVERAGE TRAIN LOSS: 0.021934736520051956
# AVERAGE VAL LOSS: 0.06300821900367737
# #################
# # EPOCH 2170
# #################
# AVERAGE TRAIN LOSS: 0.018550816923379898
# AVERAGE VAL LOSS: 0.05944123864173889
# #################
# # EPOCH 2171
# #################
# AVERAGE TRAIN LOSS: 0.0244101844727993
# AVERAGE VAL LOSS: 0.05746228247880936
# #################
# # EPOCH 2172
# #################
# AVERAGE TRAIN LOSS: 0.020256727933883667
# AVERAGE VAL LOSS: 0.07072854787111282
# #################
# # EPOCH 2173
# #################
# AVERAGE TRAIN LOSS: 0.024763714522123337
# AVERAGE VAL LOSS: 0.06685728579759598
# #################
# # EPOCH 2174
# #################
# AVERAGE TRAIN LOSS: 0.018013665452599525
# AVERAGE VAL LOSS: 0.05729576200246811
# #################
# # EPOCH 2175
# #################
# AVERAGE TRAIN LOSS: 0.024374809116125107
# AVERAGE VAL LOSS: 0.058456480503082275
# #################
# # EPOCH 2176
# #################
# AVERAGE TRAIN LOSS: 0.0192113034427166
# AVERAGE VAL LOSS: 0.07013904303312302
# #################
# # EPOCH 2177
# #################
# AVERAGE TRAIN LOSS: 0.02206181362271309
# AVERAGE VAL LOSS: 0.06107502058148384
# #################
# # EPOCH 2178
# #################
# AVERAGE TRAIN LOSS: 0.018597474321722984
# AVERAGE VAL LOSS: 0.05712570995092392
# #################
# # EPOCH 2179
# #################
# AVERAGE TRAIN LOSS: 0.021212151274085045
# AVERAGE VAL LOSS: 0.0595775842666626
# #################
# # EPOCH 2180
# #################
# AVERAGE TRAIN LOSS: 0.020566528663039207
# AVERAGE VAL LOSS: 0.05828887224197388
# #################
# # EPOCH 2181
# #################
# AVERAGE TRAIN LOSS: 0.02463197521865368
# AVERAGE VAL LOSS: 0.0654292032122612
# #################
# # EPOCH 2182
# #################
# AVERAGE TRAIN LOSS: 0.02087346836924553
# AVERAGE VAL LOSS: 0.05934179946780205
# #################
# # EPOCH 2183
# #################
# AVERAGE TRAIN LOSS: 0.020901378244161606
# AVERAGE VAL LOSS: 0.0628989189863205
# #################
# # EPOCH 2184
# #################
# AVERAGE TRAIN LOSS: 0.01942867413163185
# AVERAGE VAL LOSS: 0.05989357829093933
# #################
# # EPOCH 2185
# #################
# AVERAGE TRAIN LOSS: 0.023920360952615738
# AVERAGE VAL LOSS: 0.05721928924322128
# #################
# # EPOCH 2186
# #################
# AVERAGE TRAIN LOSS: 0.019971352070569992
# AVERAGE VAL LOSS: 0.07077541202306747
# #################
# # EPOCH 2187
# #################
# AVERAGE TRAIN LOSS: 0.02190146967768669
# AVERAGE VAL LOSS: 0.060596615076065063
# #################
# # EPOCH 2188
# #################
# AVERAGE TRAIN LOSS: 0.020622164011001587
# AVERAGE VAL LOSS: 0.059046704322099686
# #################
# # EPOCH 2189
# #################
# AVERAGE TRAIN LOSS: 0.019684188067913055
# AVERAGE VAL LOSS: 0.06406635046005249
# #################
# # EPOCH 2190
# #################
# AVERAGE TRAIN LOSS: 0.019751721993088722
# AVERAGE VAL LOSS: 0.0633992999792099
# #################
# # EPOCH 2191
# #################
# AVERAGE TRAIN LOSS: 0.01932816207408905
# AVERAGE VAL LOSS: 0.05871572345495224
# #################
# # EPOCH 2192
# #################
# AVERAGE TRAIN LOSS: 0.021991252899169922
# AVERAGE VAL LOSS: 0.061330653727054596
# #################
# # EPOCH 2193
# #################
# AVERAGE TRAIN LOSS: 0.019379574805498123
# AVERAGE VAL LOSS: 0.059411101043224335
# #################
# # EPOCH 2194
# #################
# AVERAGE TRAIN LOSS: 0.019284311681985855
# AVERAGE VAL LOSS: 0.05704868584871292
# #################
# # EPOCH 2195
# #################
# AVERAGE TRAIN LOSS: 0.026655545458197594
# AVERAGE VAL LOSS: 0.06659764796495438
# #################
# # EPOCH 2196
# #################
# AVERAGE TRAIN LOSS: 0.018898796290159225
# AVERAGE VAL LOSS: 0.05738907307386398
# #################
# # EPOCH 2197
# #################
# AVERAGE TRAIN LOSS: 0.023090669885277748
# AVERAGE VAL LOSS: 0.057913921773433685
# #################
# # EPOCH 2198
# #################
# AVERAGE TRAIN LOSS: 0.019663158804178238
# AVERAGE VAL LOSS: 0.06947844475507736
# #################
# # EPOCH 2199
# #################
# AVERAGE TRAIN LOSS: 0.024341050535440445
# AVERAGE VAL LOSS: 0.0596315972507
# #################
# # EPOCH 2200
# #################
# AVERAGE TRAIN LOSS: 0.019264094531536102
# AVERAGE VAL LOSS: 0.06271551549434662
# #################
# # EPOCH 2201
# #################
# AVERAGE TRAIN LOSS: 0.020475191995501518
# AVERAGE VAL LOSS: 0.06273386627435684
# #################
# # EPOCH 2202
# #################
# AVERAGE TRAIN LOSS: 0.01937972381711006
# AVERAGE VAL LOSS: 0.057368434965610504
# #################
# # EPOCH 2203
# #################
# AVERAGE TRAIN LOSS: 0.019966179504990578
# AVERAGE VAL LOSS: 0.06045365333557129
# #################
# # EPOCH 2204
# #################
# AVERAGE TRAIN LOSS: 0.0198315791785717
# AVERAGE VAL LOSS: 0.06488467752933502
# #################
# # EPOCH 2205
# #################
# AVERAGE TRAIN LOSS: 0.020298469811677933
# AVERAGE VAL LOSS: 0.05803670734167099
# #################
# # EPOCH 2206
# #################
# AVERAGE TRAIN LOSS: 0.020032456144690514
# AVERAGE VAL LOSS: 0.06128904968500137
# #################
# # EPOCH 2207
# #################
# AVERAGE TRAIN LOSS: 0.020467936992645264
# AVERAGE VAL LOSS: 0.06329570710659027
# #################
# # EPOCH 2208
# #################
# AVERAGE TRAIN LOSS: 0.018792178481817245
# AVERAGE VAL LOSS: 0.06093624234199524
# #################
# # EPOCH 2209
# #################
# AVERAGE TRAIN LOSS: 0.019915569573640823
# AVERAGE VAL LOSS: 0.05881354957818985
# #################
# # EPOCH 2210
# #################
# AVERAGE TRAIN LOSS: 0.019242169335484505
# AVERAGE VAL LOSS: 0.06305885314941406
# #################
# # EPOCH 2211
# #################
# AVERAGE TRAIN LOSS: 0.019864819943904877
# AVERAGE VAL LOSS: 0.06424770504236221
# #################
# # EPOCH 2212
# #################
# AVERAGE TRAIN LOSS: 0.021321825683116913
# AVERAGE VAL LOSS: 0.05807352811098099
# #################
# # EPOCH 2213
# #################
# AVERAGE TRAIN LOSS: 0.019509784877300262
# AVERAGE VAL LOSS: 0.06161918118596077
# #################
# # EPOCH 2214
# #################
# AVERAGE TRAIN LOSS: 0.020913701504468918
# AVERAGE VAL LOSS: 0.06126317381858826
# #################
# # EPOCH 2215
# #################
# AVERAGE TRAIN LOSS: 0.019691428169608116
# AVERAGE VAL LOSS: 0.06344664096832275
# #################
# # EPOCH 2216
# #################
# AVERAGE TRAIN LOSS: 0.019681960344314575
# AVERAGE VAL LOSS: 0.05982968956232071
# #################
# # EPOCH 2217
# #################
# AVERAGE TRAIN LOSS: 0.01987237110733986
# AVERAGE VAL LOSS: 0.05710924416780472
# #################
# # EPOCH 2218
# #################
# AVERAGE TRAIN LOSS: 0.02011934295296669
# AVERAGE VAL LOSS: 0.05917041748762131
# #################
# # EPOCH 2219
# #################
# AVERAGE TRAIN LOSS: 0.02054779604077339
# AVERAGE VAL LOSS: 0.06307362765073776
# #################
# # EPOCH 2220
# #################
# AVERAGE TRAIN LOSS: 0.01956930384039879
# AVERAGE VAL LOSS: 0.06242077797651291
# #################
# # EPOCH 2221
# #################
# AVERAGE TRAIN LOSS: 0.0213609728962183
# AVERAGE VAL LOSS: 0.0578850582242012
# #################
# # EPOCH 2222
# #################
# AVERAGE TRAIN LOSS: 0.019284838810563087
# AVERAGE VAL LOSS: 0.06486374884843826
# #################
# # EPOCH 2223
# #################
# AVERAGE TRAIN LOSS: 0.021028753370046616
# AVERAGE VAL LOSS: 0.0639558732509613
# #################
# # EPOCH 2224
# #################
# AVERAGE TRAIN LOSS: 0.018871640786528587
# AVERAGE VAL LOSS: 0.0582367368042469
# #################
# # EPOCH 2225
# #################
# AVERAGE TRAIN LOSS: 0.02088635228574276
# AVERAGE VAL LOSS: 0.05876029655337334
# #################
# # EPOCH 2226
# #################
# AVERAGE TRAIN LOSS: 0.022305918857455254
# AVERAGE VAL LOSS: 0.0675126388669014
# #################
# # EPOCH 2227
# #################
# AVERAGE TRAIN LOSS: 0.02292291447520256
# AVERAGE VAL LOSS: 0.059211187064647675
# #################
# # EPOCH 2228
# #################
# AVERAGE TRAIN LOSS: 0.019316647201776505
# AVERAGE VAL LOSS: 0.06257093697786331
# #################
# # EPOCH 2229
# #################
# AVERAGE TRAIN LOSS: 0.01971455290913582
# AVERAGE VAL LOSS: 0.06343842297792435
# #################
# # EPOCH 2230
# #################
# AVERAGE TRAIN LOSS: 0.019541773945093155
# AVERAGE VAL LOSS: 0.058925509452819824
# #################
# # EPOCH 2231
# #################
# AVERAGE TRAIN LOSS: 0.020432623103260994
# AVERAGE VAL LOSS: 0.05778466537594795
# #################
# # EPOCH 2232
# #################
# AVERAGE TRAIN LOSS: 0.018650595098733902
# AVERAGE VAL LOSS: 0.06308632344007492
# #################
# # EPOCH 2233
# #################
# AVERAGE TRAIN LOSS: 0.02153376117348671
# AVERAGE VAL LOSS: 0.06187231466174126
# #################
# # EPOCH 2234
# #################
# AVERAGE TRAIN LOSS: 0.022006962448358536
# AVERAGE VAL LOSS: 0.06847815960645676
# #################
# # EPOCH 2235
# #################
# AVERAGE TRAIN LOSS: 0.025422299280762672
# AVERAGE VAL LOSS: 0.0586201436817646
# #################
# # EPOCH 2236
# #################
# AVERAGE TRAIN LOSS: 0.019270354881882668
# AVERAGE VAL LOSS: 0.06243063136935234
# #################
# # EPOCH 2237
# #################
# AVERAGE TRAIN LOSS: 0.021834248676896095
# AVERAGE VAL LOSS: 0.06941556185483932
# #################
# # EPOCH 2238
# #################
# AVERAGE TRAIN LOSS: 0.019315650686621666
# AVERAGE VAL LOSS: 0.05936160683631897
# #################
# # EPOCH 2239
# #################
# AVERAGE TRAIN LOSS: 0.020953280851244926
# AVERAGE VAL LOSS: 0.05838705226778984
# #################
# # EPOCH 2240
# #################
# AVERAGE TRAIN LOSS: 0.018435118719935417
# AVERAGE VAL LOSS: 0.06407772749662399
# #################
# # EPOCH 2241
# #################
# AVERAGE TRAIN LOSS: 0.023549288511276245
# AVERAGE VAL LOSS: 0.06807706505060196
# #################
# # EPOCH 2242
# #################
# AVERAGE TRAIN LOSS: 0.01821635104715824
# AVERAGE VAL LOSS: 0.057497549802064896
# #################
# # EPOCH 2243
# #################
# AVERAGE TRAIN LOSS: 0.022095289081335068
# AVERAGE VAL LOSS: 0.058820903301239014
# #################
# # EPOCH 2244
# #################
# AVERAGE TRAIN LOSS: 0.025647198781371117
# AVERAGE VAL LOSS: 0.0694485753774643
# #################
# # EPOCH 2245
# #################
# AVERAGE TRAIN LOSS: 0.01819026656448841
# AVERAGE VAL LOSS: 0.0581313893198967
# #################
# # EPOCH 2246
# #################
# AVERAGE TRAIN LOSS: 0.022264685481786728
# AVERAGE VAL LOSS: 0.057039301842451096
# #################
# # EPOCH 2247
# #################
# AVERAGE TRAIN LOSS: 0.022153228521347046
# AVERAGE VAL LOSS: 0.06610596179962158
# #################
# # EPOCH 2248
# #################
# AVERAGE TRAIN LOSS: 0.02020249143242836
# AVERAGE VAL LOSS: 0.06032450124621391
# #################
# # EPOCH 2249
# #################
# AVERAGE TRAIN LOSS: 0.019372694194316864
# AVERAGE VAL LOSS: 0.06021379679441452
# #################
# # EPOCH 2250
# #################
# AVERAGE TRAIN LOSS: 0.020490510389208794
# AVERAGE VAL LOSS: 0.05685853213071823
# #################
# # EPOCH 2251
# #################
# AVERAGE TRAIN LOSS: 0.020339485257864
# AVERAGE VAL LOSS: 0.06332133710384369
# #################
# # EPOCH 2252
# #################
# AVERAGE TRAIN LOSS: 0.01940218359231949
# AVERAGE VAL LOSS: 0.064999520778656
# #################
# # EPOCH 2253
# #################
# AVERAGE TRAIN LOSS: 0.020643139258027077
# AVERAGE VAL LOSS: 0.05865786224603653
# #################
# # EPOCH 2254
# #################
# AVERAGE TRAIN LOSS: 0.018953919410705566
# AVERAGE VAL LOSS: 0.06293369829654694
# #################
# # EPOCH 2255
# #################
# AVERAGE TRAIN LOSS: 0.021022295579314232
# AVERAGE VAL LOSS: 0.06405763328075409
# #################
# # EPOCH 2256
# #################
# AVERAGE TRAIN LOSS: 0.021538233384490013
# AVERAGE VAL LOSS: 0.057647593319416046
# #################
# # EPOCH 2257
# #################
# AVERAGE TRAIN LOSS: 0.020052533596754074
# AVERAGE VAL LOSS: 0.06262578815221786
# #################
# # EPOCH 2258
# #################
# AVERAGE TRAIN LOSS: 0.0198972225189209
# AVERAGE VAL LOSS: 0.061231665313243866
# #################
# # EPOCH 2259
# #################
# AVERAGE TRAIN LOSS: 0.022188615053892136
# AVERAGE VAL LOSS: 0.05853930115699768
# #################
# # EPOCH 2260
# #################
# AVERAGE TRAIN LOSS: 0.02012970857322216
# AVERAGE VAL LOSS: 0.06549496948719025
# #################
# # EPOCH 2261
# #################
# AVERAGE TRAIN LOSS: 0.01971154287457466
# AVERAGE VAL LOSS: 0.0628165677189827
# #################
# # EPOCH 2262
# #################
# AVERAGE TRAIN LOSS: 0.02110983058810234
# AVERAGE VAL LOSS: 0.060468584299087524
# #################
# # EPOCH 2263
# #################
# AVERAGE TRAIN LOSS: 0.019161056727170944
# AVERAGE VAL LOSS: 0.06113823130726814
# #################
# # EPOCH 2264
# #################
# AVERAGE TRAIN LOSS: 0.02538158930838108
# AVERAGE VAL LOSS: 0.06672133505344391
# #################
# # EPOCH 2265
# #################
# AVERAGE TRAIN LOSS: 0.023169871419668198
# AVERAGE VAL LOSS: 0.055031903088092804
# #################
# # EPOCH 2266
# #################
# AVERAGE TRAIN LOSS: 0.021495141088962555
# AVERAGE VAL LOSS: 0.061852794140577316
# #################
# # EPOCH 2267
# #################
# AVERAGE TRAIN LOSS: 0.02033846639096737
# AVERAGE VAL LOSS: 0.06150022894144058
# #################
# # EPOCH 2268
# #################
# AVERAGE TRAIN LOSS: 0.019098596647381783
# AVERAGE VAL LOSS: 0.0642133504152298
# #################
# # EPOCH 2269
# #################
# AVERAGE TRAIN LOSS: 0.022549699991941452
# AVERAGE VAL LOSS: 0.06650681793689728
# #################
# # EPOCH 2270
# #################
# AVERAGE TRAIN LOSS: 0.01836354471743107
# AVERAGE VAL LOSS: 0.06088683754205704
# #################
# # EPOCH 2271
# #################
# AVERAGE TRAIN LOSS: 0.019862452521920204
# AVERAGE VAL LOSS: 0.059555016458034515
# #################
# # EPOCH 2272
# #################
# AVERAGE TRAIN LOSS: 0.018969610333442688
# AVERAGE VAL LOSS: 0.0623035654425621
# #################
# # EPOCH 2273
# #################
# AVERAGE TRAIN LOSS: 0.01993555761873722
# AVERAGE VAL LOSS: 0.06257843971252441
# #################
# # EPOCH 2274
# #################
# AVERAGE TRAIN LOSS: 0.0212046317756176
# AVERAGE VAL LOSS: 0.05751547962427139
# #################
# # EPOCH 2275
# #################
# AVERAGE TRAIN LOSS: 0.020145945250988007
# AVERAGE VAL LOSS: 0.05943375825881958
# #################
# # EPOCH 2276
# #################
# AVERAGE TRAIN LOSS: 0.021616701036691666
# AVERAGE VAL LOSS: 0.07164496183395386
# #################
# # EPOCH 2277
# #################
# AVERAGE TRAIN LOSS: 0.01972128078341484
# AVERAGE VAL LOSS: 0.06118546053767204
# #################
# # EPOCH 2278
# #################
# AVERAGE TRAIN LOSS: 0.023271000012755394
# AVERAGE VAL LOSS: 0.06128566712141037
# #################
# # EPOCH 2279
# #################
# AVERAGE TRAIN LOSS: 0.01985992304980755
# AVERAGE VAL LOSS: 0.07060656696557999
# #################
# # EPOCH 2280
# #################
# AVERAGE TRAIN LOSS: 0.026094000786542892
# AVERAGE VAL LOSS: 0.06937377154827118
# #################
# # EPOCH 2281
# #################
# AVERAGE TRAIN LOSS: 0.022895697504281998
# AVERAGE VAL LOSS: 0.05618808791041374
# #################
# # EPOCH 2282
# #################
# AVERAGE TRAIN LOSS: 0.02277337573468685
# AVERAGE VAL LOSS: 0.06458506733179092
# #################
# # EPOCH 2283
# #################
# AVERAGE TRAIN LOSS: 0.01977258175611496
# AVERAGE VAL LOSS: 0.06378144025802612
# #################
# # EPOCH 2284
# #################
# AVERAGE TRAIN LOSS: 0.02033849246799946
# AVERAGE VAL LOSS: 0.057499635964632034
# #################
# # EPOCH 2285
# #################
# AVERAGE TRAIN LOSS: 0.020921530202031136
# AVERAGE VAL LOSS: 0.06274338066577911
# #################
# # EPOCH 2286
# #################
# AVERAGE TRAIN LOSS: 0.01975211687386036
# AVERAGE VAL LOSS: 0.0634486973285675
# #################
# # EPOCH 2287
# #################
# AVERAGE TRAIN LOSS: 0.018578864634037018
# AVERAGE VAL LOSS: 0.06003540754318237
# #################
# # EPOCH 2288
# #################
# AVERAGE TRAIN LOSS: 0.0199027918279171
# AVERAGE VAL LOSS: 0.0594196692109108
# #################
# # EPOCH 2289
# #################
# AVERAGE TRAIN LOSS: 0.019541526213288307
# AVERAGE VAL LOSS: 0.06377540528774261
# #################
# # EPOCH 2290
# #################
# AVERAGE TRAIN LOSS: 0.01980523392558098
# AVERAGE VAL LOSS: 0.060234926640987396
# #################
# # EPOCH 2291
# #################
# AVERAGE TRAIN LOSS: 0.01978886127471924
# AVERAGE VAL LOSS: 0.060302846133708954
# #################
# # EPOCH 2292
# #################
# AVERAGE TRAIN LOSS: 0.018962541595101357
# AVERAGE VAL LOSS: 0.05837111547589302
# #################
# # EPOCH 2293
# #################
# AVERAGE TRAIN LOSS: 0.019932564347982407
# AVERAGE VAL LOSS: 0.06057558208703995
# #################
# # EPOCH 2294
# #################
# AVERAGE TRAIN LOSS: 0.0189379770308733
# AVERAGE VAL LOSS: 0.06427332013845444
# #################
# # EPOCH 2295
# #################
# AVERAGE TRAIN LOSS: 0.01953871361911297
# AVERAGE VAL LOSS: 0.06322138011455536
# #################
# # EPOCH 2296
# #################
# AVERAGE TRAIN LOSS: 0.019842153415083885
# AVERAGE VAL LOSS: 0.05884870886802673
# #################
# # EPOCH 2297
# #################
# AVERAGE TRAIN LOSS: 0.019409304484725
# AVERAGE VAL LOSS: 0.05836568400263786
# #################
# # EPOCH 2298
# #################
# AVERAGE TRAIN LOSS: 0.01967422477900982
# AVERAGE VAL LOSS: 0.06254687160253525
# #################
# # EPOCH 2299
# #################
# AVERAGE TRAIN LOSS: 0.019241318106651306
# AVERAGE VAL LOSS: 0.06397351622581482
# #################
# # EPOCH 2300
# #################
# AVERAGE TRAIN LOSS: 0.01921284943819046
# AVERAGE VAL LOSS: 0.06127435714006424
# #################
# # EPOCH 2301
# #################
# AVERAGE TRAIN LOSS: 0.02014916017651558
# AVERAGE VAL LOSS: 0.06065420061349869
# #################
# # EPOCH 2302
# #################
# AVERAGE TRAIN LOSS: 0.019816065207123756
# AVERAGE VAL LOSS: 0.06303471326828003
# #################
# # EPOCH 2303
# #################
# AVERAGE TRAIN LOSS: 0.021936917677521706
# AVERAGE VAL LOSS: 0.06386388838291168
# #################
# # EPOCH 2304
# #################
# AVERAGE TRAIN LOSS: 0.022509586066007614
# AVERAGE VAL LOSS: 0.05616002529859543
# #################
# # EPOCH 2305
# #################
# AVERAGE TRAIN LOSS: 0.01944679580628872
# AVERAGE VAL LOSS: 0.06268437206745148
# #################
# # EPOCH 2306
# #################
# AVERAGE TRAIN LOSS: 0.023560458794236183
# AVERAGE VAL LOSS: 0.06974132359027863
# #################
# # EPOCH 2307
# #################
# AVERAGE TRAIN LOSS: 0.019006483256816864
# AVERAGE VAL LOSS: 0.05735474079847336
# #################
# # EPOCH 2308
# #################
# AVERAGE TRAIN LOSS: 0.02286963164806366
# AVERAGE VAL LOSS: 0.05996980518102646
# #################
# # EPOCH 2309
# #################
# AVERAGE TRAIN LOSS: 0.01920129917562008
# AVERAGE VAL LOSS: 0.06551334261894226
# #################
# # EPOCH 2310
# #################
# AVERAGE TRAIN LOSS: 0.020222466439008713
# AVERAGE VAL LOSS: 0.061420995742082596
# #################
# # EPOCH 2311
# #################
# AVERAGE TRAIN LOSS: 0.01978393830358982
# AVERAGE VAL LOSS: 0.057851534336805344
# #################
# # EPOCH 2312
# #################
# AVERAGE TRAIN LOSS: 0.020567892119288445
# AVERAGE VAL LOSS: 0.0606042854487896
# #################
# # EPOCH 2313
# #################
# AVERAGE TRAIN LOSS: 0.01873783767223358
# AVERAGE VAL LOSS: 0.06666406244039536
# #################
# # EPOCH 2314
# #################
# AVERAGE TRAIN LOSS: 0.02181924320757389
# AVERAGE VAL LOSS: 0.06257552653551102
# #################
# # EPOCH 2315
# #################
# AVERAGE TRAIN LOSS: 0.020292887464165688
# AVERAGE VAL LOSS: 0.06011822074651718
# #################
# # EPOCH 2316
# #################
# AVERAGE TRAIN LOSS: 0.022683855146169662
# AVERAGE VAL LOSS: 0.05798163264989853
# #################
# # EPOCH 2317
# #################
# AVERAGE TRAIN LOSS: 0.021390782669186592
# AVERAGE VAL LOSS: 0.06449384987354279
# #################
# # EPOCH 2318
# #################
# AVERAGE TRAIN LOSS: 0.02129952423274517
# AVERAGE VAL LOSS: 0.06148576736450195
# #################
# # EPOCH 2319
# #################
# AVERAGE TRAIN LOSS: 0.018714968115091324
# AVERAGE VAL LOSS: 0.059607040137052536
# #################
# # EPOCH 2320
# #################
# AVERAGE TRAIN LOSS: 0.019390031695365906
# AVERAGE VAL LOSS: 0.060116399079561234
# #################
# # EPOCH 2321
# #################
# AVERAGE TRAIN LOSS: 0.02034042961895466
# AVERAGE VAL LOSS: 0.06290732324123383
# #################
# # EPOCH 2322
# #################
# AVERAGE TRAIN LOSS: 0.020271217450499535
# AVERAGE VAL LOSS: 0.06192546337842941
# #################
# # EPOCH 2323
# #################
# AVERAGE TRAIN LOSS: 0.01993390917778015
# AVERAGE VAL LOSS: 0.06341059505939484
# #################
# # EPOCH 2324
# #################
# AVERAGE TRAIN LOSS: 0.020745323970913887
# AVERAGE VAL LOSS: 0.057884931564331055
# #################
# # EPOCH 2325
# #################
# AVERAGE TRAIN LOSS: 0.019675711169838905
# AVERAGE VAL LOSS: 0.05997813865542412
# #################
# # EPOCH 2326
# #################
# AVERAGE TRAIN LOSS: 0.020007098093628883
# AVERAGE VAL LOSS: 0.06384435296058655
# #################
# # EPOCH 2327
# #################
# AVERAGE TRAIN LOSS: 0.018684182316064835
# AVERAGE VAL LOSS: 0.059799812734127045
# #################
# # EPOCH 2328
# #################
# AVERAGE TRAIN LOSS: 0.020639125257730484
# AVERAGE VAL LOSS: 0.061723362654447556
# #################
# # EPOCH 2329
# #################
# AVERAGE TRAIN LOSS: 0.021016743034124374
# AVERAGE VAL LOSS: 0.06637116521596909
# #################
# # EPOCH 2330
# #################
# AVERAGE TRAIN LOSS: 0.019718235358595848
# AVERAGE VAL LOSS: 0.05897730588912964
# #################
# # EPOCH 2331
# #################
# AVERAGE TRAIN LOSS: 0.019866054877638817
# AVERAGE VAL LOSS: 0.061608731746673584
# #################
# # EPOCH 2332
# #################
# AVERAGE TRAIN LOSS: 0.02011708915233612
# AVERAGE VAL LOSS: 0.05986221507191658
# #################
# # EPOCH 2333
# #################
# AVERAGE TRAIN LOSS: 0.019119776785373688
# AVERAGE VAL LOSS: 0.06337620317935944
# #################
# # EPOCH 2334
# #################
# AVERAGE TRAIN LOSS: 0.0195961594581604
# AVERAGE VAL LOSS: 0.06337680667638779
# #################
# # EPOCH 2335
# #################
# AVERAGE TRAIN LOSS: 0.018917551264166832
# AVERAGE VAL LOSS: 0.06164699047803879
# #################
# # EPOCH 2336
# #################
# AVERAGE TRAIN LOSS: 0.021824579685926437
# AVERAGE VAL LOSS: 0.057734619826078415
# #################
# # EPOCH 2337
# #################
# AVERAGE TRAIN LOSS: 0.02558772638440132
# AVERAGE VAL LOSS: 0.07219602912664413
# #################
# # EPOCH 2338
# #################
# AVERAGE TRAIN LOSS: 0.022333718836307526
# AVERAGE VAL LOSS: 0.058588068932294846
# #################
# # EPOCH 2339
# #################
# AVERAGE TRAIN LOSS: 0.021056193858385086
# AVERAGE VAL LOSS: 0.059224434196949005
# #################
# # EPOCH 2340
# #################
# AVERAGE TRAIN LOSS: 0.019380856305360794
# AVERAGE VAL LOSS: 0.06380748003721237
# #################
# # EPOCH 2341
# #################
# AVERAGE TRAIN LOSS: 0.019297361373901367
# AVERAGE VAL LOSS: 0.06141267344355583
# #################
# # EPOCH 2342
# #################
# AVERAGE TRAIN LOSS: 0.01919296383857727
# AVERAGE VAL LOSS: 0.05925885587930679
# #################
# # EPOCH 2343
# #################
# AVERAGE TRAIN LOSS: 0.021155381575226784
# AVERAGE VAL LOSS: 0.05936651676893234
# #################
# # EPOCH 2344
# #################
# AVERAGE TRAIN LOSS: 0.02140401303768158
# AVERAGE VAL LOSS: 0.07065584510564804
# #################
# # EPOCH 2345
# #################
# AVERAGE TRAIN LOSS: 0.02066463604569435
# AVERAGE VAL LOSS: 0.06161561608314514
# #################
# # EPOCH 2346
# #################
# AVERAGE TRAIN LOSS: 0.01998697593808174
# AVERAGE VAL LOSS: 0.05850570648908615
# #################
# # EPOCH 2347
# #################
# AVERAGE TRAIN LOSS: 0.021190430968999863
# AVERAGE VAL LOSS: 0.06419073790311813
# #################
# # EPOCH 2348
# #################
# AVERAGE TRAIN LOSS: 0.01998232677578926
# AVERAGE VAL LOSS: 0.06122218817472458
# #################
# # EPOCH 2349
# #################
# AVERAGE TRAIN LOSS: 0.019965657964348793
# AVERAGE VAL LOSS: 0.057999491691589355
# #################
# # EPOCH 2350
# #################
# AVERAGE TRAIN LOSS: 0.019100382924079895
# AVERAGE VAL LOSS: 0.06075706332921982
# #################
# # EPOCH 2351
# #################
# AVERAGE TRAIN LOSS: 0.018941879272460938
# AVERAGE VAL LOSS: 0.06171413138508797
# #################
# # EPOCH 2352
# #################
# AVERAGE TRAIN LOSS: 0.019255895167589188
# AVERAGE VAL LOSS: 0.06043366715312004
# #################
# # EPOCH 2353
# #################
# AVERAGE TRAIN LOSS: 0.019110333174467087
# AVERAGE VAL LOSS: 0.06031394749879837
# #################
# # EPOCH 2354
# #################
# AVERAGE TRAIN LOSS: 0.02045045793056488
# AVERAGE VAL LOSS: 0.06329195946455002
# #################
# # EPOCH 2355
# #################
# AVERAGE TRAIN LOSS: 0.02146775647997856
# AVERAGE VAL LOSS: 0.06022004038095474
# #################
# # EPOCH 2356
# #################
# AVERAGE TRAIN LOSS: 0.019747845828533173
# AVERAGE VAL LOSS: 0.06455553323030472
# #################
# # EPOCH 2357
# #################
# AVERAGE TRAIN LOSS: 0.019524533301591873
# AVERAGE VAL LOSS: 0.06069578975439072
# #################
# # EPOCH 2358
# #################
# AVERAGE TRAIN LOSS: 0.020067987963557243
# AVERAGE VAL LOSS: 0.058359067887067795
# #################
# # EPOCH 2359
# #################
# AVERAGE TRAIN LOSS: 0.019571412354707718
# AVERAGE VAL LOSS: 0.059747226536273956
# #################
# # EPOCH 2360
# #################
# AVERAGE TRAIN LOSS: 0.019459862262010574
# AVERAGE VAL LOSS: 0.06352441012859344
# #################
# # EPOCH 2361
# #################
# AVERAGE TRAIN LOSS: 0.0206508319824934
# AVERAGE VAL LOSS: 0.059074245393276215
# #################
# # EPOCH 2362
# #################
# AVERAGE TRAIN LOSS: 0.020220795646309853
# AVERAGE VAL LOSS: 0.06373269110918045
# #################
# # EPOCH 2363
# #################
# AVERAGE TRAIN LOSS: 0.020515479147434235
# AVERAGE VAL LOSS: 0.05883758142590523
# #################
# # EPOCH 2364
# #################
# AVERAGE TRAIN LOSS: 0.020769447088241577
# AVERAGE VAL LOSS: 0.05868201702833176
# #################
# # EPOCH 2365
# #################
# AVERAGE TRAIN LOSS: 0.018758054822683334
# AVERAGE VAL LOSS: 0.06494162231683731
# #################
# # EPOCH 2366
# #################
# AVERAGE TRAIN LOSS: 0.01936751790344715
# AVERAGE VAL LOSS: 0.06375843286514282
# #################
# # EPOCH 2367
# #################
# AVERAGE TRAIN LOSS: 0.020252052694559097
# AVERAGE VAL LOSS: 0.06115608289837837
# #################
# # EPOCH 2368
# #################
# AVERAGE TRAIN LOSS: 0.019209012389183044
# AVERAGE VAL LOSS: 0.058136772364377975
# #################
# # EPOCH 2369
# #################
# AVERAGE TRAIN LOSS: 0.019487779587507248
# AVERAGE VAL LOSS: 0.06070571020245552
# #################
# # EPOCH 2370
# #################
# AVERAGE TRAIN LOSS: 0.01924501173198223
# AVERAGE VAL LOSS: 0.0666741132736206
# #################
# # EPOCH 2371
# #################
# AVERAGE TRAIN LOSS: 0.021183112636208534
# AVERAGE VAL LOSS: 0.05959656089544296
# #################
# # EPOCH 2372
# #################
# AVERAGE TRAIN LOSS: 0.019477343186736107
# AVERAGE VAL LOSS: 0.06214805692434311
# #################
# # EPOCH 2373
# #################
# AVERAGE TRAIN LOSS: 0.021162129938602448
# AVERAGE VAL LOSS: 0.05995761603116989
# #################
# # EPOCH 2374
# #################
# AVERAGE TRAIN LOSS: 0.0198565311729908
# AVERAGE VAL LOSS: 0.0583137571811676
# #################
# # EPOCH 2375
# #################
# ...
# #################
# # EPOCH 2875
# #################
# AVERAGE TRAIN LOSS: 0.01926395297050476
# AVERAGE VAL LOSS: 0.0595843680202961
# #################
# # EPOCH 2876
# #################
# AVERAGE TRAIN LOSS: 0.01954766735434532
# AVERAGE VAL LOSS: 0.06195632740855217
# #################
# # EPOCH 2877
# #################
# AVERAGE TRAIN LOSS: 0.01899769902229309
# AVERAGE VAL LOSS: 0.06054925173521042
# #################
# # EPOCH 2878
# #################
# AVERAGE TRAIN LOSS: 0.023560304194688797
# AVERAGE VAL LOSS: 0.05826316401362419
# #################
# # EPOCH 2879
# #################
# AVERAGE TRAIN LOSS: 0.021418806165456772
# AVERAGE VAL LOSS: 0.067954421043396
# #################
# # EPOCH 2880
# #################
# AVERAGE TRAIN LOSS: 0.01986883208155632
# AVERAGE VAL LOSS: 0.06304269284009933
# #################
# # EPOCH 2881
# #################
# AVERAGE TRAIN LOSS: 0.020366502925753593
# AVERAGE VAL LOSS: 0.05880014970898628
# #################
# # EPOCH 2882
# #################
# AVERAGE TRAIN LOSS: 0.02051404118537903
# AVERAGE VAL LOSS: 0.060049496591091156
# #################
# # EPOCH 2883
# #################
# AVERAGE TRAIN LOSS: 0.01811896823346615
# AVERAGE VAL LOSS: 0.06730355322360992
# #################
# # EPOCH 2884
# #################
# AVERAGE TRAIN LOSS: 0.022800492122769356
# AVERAGE VAL LOSS: 0.0657736212015152
# #################
# # EPOCH 2885
# #################
# AVERAGE TRAIN LOSS: 0.019110089167952538
# AVERAGE VAL LOSS: 0.057120513170957565
# #################
# # EPOCH 2886
# #################
# AVERAGE TRAIN LOSS: 0.021225934848189354
# AVERAGE VAL LOSS: 0.06060562655329704
# #################
# # EPOCH 2887
# #################
# AVERAGE TRAIN LOSS: 0.018940769135951996
# AVERAGE VAL LOSS: 0.06138945370912552
# #################
# # EPOCH 2888
# #################
# AVERAGE TRAIN LOSS: 0.01911855861544609
# AVERAGE VAL LOSS: 0.06306000798940659
# #################
# # EPOCH 2889
# #################
# AVERAGE TRAIN LOSS: 0.020340580493211746
# AVERAGE VAL LOSS: 0.06399241089820862
# #################
# # EPOCH 2890
# #################
# AVERAGE TRAIN LOSS: 0.025575783103704453
# AVERAGE VAL LOSS: 0.056457437574863434
# #################
# # EPOCH 2891
# #################
# AVERAGE TRAIN LOSS: 0.022002285346388817
# AVERAGE VAL LOSS: 0.06597388535737991
# #################
# # EPOCH 2892
# #################
# AVERAGE TRAIN LOSS: 0.02136426791548729
# AVERAGE VAL LOSS: 0.06398999691009521
# #################
# # EPOCH 2893
# #################
# AVERAGE TRAIN LOSS: 0.02070334181189537
# AVERAGE VAL LOSS: 0.057538606226444244
# #################
# # EPOCH 2894
# #################
# AVERAGE TRAIN LOSS: 0.020515870302915573
# AVERAGE VAL LOSS: 0.05722005292773247
# #################
# # EPOCH 2895
# #################
# AVERAGE TRAIN LOSS: 0.018163364380598068
# AVERAGE VAL LOSS: 0.06266389787197113
# #################
# # EPOCH 2896
# #################
# AVERAGE TRAIN LOSS: 0.019446495920419693
# AVERAGE VAL LOSS: 0.06533049046993256
# #################
# # EPOCH 2897
# #################
# AVERAGE TRAIN LOSS: 0.021156229078769684
# AVERAGE VAL LOSS: 0.058249372988939285
# #################
# # EPOCH 2898
# #################
# AVERAGE TRAIN LOSS: 0.021043961867690086
# AVERAGE VAL LOSS: 0.05959324166178703
# #################
# # EPOCH 2899
# #################
# AVERAGE TRAIN LOSS: 0.019619425758719444
# AVERAGE VAL LOSS: 0.06831574440002441
# #################
# # EPOCH 2900
# #################
# AVERAGE TRAIN LOSS: 0.02005520462989807
# AVERAGE VAL LOSS: 0.06125753000378609
# #################
# # EPOCH 2901
# #################
# AVERAGE TRAIN LOSS: 0.018467877060174942
# AVERAGE VAL LOSS: 0.05766032263636589
# #################
# # EPOCH 2902
# #################
# AVERAGE TRAIN LOSS: 0.02271183207631111
# AVERAGE VAL LOSS: 0.060647476464509964
# #################
# # EPOCH 2903
# #################
# AVERAGE TRAIN LOSS: 0.0187140591442585
# AVERAGE VAL LOSS: 0.05973055213689804
# #################
# # EPOCH 2904
# #################
# AVERAGE TRAIN LOSS: 0.020596861839294434
# AVERAGE VAL LOSS: 0.05888260528445244
# #################
# # EPOCH 2905
# #################
# AVERAGE TRAIN LOSS: 0.02038131281733513
# AVERAGE VAL LOSS: 0.06545175611972809
# #################
# # EPOCH 2906
# #################
# AVERAGE TRAIN LOSS: 0.020099487155675888
# AVERAGE VAL LOSS: 0.0593862421810627
# #################
# # EPOCH 2907
# #################
# AVERAGE TRAIN LOSS: 0.019676629453897476
# AVERAGE VAL LOSS: 0.05792846530675888
# #################
# # EPOCH 2908
# #################
# AVERAGE TRAIN LOSS: 0.02525913342833519
# AVERAGE VAL LOSS: 0.06529978662729263
# #################
# # EPOCH 2909
# #################
# AVERAGE TRAIN LOSS: 0.020326822996139526
# AVERAGE VAL LOSS: 0.05646966025233269
# #################
# # EPOCH 2910
# #################
# AVERAGE TRAIN LOSS: 0.02061893418431282
# AVERAGE VAL LOSS: 0.06018416956067085
# #################
# # EPOCH 2911
# #################
# AVERAGE TRAIN LOSS: 0.018981480970978737
# AVERAGE VAL LOSS: 0.06344376504421234
# #################
# # EPOCH 2912
# #################
# AVERAGE TRAIN LOSS: 0.019907992333173752
# AVERAGE VAL LOSS: 0.06202823668718338
# #################
# # EPOCH 2913
# #################
# AVERAGE TRAIN LOSS: 0.020784443244338036
# AVERAGE VAL LOSS: 0.058278121054172516
# #################
# # EPOCH 2914
# #################
# AVERAGE TRAIN LOSS: 0.02417578361928463
# AVERAGE VAL LOSS: 0.06845495104789734
# #################
# # EPOCH 2915
# #################
# AVERAGE TRAIN LOSS: 0.020885391160845757
# AVERAGE VAL LOSS: 0.05799693986773491
# #################
# # EPOCH 2916
# #################
# AVERAGE TRAIN LOSS: 0.01967073418200016
# AVERAGE VAL LOSS: 0.059193532913923264
# #################
# # EPOCH 2917
# #################
# AVERAGE TRAIN LOSS: 0.02058527246117592
# AVERAGE VAL LOSS: 0.06304679811000824
# #################
# # EPOCH 2918
# #################
# AVERAGE TRAIN LOSS: 0.021673765033483505
# AVERAGE VAL LOSS: 0.062399692833423615
# #################
# # EPOCH 2919
# #################
# AVERAGE TRAIN LOSS: 0.022175345569849014
# AVERAGE VAL LOSS: 0.057651519775390625
# #################
# # EPOCH 2920
# #################
# AVERAGE TRAIN LOSS: 0.020028239116072655
# AVERAGE VAL LOSS: 0.06504254043102264
# #################
# # EPOCH 2921
# #################
# AVERAGE TRAIN LOSS: 0.01985454559326172
# AVERAGE VAL LOSS: 0.06418384611606598
# #################
# # EPOCH 2922
# #################
# AVERAGE TRAIN LOSS: 0.020085539668798447
# AVERAGE VAL LOSS: 0.061584193259477615
# #################
# # EPOCH 2923
# #################
# AVERAGE TRAIN LOSS: 0.019242877140641212
# AVERAGE VAL LOSS: 0.05765413120388985
# #################
# # EPOCH 2924
# #################
# AVERAGE TRAIN LOSS: 0.020639358088374138
# AVERAGE VAL LOSS: 0.06068964675068855
# #################
# # EPOCH 2925
# #################
# AVERAGE TRAIN LOSS: 0.022594988346099854
# AVERAGE VAL LOSS: 0.05597580596804619
# #################
# # EPOCH 2926
# #################
# AVERAGE TRAIN LOSS: 0.019737496972084045
# AVERAGE VAL LOSS: 0.06748249381780624
# #################
# # EPOCH 2927
# #################
# AVERAGE TRAIN LOSS: 0.020452816039323807
# AVERAGE VAL LOSS: 0.062497396022081375
# #################
# # EPOCH 2928
# #################
# AVERAGE TRAIN LOSS: 0.02013256773352623
# AVERAGE VAL LOSS: 0.06357935816049576
# #################
# # EPOCH 2929
# #################
# AVERAGE TRAIN LOSS: 0.02036968432366848
# AVERAGE VAL LOSS: 0.060315392911434174
# #################
# # EPOCH 2930
# #################
# AVERAGE TRAIN LOSS: 0.01991383731365204
# AVERAGE VAL LOSS: 0.062217891216278076
# #################
# # EPOCH 2931
# #################
# AVERAGE TRAIN LOSS: 0.01918082684278488
# AVERAGE VAL LOSS: 0.06104111671447754
# #################
# # EPOCH 2932
# #################
# AVERAGE TRAIN LOSS: 0.020842980593442917
# AVERAGE VAL LOSS: 0.06615374237298965
# #################
# # EPOCH 2933
# #################
# AVERAGE TRAIN LOSS: 0.018727755174040794
# AVERAGE VAL LOSS: 0.0591747984290123
# #################
# # EPOCH 2934
# #################
# AVERAGE TRAIN LOSS: 0.01930457167327404
# AVERAGE VAL LOSS: 0.059559475630521774
# #################
# # EPOCH 2935
# #################
# AVERAGE TRAIN LOSS: 0.019479388371109962
# AVERAGE VAL LOSS: 0.05785924941301346
# #################
# # EPOCH 2936
# #################
# AVERAGE TRAIN LOSS: 0.019343852996826172
# AVERAGE VAL LOSS: 0.06161762401461601
# #################
# # EPOCH 2937
# #################
# AVERAGE TRAIN LOSS: 0.019015247002243996
# AVERAGE VAL LOSS: 0.06281906366348267
# #################
# # EPOCH 2938
# #################
# AVERAGE TRAIN LOSS: 0.020053669810295105
# AVERAGE VAL LOSS: 0.059154994785785675
# #################
# # EPOCH 2939
# #################
# AVERAGE TRAIN LOSS: 0.019476374611258507
# AVERAGE VAL LOSS: 0.06252877414226532
# #################
# # EPOCH 2940
# #################
# AVERAGE TRAIN LOSS: 0.019782621413469315
# AVERAGE VAL LOSS: 0.06076224893331528
# #################
# # EPOCH 2941
# #################
# AVERAGE TRAIN LOSS: 0.0197114460170269
# AVERAGE VAL LOSS: 0.06016907840967178
# #################
# # EPOCH 2942
# #################
# AVERAGE TRAIN LOSS: 0.019254136830568314
# AVERAGE VAL LOSS: 0.061967890709638596
# #################
# # EPOCH 2943
# #################
# AVERAGE TRAIN LOSS: 0.01902131922543049
# AVERAGE VAL LOSS: 0.060672931373119354
# #################
# # EPOCH 2944
# #################
# AVERAGE TRAIN LOSS: 0.019810041412711143
# AVERAGE VAL LOSS: 0.05863573029637337
# #################
# # EPOCH 2945
# #################
# AVERAGE TRAIN LOSS: 0.019225098192691803
# AVERAGE VAL LOSS: 0.06160299852490425
# #################
# # EPOCH 2946
# #################
# AVERAGE TRAIN LOSS: 0.019189802929759026
# AVERAGE VAL LOSS: 0.06199757009744644
# #################
# # EPOCH 2947
# #################
# AVERAGE TRAIN LOSS: 0.01971229538321495
# AVERAGE VAL LOSS: 0.06392673403024673
# #################
# # EPOCH 2948
# #################
# AVERAGE TRAIN LOSS: 0.01907656155526638
# AVERAGE VAL LOSS: 0.06072736531496048
# #################
# # EPOCH 2949
# #################
# AVERAGE TRAIN LOSS: 0.018891245126724243
# AVERAGE VAL LOSS: 0.05995435267686844
# #################
# # EPOCH 2950
# #################
# AVERAGE TRAIN LOSS: 0.02137785032391548
# AVERAGE VAL LOSS: 0.06364832818508148
# #################
# # EPOCH 2951
# #################
# AVERAGE TRAIN LOSS: 0.020657237619161606
# AVERAGE VAL LOSS: 0.055978018790483475
# #################
# # EPOCH 2952
# #################
# AVERAGE TRAIN LOSS: 0.02001749537885189
# AVERAGE VAL LOSS: 0.061667490750551224
# #################
# # EPOCH 2953
# #################
# AVERAGE TRAIN LOSS: 0.01880539022386074
# AVERAGE VAL LOSS: 0.06424425542354584
# #################
# # EPOCH 2954
# #################
# AVERAGE TRAIN LOSS: 0.02000008523464203
# AVERAGE VAL LOSS: 0.0599493682384491
# #################
# # EPOCH 2955
# #################
# AVERAGE TRAIN LOSS: 0.018894050270318985
# AVERAGE VAL LOSS: 0.06042606383562088
# #################
# # EPOCH 2956
# #################
# AVERAGE TRAIN LOSS: 0.0195059385150671
# AVERAGE VAL LOSS: 0.06320681422948837
# #################
# # EPOCH 2957
# #################
# AVERAGE TRAIN LOSS: 0.02226758375763893
# AVERAGE VAL LOSS: 0.059362344443798065
# #################
# # EPOCH 2958
# #################
# AVERAGE TRAIN LOSS: 0.021913763135671616
# AVERAGE VAL LOSS: 0.06780698895454407
# #################
# # EPOCH 2959
# #################
# AVERAGE TRAIN LOSS: 0.020030558109283447
# AVERAGE VAL LOSS: 0.059391170740127563
# #################
# # EPOCH 2960
# #################
# AVERAGE TRAIN LOSS: 0.020856663584709167
# AVERAGE VAL LOSS: 0.060290366411209106
# #################
# # EPOCH 2961
# #################
# AVERAGE TRAIN LOSS: 0.019333254545927048
# AVERAGE VAL LOSS: 0.06319128721952438
# #################
# # EPOCH 2962
# #################
# AVERAGE TRAIN LOSS: 0.01969054900109768
# AVERAGE VAL LOSS: 0.06201816350221634
# #################
# # EPOCH 2963
# #################
# AVERAGE TRAIN LOSS: 0.020599158480763435
# AVERAGE VAL LOSS: 0.05743458867073059
# #################
# # EPOCH 2964
# #################
# AVERAGE TRAIN LOSS: 0.02035808563232422
# AVERAGE VAL LOSS: 0.06213133782148361
# #################
# # EPOCH 2965
# #################
# AVERAGE TRAIN LOSS: 0.019382666796445847
# AVERAGE VAL LOSS: 0.0585998110473156
# #################
# # EPOCH 2966
# #################
# AVERAGE TRAIN LOSS: 0.018992822617292404
# AVERAGE VAL LOSS: 0.06010293960571289
# #################
# # EPOCH 2967
# #################
# AVERAGE TRAIN LOSS: 0.019021859392523766
# AVERAGE VAL LOSS: 0.060756903141736984
# #################
# # EPOCH 2968
# #################
# AVERAGE TRAIN LOSS: 0.021886203438043594
# AVERAGE VAL LOSS: 0.06573759764432907
# #################
# # EPOCH 2969
# #################
# AVERAGE TRAIN LOSS: 0.025517618283629417
# AVERAGE VAL LOSS: 0.05670475214719772
# #################
# # EPOCH 2970
# #################
# AVERAGE TRAIN LOSS: 0.020799007266759872
# AVERAGE VAL LOSS: 0.06431438773870468
# #################
# # EPOCH 2971
# #################
# AVERAGE TRAIN LOSS: 0.020360345020890236
# AVERAGE VAL LOSS: 0.06743484735488892
# #################
# # EPOCH 2972
# #################
# AVERAGE TRAIN LOSS: 0.0206399317830801
# AVERAGE VAL LOSS: 0.05905015394091606
# #################
# # EPOCH 2973
# #################
# AVERAGE TRAIN LOSS: 0.01964542455971241
# AVERAGE VAL LOSS: 0.06093274801969528
# #################
# # EPOCH 2974
# #################
# AVERAGE TRAIN LOSS: 0.01919415406882763
# AVERAGE VAL LOSS: 0.06309816986322403
# #################
# # EPOCH 2975
# #################
# AVERAGE TRAIN LOSS: 0.022867737337946892
# AVERAGE VAL LOSS: 0.06943315267562866
# #################
# # EPOCH 2976
# #################
# AVERAGE TRAIN LOSS: 0.018916452303528786
# AVERAGE VAL LOSS: 0.056024473160505295
# #################
# # EPOCH 2977
# #################
# AVERAGE TRAIN LOSS: 0.02153051272034645
# AVERAGE VAL LOSS: 0.058272384107112885
# #################
# # EPOCH 2978
# #################
# AVERAGE TRAIN LOSS: 0.019370734691619873
# AVERAGE VAL LOSS: 0.060185182839632034
# #################
# # EPOCH 2979
# #################
# AVERAGE TRAIN LOSS: 0.01907901093363762
# AVERAGE VAL LOSS: 0.061748553067445755
# #################
# # EPOCH 2980
# #################
# AVERAGE TRAIN LOSS: 0.019433289766311646
# AVERAGE VAL LOSS: 0.05984065681695938
# #################
# # EPOCH 2981
# #################
# AVERAGE TRAIN LOSS: 0.018829530104994774
# AVERAGE VAL LOSS: 0.06307918578386307
# #################
# # EPOCH 2982
# #################
# AVERAGE TRAIN LOSS: 0.019777217879891396
# AVERAGE VAL LOSS: 0.06217334792017937
# #################
# # EPOCH 2983
# #################
# AVERAGE TRAIN LOSS: 0.02160157822072506
# AVERAGE VAL LOSS: 0.05786533281207085
# #################
# # EPOCH 2984
# #################
# AVERAGE TRAIN LOSS: 0.019110431894659996
# AVERAGE VAL LOSS: 0.06325598061084747
# #################
# # EPOCH 2985
# #################
# AVERAGE TRAIN LOSS: 0.021300658583641052
# AVERAGE VAL LOSS: 0.06762418895959854
# #################
# # EPOCH 2986
# #################
# AVERAGE TRAIN LOSS: 0.01932496391236782
# AVERAGE VAL LOSS: 0.05911371111869812
# #################
# # EPOCH 2987
# #################
# AVERAGE TRAIN LOSS: 0.02092277631163597
# AVERAGE VAL LOSS: 0.05773094296455383
# #################
# # EPOCH 2988
# #################
# AVERAGE TRAIN LOSS: 0.019579147920012474
# AVERAGE VAL LOSS: 0.06410549581050873
# #################
# # EPOCH 2989
# #################
# AVERAGE TRAIN LOSS: 0.020107049494981766
# AVERAGE VAL LOSS: 0.061851806938648224
# #################
# # EPOCH 2990
# #################
# AVERAGE TRAIN LOSS: 0.019488848745822906
# AVERAGE VAL LOSS: 0.061478596180677414
# #################
# # EPOCH 2991
# #################
# AVERAGE TRAIN LOSS: 0.019377443939447403
# AVERAGE VAL LOSS: 0.06311149895191193
# #################
# # EPOCH 2992
# #################
# AVERAGE TRAIN LOSS: 0.019457681104540825
# AVERAGE VAL LOSS: 0.059495918452739716
# #################
# # EPOCH 2993
# #################
# AVERAGE TRAIN LOSS: 0.02027187868952751
# AVERAGE VAL LOSS: 0.05885624140501022
# #################
# # EPOCH 2994
# #################
# AVERAGE TRAIN LOSS: 0.01924975961446762
# AVERAGE VAL LOSS: 0.06308954209089279
# #################
# # EPOCH 2995
# #################
# AVERAGE TRAIN LOSS: 0.019431928172707558
# AVERAGE VAL LOSS: 0.06145712733268738
# #################
# # EPOCH 2996
# #################
# AVERAGE TRAIN LOSS: 0.01960180327296257
# AVERAGE VAL LOSS: 0.05856884643435478
# #################
# # EPOCH 2997
# #################
# AVERAGE TRAIN LOSS: 0.01936875469982624
# AVERAGE VAL LOSS: 0.06191093847155571
# #################
# # EPOCH 2998
# #################
# AVERAGE TRAIN LOSS: 0.024403365328907967
# AVERAGE VAL LOSS: 0.0708061009645462
# #################
# # EPOCH 2999
# #################
# AVERAGE TRAIN LOSS: 0.02154185250401497
# AVERAGE VAL LOSS: 0.05868805572390556

# %% [markdown]
# ### Plot losses
#
# Additional tool for visualization:
#
# *   [Weights and Biases](https://wandb.ai/site) (Suggested)
# *   [Tensorboard](https://www.tensorflow.org/tensorboard?hl=it)

# %%
# Plot losses
plt.figure(figsize=(12,8))
plt.semilogy(train_loss_log, label='Train loss')
plt.semilogy(val_loss_log, label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Network output

# %%
# Input vector
x_vec = torch.linspace(0,1,1000)
x_vec = x_vec.to(device)
x_vec = x_vec.unsqueeze(-1)  # Adding a dimension to the input vector
print(f"Input shape: {x_vec.shape}")

# Network output
# eval() acts as switch for some specific layers/parts of the model that behave
# differently during training and inference (eval) time. For example, Dropout
# BatchNorm etc.
net.eval()
with torch.no_grad(): # turn off gradients computation
    y_vec = net(x_vec)
print(f"Output shape: {y_vec.shape}")

# Expected output
beta_true = [-1.45, 1.12, 2.3]
true_model = poly_model(x_vec.cpu().numpy(), beta_true).squeeze()
# Out:
# Input shape: torch.Size([1000, 1])
# Output shape: torch.Size([1000, 1])

# %%
# Convert x_vec and y_vec to numpy one dimensional arrays
x_vec = x_vec.squeeze().cpu().numpy()
y_vec = y_vec.squeeze().cpu().numpy()

# Plot output
plt.figure(figsize=(12,8))
plt.plot(x_vec, y_vec, label='Network output')
plt.plot(x_vec, true_model, label='True model')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### What if we predict outside the range?

# %%
# Input vector
x_vec = torch.linspace(-5,5,1000)
x_vec = x_vec.to(device)
x_vec = x_vec.unsqueeze(-1)  # Adding a dimension to the input vector
print(f"Input shape: {x_vec.shape}")

# Network output
net.eval()
with torch.no_grad():
    y_vec = net(x_vec)
print(f"Output shape: {y_vec.shape}")

# Expected output
beta_true = [-1.45, 1.12, 2.3]
true_model = poly_model(x_vec.cpu().numpy(), beta_true).squeeze()

# Convert x_vec and y_vec to numpy one dimensional arrays
x_vec = x_vec.squeeze().cpu().numpy()
y_vec = y_vec.squeeze().cpu().numpy()

# Plot output
plt.figure(figsize=(12,8))
plt.plot(x_vec, y_vec, label='Network output')
plt.plot(x_vec, true_model, label='True model')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()
# Out:
# Input shape: torch.Size([1000, 1])
# Output shape: torch.Size([1000, 1])

# %% [markdown]
# ### What if we try different activation functions? (e.g., ReLU for nonlinearities)
# ### Is there overfit with ReLU?
#
# ### Homework : add some regularization to fight overfitting (e.g., dropout, weight decay,...)

# %% [markdown]
# ## Access network parameters

# %%
# First hidden layer
h1_w = net.fc1.weight.data.cpu().numpy()
h1_b = net.fc1.bias.data.cpu().numpy()

# Second hidden layer
h2_w = net.fc2.weight.data.cpu().numpy()
h2_b = net.fc2.bias.data.cpu().numpy()

# Output layer
out_w = net.out.weight.data.cpu().numpy()
out_b = net.out.bias.data.cpu().numpy()

# %% [markdown]
# ## Weights histogram

# %%
# Weights histogram
fig, axs = plt.subplots(3, 1, figsize=(12,8))
axs[0].hist(h1_w.flatten(), 50)
axs[0].set_title('First hidden layer weights')
axs[1].hist(h2_w.flatten(), 50)
axs[1].set_title('Second hidden layer weights')
axs[2].hist(out_w.flatten(), 50)
axs[2].set_title('Output layer weights')
[ax.grid() for ax in axs]
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Homework (simple): compare the histogram before and after the training

# %% [markdown]
# ## Saving the network weights **(Essential for the Final Project)**
#
# After training a model, a good practice is to save its weights in order to be able to retrieve it later.
#
# **NOTE**: saving the weights is essential also for creating checkpoints of your training process. Google Colab imposes time limits on your kernel sessions, so *it will not be possible for you to carry out very long training sessions*.
#
# It will be therefore essential for your final project to create checkpoints, so that you will be able to resume your training at a later moment, when re-gaining access of your Colab runtime. Even when using a dedicated GPU in your local machine or on a server, creating checkpoints is a good practice you should always implement in your training pipeline.

# %% [markdown]
# ### Save network

# %%
### Save network parameters
### Save the network state
# The state dictionary includes all the parameters of the network
net_state_dict = net.state_dict()
print(net_state_dict.keys())
# Save the state dict to a file
torch.save(net_state_dict, 'net_parameters.torch')
# Out:
# odict_keys(['fc1.weight', 'fc1.bias', 'fc2.weight', 'fc2.bias', 'out.weight', 'out.bias'])

# %% [markdown]
# ### Load network

# %%
### Reload the network state
# First initialize the network (if not already done)
# IMPORTANT: you need to know the model definition!!
net = Net(Ni, Nh1, Nh2, No)
# Load the state dict previously saved
net_state_dict = torch.load('net_parameters.torch')
# Update the network parameters
net.load_state_dict(net_state_dict)
# Out:
# Network initialized
# <All keys matched successfully>

# %% [markdown]
# ### Save optimizer state
# Also the optimizer has its internal state!
#
# You need to save both the network and the optimizer states if you want to continue your training.
#
# If you are sure you have finished your training you can just save the network.

# %%
### Save the optimizer state
torch.save(optimizer.state_dict(), 'optimizer_state.torch')

### Reload the optimizer state
optimizer = optim.Adam(net.parameters(), lr=0.001)
opt_state_dict = torch.load('optimizer_state.torch')
optimizer.load_state_dict(opt_state_dict)

# %% [markdown]
# ## Analyze activations (Advanced)

# %%
# First naive way: simply change the network definition to return an additional output

# More advanced strategy (optional if you're not familiar with Python!): using hooks

def get_activation(layer, input, output):
    global activation
    activation = torch.sigmoid(output)

### Register hook
hook_handle = net.fc2.register_forward_hook(get_activation)

### Analyze activations
net = net.to(device)
net.eval()
with torch.no_grad():
    x1 = torch.tensor([0.1]).float().to(device)
    y1 = net(x1)
    z1 = activation
    x2 = torch.tensor([0.9]).float().to(device)
    y2 = net(x2)
    z2 = activation
    x3 = torch.tensor([2.5]).float().to(device)
    y3 = net(x3)
    z3 = activation

### Remove hook
hook_handle.remove()

### Plot activations
fig, axs = plt.subplots(3, 1, figsize=(12,6))
axs[0].stem(z1.cpu().numpy())
axs[0].set_title('Last layer activations for input x=%.2f' % x1)
axs[1].stem(z2.cpu().numpy())
axs[1].set_title('Last layer activations for input x=%.2f' % x2)
axs[2].stem(z3.cpu().numpy())
axs[2].set_title('Last layer activations for input x=%.2f' % x3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Part 3: Classification model with PyTorch

# %% [markdown]
# **HINTS**
# - Choose a loss function that is suitable for the specific problem, a binary classification in this case. If you keep a single linear output you can use a BCEWithLogitsLoss, which is more numerically stable than manually using a sigmoid output activation (more info here: https://pytorch.org/docs/stable/generated/torch.nn.BCEWithLogitsLoss.html ).
# - The network now has 2 inputs. A batched input should have a shape $\text{batch_size} \times 2$.
# - The dataset should be adapted accordingly. Also consider to increase the batch size.
# - Explore different optimizers, trying to understand the differences and their parameters (https://pytorch.org/docs/stable/optim.html ).
# - Try to increase the complexity of the network, and at the same time to introduce some regularization with dropout layers and/or weight decay (which is equivalent to an L2 regularization, typically implemented by the optimizer).
# - Experiment with different hyper-parameters trying to minimize the VALIDATION LOSS. Once you are happy with the result, try the final test with the TEST dataset.

# %% [markdown]
# ## Data generation

# %%
import itertools

np.random.seed(123)

def bidimensional_model(x1, x2):
    a = 1
    b = 1
    cx1 = 0
    cx2 = 0
    out = (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 2
    b = 2
    cx1 = 5
    cx2 = 5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 1
    b = 2
    cx1 = -2.5
    cx2 = 5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 3
    b = 1
    cx1 = -6
    cx2 = -2.5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 2
    b = 4
    cx1 = -7.5
    cx2 = -5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 6
    b = 1
    cx1 = -7.5
    cx2 = 5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 4
    b = 4
    cx1 = 7.5
    cx2 = -7.5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 3
    b = 2
    cx1 = -1
    cx2 = -6
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 2
    b = 5
    cx1 = 1
    cx2 = 6
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 2
    b = 2
    cx1 = 6
    cx2 = 0
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    return out.astype(int)

### PLOT MODEL
# Input grid
x1 = np.linspace(-10, 10, 400)
x2 = np.linspace(-10, 10, 400)
x_prod = [x for x in itertools.product(x1, x2)]
x1 = np.array([x[0] for x in x_prod])
x2 = np.array([x[1] for x in x_prod])
# Evaluate out
y = bidimensional_model(x1, x2)
# Scatter plot
fig, ax = plt.subplots(figsize=(12,8))
colors = np.array(['C0', 'C1'])
ax.scatter(x1, x2, c=colors[y], s=10, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
fig.show()

# %% [markdown]
# ### Training points

# %%
import pandas as pd

### Train data
num_points = 1000
x1 = np.random.uniform(-10, 10, num_points)
x2 = np.random.uniform(-10, 10, num_points)
y = bidimensional_model(x1, x2)
train_df = pd.DataFrame({'x1': x1, 'x2': x2, 'y': y})
train_df.to_csv('classifier_train_data.csv', index=False)

fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(x1, x2, c=colors[y], s=10, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_title('Training points')
fig.show()

# %% [markdown]
# ### Validation points

# %% [markdown]
# In this case: we generate validation points.
# Usually: validation points are randomly selected from the training points (~20% of training data).

# %%
### Validation data
num_points = 200
x1 = np.random.uniform(-10, 10, num_points)
x2 = np.random.uniform(-10, 10, num_points)
y = bidimensional_model(x1, x2)
val_df = pd.DataFrame({'x1': x1, 'x2': x2, 'y': y})
val_df.to_csv('classifier_val_data.csv', index=False)

fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(x1, x2, c=colors[y], s=10, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_title('Validation points')
fig.show()

# %% [markdown]
# ### Test points

# %%
### Test data
num_points = 400
x1 = np.random.uniform(-10, 10, num_points)
x2 = np.random.uniform(-10, 10, num_points)
y = bidimensional_model(x1, x2)
val_df = pd.DataFrame({'x1': x1, 'x2': x2, 'y': y})
val_df.to_csv('classifier_test_data.csv', index=False)

fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(x1, x2, c=colors[y], s=10, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_title('Test points')
fig.show()

# %% [markdown]
# ## Dataset and Dataloader

# %% [markdown]
# Define the dataset

# %%
class ClassifierDataset(Dataset):

    def __init__(self, csv_file, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        ###############################
        # PUT YOUR CODE HERE
        self.transform = transform
        # Read the file and store the content in a pandas DataFrame
        self.df = pd.read_csv(csv_file)
        ###############################

    def __len__(self):
        ###############################
        # PUT YOUR CODE HERE
        # The length of the dataset is simply the length of the self.df DataFrame
        return len(self.df)
        ###############################

    def __getitem__(self, idx):
        # Our sample is the row at index idx of the dataframe

        ###############################
        # PUT YOUR CODE HERE
        row = self.df.iloc[idx]
        # There are 2 inputs this time
        sample = ([row.x1, row.x2], row.y)
        if self.transform:
            sample = self.transform(sample)
        ###############################
        return sample

# %% [markdown]
# Define the transformations

# %%
class ToTensor(object):
    """Convert sample to Tensors."""

    def __call__(self, sample):
        x, y = sample
        return (torch.Tensor(x).float(),
                torch.Tensor([y]).float())

# %% [markdown]
# Initialize the datasets

# %%
###############################
### PUT YOUR CODE HERE
composed_transform = transforms.Compose([ToTensor()])

train_dataset = ClassifierDataset('classifier_train_data.csv', transform=composed_transform)
val_dataset   = ClassifierDataset('classifier_val_data.csv',   transform=composed_transform)
test_dataset  = ClassifierDataset('classifier_test_data.csv',  transform=composed_transform)
###############################

# %% [markdown]
# Define the dataloaders

# %%
###############################
#Put your code here
train_dataloader = DataLoader(train_dataset, 200) #batch size = 200
val_dataloader   = DataLoader(val_dataset, 200) #The batch size can be equal to the validation set size if it fits in memory
test_dataloader  = DataLoader(test_dataset, 200)
###############################

# %% [markdown]
# ## Network definition

# %%
class Net(nn.Module):

    def __init__(self, Ni, Nh1, Nh2, No):
        """
        Ni - Input size
        Nh1 - Neurons in the 1st hidden layer
        Nh2 - Neurons in the 2nd hidden layer
        No - Output size
        """
        super().__init__()

        print('Network initialized')
        self.fc1 = nn.Linear(in_features=Ni, out_features=Nh1)
        self.fc2 = nn.Linear(in_features=Nh1, out_features=Nh2)
        self.out = nn.Linear(in_features=Nh2, out_features=No)
        self.act = nn.Sigmoid()

    def forward(self, x, additional_out=False):
        x = self.act(self.fc1(x))
        x = self.act(self.fc2(x))
        x = self.out(x)
        return x

# %% [markdown]
# ## Training loop

# %%
# Initialize the network
torch.manual_seed(0)
Ni = 2
Nh1 = 128
Nh2 = 256
No = 1 #now we have classification between two classes

net = Net(Ni, Nh1, Nh2, No)
net.to(device)

# Define the loss function
###############################################
###PUT YOUR CODE HERE
loss_fn = nn.BCEWithLogitsLoss() # TODO: use a proper classification loss

# Define the optimizer with lr=1e-2
optimizer = optim.Adam(net.parameters(), lr=1e-2)
###############################################
# Out:
# Network initialized

# %%
### TRAINING LOOP
num_epochs = 600
train_loss_log = []
val_loss_log = []
for epoch_num in range(num_epochs):
    print('#################')
    print(f'# EPOCH {epoch_num}')
    print('#################')

    ### TRAIN
    train_loss= []
    ###############################################
    ###PUT YOUR CODE HERE
    net.train() # Training mode (e.g. enable dropout)
    for sample_batched in train_dataloader:
        # Move data to device
        x_batch = sample_batched[0].to(device)
        label_batch = sample_batched[1].to(device)

        # Forward pass
        out = net(x_batch)

        # Compute loss
        loss = loss_fn(out, label_batch)

        # Backpropagation
        net.zero_grad()
        loss.backward()

        # Update the weights
        optimizer.step()

        # Save train loss for this batch
        loss_batch = loss.detach().cpu().numpy()
        train_loss.append(loss_batch)

    # Save average train loss
    train_loss = np.mean(train_loss)
    print(f"AVERAGE TRAIN LOSS: {train_loss}")
    train_loss_log.append(train_loss)

    ### VALIDATION
    val_loss= []
    net.eval() # Evaluation mode (e.g. disable dropout)
    with torch.no_grad(): # Disable gradient tracking
        for sample_batched in val_dataloader:
            # Move data to device
            x_batch = sample_batched[0].to(device)
            label_batch = sample_batched[1].to(device)

            # Forward pass
            out = net(x_batch)

            # Compute loss
            loss = loss_fn(out, label_batch)

            # Save val loss for this batch
            loss_batch = loss.detach().cpu().numpy()
            val_loss.append(loss_batch)
        ###############################################
        # Save average validation loss
        val_loss = np.mean(val_loss)
        print(f"AVERAGE VAL LOSS: {np.mean(val_loss)}")
        val_loss_log.append(val_loss)
# Out:
# #################
# # EPOCH 0
# #################
# AVERAGE TRAIN LOSS: 0.8243857622146606
# AVERAGE VAL LOSS: 0.8206965923309326
# #################
# # EPOCH 1
# #################
# AVERAGE TRAIN LOSS: 0.7350733876228333
# AVERAGE VAL LOSS: 0.7745404839515686
# #################
# # EPOCH 2
# #################
# AVERAGE TRAIN LOSS: 0.6817244291305542
# AVERAGE VAL LOSS: 0.6821430325508118
# #################
# # EPOCH 3
# #################
# AVERAGE TRAIN LOSS: 0.66047602891922
# AVERAGE VAL LOSS: 0.6875277161598206
# #################
# # EPOCH 4
# #################
# AVERAGE TRAIN LOSS: 0.6584616899490356
# AVERAGE VAL LOSS: 0.679558277130127
# #################
# # EPOCH 5
# #################
# AVERAGE TRAIN LOSS: 0.6481497287750244
# AVERAGE VAL LOSS: 0.6899506449699402
# #################
# # EPOCH 6
# #################
# AVERAGE TRAIN LOSS: 0.6409519910812378
# AVERAGE VAL LOSS: 0.6762188673019409
# #################
# # EPOCH 7
# #################
# AVERAGE TRAIN LOSS: 0.6311357617378235
# AVERAGE VAL LOSS: 0.670314610004425
# #################
# # EPOCH 8
# #################
# AVERAGE TRAIN LOSS: 0.6255761981010437
# AVERAGE VAL LOSS: 0.6655678749084473
# #################
# # EPOCH 9
# #################
# AVERAGE TRAIN LOSS: 0.615066647529602
# AVERAGE VAL LOSS: 0.6609785556793213
# #################
# # EPOCH 10
# #################
# AVERAGE TRAIN LOSS: 0.601333498954773
# AVERAGE VAL LOSS: 0.6507132053375244
# #################
# # EPOCH 11
# #################
# AVERAGE TRAIN LOSS: 0.5903042554855347
# AVERAGE VAL LOSS: 0.6447975039482117
# #################
# # EPOCH 12
# #################
# AVERAGE TRAIN LOSS: 0.5793061852455139
# AVERAGE VAL LOSS: 0.6452414989471436
# #################
# # EPOCH 13
# #################
# AVERAGE TRAIN LOSS: 0.5718193054199219
# AVERAGE VAL LOSS: 0.6474114060401917
# #################
# # EPOCH 14
# #################
# AVERAGE TRAIN LOSS: 0.5677303075790405
# AVERAGE VAL LOSS: 0.6475803852081299
# #################
# # EPOCH 15
# #################
# AVERAGE TRAIN LOSS: 0.5640363693237305
# AVERAGE VAL LOSS: 0.6436958909034729
# #################
# # EPOCH 16
# #################
# AVERAGE TRAIN LOSS: 0.5593773126602173
# AVERAGE VAL LOSS: 0.6361433267593384
# #################
# # EPOCH 17
# #################
# AVERAGE TRAIN LOSS: 0.5550087690353394
# AVERAGE VAL LOSS: 0.6282427906990051
# #################
# # EPOCH 18
# #################
# AVERAGE TRAIN LOSS: 0.5501055717468262
# AVERAGE VAL LOSS: 0.6224717497825623
# #################
# # EPOCH 19
# #################
# AVERAGE TRAIN LOSS: 0.5454398393630981
# AVERAGE VAL LOSS: 0.6169335842132568
# #################
# # EPOCH 20
# #################
# AVERAGE TRAIN LOSS: 0.5398138761520386
# AVERAGE VAL LOSS: 0.6124534606933594
# #################
# # EPOCH 21
# #################
# AVERAGE TRAIN LOSS: 0.5343331098556519
# AVERAGE VAL LOSS: 0.6076424717903137
# #################
# # EPOCH 22
# #################
# AVERAGE TRAIN LOSS: 0.5281509160995483
# AVERAGE VAL LOSS: 0.6025508642196655
# #################
# # EPOCH 23
# #################
# AVERAGE TRAIN LOSS: 0.5219127535820007
# AVERAGE VAL LOSS: 0.5969734191894531
# #################
# # EPOCH 24
# #################
# AVERAGE TRAIN LOSS: 0.515031635761261
# AVERAGE VAL LOSS: 0.5905846953392029
# #################
# # EPOCH 25
# #################
# AVERAGE TRAIN LOSS: 0.5077269673347473
# AVERAGE VAL LOSS: 0.5836637616157532
# #################
# # EPOCH 26
# #################
# AVERAGE TRAIN LOSS: 0.4999902844429016
# AVERAGE VAL LOSS: 0.576387882232666
# #################
# # EPOCH 27
# #################
# AVERAGE TRAIN LOSS: 0.49156031012535095
# AVERAGE VAL LOSS: 0.5687924027442932
# #################
# # EPOCH 28
# #################
# AVERAGE TRAIN LOSS: 0.4827958047389984
# AVERAGE VAL LOSS: 0.5609951615333557
# #################
# # EPOCH 29
# #################
# AVERAGE TRAIN LOSS: 0.4735810160636902
# AVERAGE VAL LOSS: 0.5529845952987671
# #################
# # EPOCH 30
# #################
# AVERAGE TRAIN LOSS: 0.4641578197479248
# AVERAGE VAL LOSS: 0.5450624227523804
# #################
# # EPOCH 31
# #################
# AVERAGE TRAIN LOSS: 0.45484256744384766
# AVERAGE VAL LOSS: 0.5372573137283325
# #################
# # EPOCH 32
# #################
# AVERAGE TRAIN LOSS: 0.44583749771118164
# AVERAGE VAL LOSS: 0.529807984828949
# #################
# # EPOCH 33
# #################
# AVERAGE TRAIN LOSS: 0.43732863664627075
# AVERAGE VAL LOSS: 0.523052453994751
# #################
# # EPOCH 34
# #################
# AVERAGE TRAIN LOSS: 0.42950695753097534
# AVERAGE VAL LOSS: 0.5173168778419495
# #################
# # EPOCH 35
# #################
# AVERAGE TRAIN LOSS: 0.4224078059196472
# AVERAGE VAL LOSS: 0.512539803981781
# #################
# # EPOCH 36
# #################
# AVERAGE TRAIN LOSS: 0.41602572798728943
# AVERAGE VAL LOSS: 0.508463442325592
# #################
# # EPOCH 37
# #################
# AVERAGE TRAIN LOSS: 0.41030174493789673
# AVERAGE VAL LOSS: 0.5048844814300537
# #################
# # EPOCH 38
# #################
# AVERAGE TRAIN LOSS: 0.4051271975040436
# AVERAGE VAL LOSS: 0.5016915798187256
# #################
# # EPOCH 39
# #################
# AVERAGE TRAIN LOSS: 0.4003426432609558
# AVERAGE VAL LOSS: 0.4987136423587799
# #################
# # EPOCH 40
# #################
# AVERAGE TRAIN LOSS: 0.3958132863044739
# AVERAGE VAL LOSS: 0.4957365393638611
# #################
# # EPOCH 41
# #################
# AVERAGE TRAIN LOSS: 0.3914847671985626
# AVERAGE VAL LOSS: 0.49267396330833435
# #################
# # EPOCH 42
# #################
# AVERAGE TRAIN LOSS: 0.38733917474746704
# AVERAGE VAL LOSS: 0.48954886198043823
# #################
# # EPOCH 43
# #################
# AVERAGE TRAIN LOSS: 0.38338249921798706
# AVERAGE VAL LOSS: 0.4864022731781006
# #################
# # EPOCH 44
# #################
# AVERAGE TRAIN LOSS: 0.3796176612377167
# AVERAGE VAL LOSS: 0.48324620723724365
# #################
# # EPOCH 45
# #################
# AVERAGE TRAIN LOSS: 0.3760314881801605
# AVERAGE VAL LOSS: 0.48007380962371826
# #################
# # EPOCH 46
# #################
# AVERAGE TRAIN LOSS: 0.37259045243263245
# AVERAGE VAL LOSS: 0.47688543796539307
# #################
# # EPOCH 47
# #################
# AVERAGE TRAIN LOSS: 0.3692411780357361
# AVERAGE VAL LOSS: 0.4736778140068054
# #################
# # EPOCH 48
# #################
# AVERAGE TRAIN LOSS: 0.36593613028526306
# AVERAGE VAL LOSS: 0.4704385995864868
# #################
# # EPOCH 49
# #################
# AVERAGE TRAIN LOSS: 0.3626529276371002
# AVERAGE VAL LOSS: 0.46715521812438965
# #################
# # EPOCH 50
# #################
# AVERAGE TRAIN LOSS: 0.35939544439315796
# AVERAGE VAL LOSS: 0.46381694078445435
# #################
# # EPOCH 51
# #################
# AVERAGE TRAIN LOSS: 0.3561781644821167
# AVERAGE VAL LOSS: 0.460414856672287
# #################
# # EPOCH 52
# #################
# AVERAGE TRAIN LOSS: 0.35300612449645996
# AVERAGE VAL LOSS: 0.4569399654865265
# #################
# # EPOCH 53
# #################
# AVERAGE TRAIN LOSS: 0.3498693108558655
# AVERAGE VAL LOSS: 0.45338699221611023
# #################
# # EPOCH 54
# #################
# AVERAGE TRAIN LOSS: 0.3467333912849426
# AVERAGE VAL LOSS: 0.4497663974761963
# #################
# # EPOCH 55
# #################
# AVERAGE TRAIN LOSS: 0.34354084730148315
# AVERAGE VAL LOSS: 0.4461160898208618
# #################
# # EPOCH 56
# #################
# AVERAGE TRAIN LOSS: 0.3402421772480011
# AVERAGE VAL LOSS: 0.44253531098365784
# #################
# # EPOCH 57
# #################
# AVERAGE TRAIN LOSS: 0.33684834837913513
# AVERAGE VAL LOSS: 0.43923476338386536
# #################
# # EPOCH 58
# #################
# AVERAGE TRAIN LOSS: 0.33350566029548645
# AVERAGE VAL LOSS: 0.436544269323349
# #################
# # EPOCH 59
# #################
# AVERAGE TRAIN LOSS: 0.3304790258407593
# AVERAGE VAL LOSS: 0.43472015857696533
# #################
# # EPOCH 60
# #################
# AVERAGE TRAIN LOSS: 0.3279309570789337
# AVERAGE VAL LOSS: 0.4336124360561371
# #################
# # EPOCH 61
# #################
# AVERAGE TRAIN LOSS: 0.3257267475128174
# AVERAGE VAL LOSS: 0.4327003061771393
# #################
# # EPOCH 62
# #################
# AVERAGE TRAIN LOSS: 0.32356980443000793
# AVERAGE VAL LOSS: 0.4315110146999359
# #################
# # EPOCH 63
# #################
# AVERAGE TRAIN LOSS: 0.32124367356300354
# AVERAGE VAL LOSS: 0.42980507016181946
# #################
# # EPOCH 64
# #################
# AVERAGE TRAIN LOSS: 0.31865087151527405
# AVERAGE VAL LOSS: 0.42750245332717896
# #################
# # EPOCH 65
# #################
# AVERAGE TRAIN LOSS: 0.3157653212547302
# AVERAGE VAL LOSS: 0.4246663749217987
# #################
# # EPOCH 66
# #################
# AVERAGE TRAIN LOSS: 0.3126606345176697
# AVERAGE VAL LOSS: 0.4215274155139923
# #################
# # EPOCH 67
# #################
# AVERAGE TRAIN LOSS: 0.309542715549469
# AVERAGE VAL LOSS: 0.4183975160121918
# #################
# # EPOCH 68
# #################
# AVERAGE TRAIN LOSS: 0.3066798448562622
# AVERAGE VAL LOSS: 0.4155134856700897
# #################
# # EPOCH 69
# #################
# AVERAGE TRAIN LOSS: 0.30427682399749756
# AVERAGE VAL LOSS: 0.41296806931495667
# #################
# # EPOCH 70
# #################
# AVERAGE TRAIN LOSS: 0.3023909032344818
# AVERAGE VAL LOSS: 0.4107591509819031
# #################
# # EPOCH 71
# #################
# AVERAGE TRAIN LOSS: 0.3009357750415802
# AVERAGE VAL LOSS: 0.4088692367076874
# #################
# # EPOCH 72
# #################
# AVERAGE TRAIN LOSS: 0.2997433841228485
# AVERAGE VAL LOSS: 0.4073069095611572
# #################
# # EPOCH 73
# #################
# AVERAGE TRAIN LOSS: 0.2986301779747009
# AVERAGE VAL LOSS: 0.40609607100486755
# #################
# # EPOCH 74
# #################
# AVERAGE TRAIN LOSS: 0.2974434494972229
# AVERAGE VAL LOSS: 0.405222624540329
# #################
# # EPOCH 75
# #################
# AVERAGE TRAIN LOSS: 0.2960785925388336
# AVERAGE VAL LOSS: 0.4045582711696625
# #################
# # EPOCH 76
# #################
# AVERAGE TRAIN LOSS: 0.2944697439670563
# AVERAGE VAL LOSS: 0.40381476283073425
# #################
# # EPOCH 77
# #################
# AVERAGE TRAIN LOSS: 0.29256656765937805
# AVERAGE VAL LOSS: 0.40261149406433105
# #################
# # EPOCH 78
# #################
# AVERAGE TRAIN LOSS: 0.2903195917606354
# AVERAGE VAL LOSS: 0.4006733000278473
# #################
# # EPOCH 79
# #################
# AVERAGE TRAIN LOSS: 0.2877083718776703
# AVERAGE VAL LOSS: 0.3980312645435333
# #################
# # EPOCH 80
# #################
# AVERAGE TRAIN LOSS: 0.2848096787929535
# AVERAGE VAL LOSS: 0.3950260877609253
# #################
# # EPOCH 81
# #################
# AVERAGE TRAIN LOSS: 0.28183621168136597
# AVERAGE VAL LOSS: 0.39208754897117615
# #################
# # EPOCH 82
# #################
# AVERAGE TRAIN LOSS: 0.27907976508140564
# AVERAGE VAL LOSS: 0.38950541615486145
# #################
# # EPOCH 83
# #################
# AVERAGE TRAIN LOSS: 0.27678847312927246
# AVERAGE VAL LOSS: 0.38737478852272034
# #################
# # EPOCH 84
# #################
# AVERAGE TRAIN LOSS: 0.2750743627548218
# AVERAGE VAL LOSS: 0.38567814230918884
# #################
# # EPOCH 85
# #################
# AVERAGE TRAIN LOSS: 0.2739024758338928
# AVERAGE VAL LOSS: 0.38437363505363464
# #################
# # EPOCH 86
# #################
# AVERAGE TRAIN LOSS: 0.2731371521949768
# AVERAGE VAL LOSS: 0.38343605399131775
# #################
# # EPOCH 87
# #################
# AVERAGE TRAIN LOSS: 0.2726002633571625
# AVERAGE VAL LOSS: 0.38285553455352783
# #################
# # EPOCH 88
# #################
# AVERAGE TRAIN LOSS: 0.2721154987812042
# AVERAGE VAL LOSS: 0.3826007544994354
# #################
# # EPOCH 89
# #################
# AVERAGE TRAIN LOSS: 0.271531879901886
# AVERAGE VAL LOSS: 0.3825484812259674
# #################
# # EPOCH 90
# #################
# AVERAGE TRAIN LOSS: 0.27072396874427795
# AVERAGE VAL LOSS: 0.38240817189216614
# #################
# # EPOCH 91
# #################
# AVERAGE TRAIN LOSS: 0.2695735692977905
# AVERAGE VAL LOSS: 0.3817247450351715
# #################
# # EPOCH 92
# #################
# AVERAGE TRAIN LOSS: 0.2679532468318939
# AVERAGE VAL LOSS: 0.38004517555236816
# #################
# # EPOCH 93
# #################
# AVERAGE TRAIN LOSS: 0.26575201749801636
# AVERAGE VAL LOSS: 0.3772144019603729
# #################
# # EPOCH 94
# #################
# AVERAGE TRAIN LOSS: 0.2629619538784027
# AVERAGE VAL LOSS: 0.3735564351081848
# #################
# # EPOCH 95
# #################
# AVERAGE TRAIN LOSS: 0.2597673535346985
# AVERAGE VAL LOSS: 0.36970973014831543
# #################
# # EPOCH 96
# #################
# AVERAGE TRAIN LOSS: 0.2565322518348694
# AVERAGE VAL LOSS: 0.36623772978782654
# #################
# # EPOCH 97
# #################
# AVERAGE TRAIN LOSS: 0.25365984439849854
# AVERAGE VAL LOSS: 0.36339065432548523
# #################
# # EPOCH 98
# #################
# AVERAGE TRAIN LOSS: 0.2514283061027527
# AVERAGE VAL LOSS: 0.3611597716808319
# #################
# # EPOCH 99
# #################
# AVERAGE TRAIN LOSS: 0.24991671741008759
# AVERAGE VAL LOSS: 0.3594447672367096
# #################
# # EPOCH 100
# #################
# AVERAGE TRAIN LOSS: 0.24903401732444763
# AVERAGE VAL LOSS: 0.35816341638565063
# #################
# # EPOCH 101
# #################
# AVERAGE TRAIN LOSS: 0.2485916167497635
# AVERAGE VAL LOSS: 0.3572867214679718
# #################
# # EPOCH 102
# #################
# AVERAGE TRAIN LOSS: 0.24837276339530945
# AVERAGE VAL LOSS: 0.35683631896972656
# #################
# # EPOCH 103
# #################
# AVERAGE TRAIN LOSS: 0.2481844425201416
# AVERAGE VAL LOSS: 0.3568541705608368
# #################
# # EPOCH 104
# #################
# AVERAGE TRAIN LOSS: 0.2478867769241333
# AVERAGE VAL LOSS: 0.3573295474052429
# #################
# # EPOCH 105
# #################
# AVERAGE TRAIN LOSS: 0.24739308655261993
# AVERAGE VAL LOSS: 0.3580811321735382
# #################
# # EPOCH 106
# #################
# AVERAGE TRAIN LOSS: 0.24663396179676056
# AVERAGE VAL LOSS: 0.35865238308906555
# #################
# # EPOCH 107
# #################
# AVERAGE TRAIN LOSS: 0.24550223350524902
# AVERAGE VAL LOSS: 0.3583555519580841
# #################
# # EPOCH 108
# #################
# AVERAGE TRAIN LOSS: 0.2438279688358307
# AVERAGE VAL LOSS: 0.3565760850906372
# #################
# # EPOCH 109
# #################
# AVERAGE TRAIN LOSS: 0.24144430458545685
# AVERAGE VAL LOSS: 0.3532165586948395
# #################
# # EPOCH 110
# #################
# AVERAGE TRAIN LOSS: 0.2383347451686859
# AVERAGE VAL LOSS: 0.3488779067993164
# #################
# # EPOCH 111
# #################
# AVERAGE TRAIN LOSS: 0.2347492277622223
# AVERAGE VAL LOSS: 0.34450072050094604
# #################
# # EPOCH 112
# #################
# AVERAGE TRAIN LOSS: 0.23116128146648407
# AVERAGE VAL LOSS: 0.3407801687717438
# #################
# # EPOCH 113
# #################
# AVERAGE TRAIN LOSS: 0.2280747890472412
# AVERAGE VAL LOSS: 0.33791691064834595
# #################
# # EPOCH 114
# #################
# AVERAGE TRAIN LOSS: 0.22582349181175232
# AVERAGE VAL LOSS: 0.3357927203178406
# #################
# # EPOCH 115
# #################
# AVERAGE TRAIN LOSS: 0.2244921177625656
# AVERAGE VAL LOSS: 0.3342301845550537
# #################
# # EPOCH 116
# #################
# AVERAGE TRAIN LOSS: 0.22395849227905273
# AVERAGE VAL LOSS: 0.33311939239501953
# #################
# # EPOCH 117
# #################
# AVERAGE TRAIN LOSS: 0.22398221492767334
# AVERAGE VAL LOSS: 0.3324417173862457
# #################
# # EPOCH 118
# #################
# AVERAGE TRAIN LOSS: 0.22428837418556213
# AVERAGE VAL LOSS: 0.33226868510246277
# #################
# # EPOCH 119
# #################
# AVERAGE TRAIN LOSS: 0.2246369868516922
# AVERAGE VAL LOSS: 0.3327482342720032
# #################
# # EPOCH 120
# #################
# AVERAGE TRAIN LOSS: 0.22487382590770721
# AVERAGE VAL LOSS: 0.3340419828891754
# #################
# # EPOCH 121
# #################
# AVERAGE TRAIN LOSS: 0.22494609653949738
# AVERAGE VAL LOSS: 0.3361605405807495
# #################
# # EPOCH 122
# #################
# AVERAGE TRAIN LOSS: 0.2248542308807373
# AVERAGE VAL LOSS: 0.338692843914032
# #################
# # EPOCH 123
# #################
# AVERAGE TRAIN LOSS: 0.2245282232761383
# AVERAGE VAL LOSS: 0.34060168266296387
# #################
# # EPOCH 124
# #################
# AVERAGE TRAIN LOSS: 0.2237018346786499
# AVERAGE VAL LOSS: 0.34046250581741333
# #################
# # EPOCH 125
# #################
# AVERAGE TRAIN LOSS: 0.22194643318653107
# AVERAGE VAL LOSS: 0.3373628556728363
# #################
# # EPOCH 126
# #################
# AVERAGE TRAIN LOSS: 0.21894678473472595
# AVERAGE VAL LOSS: 0.3318603038787842
# #################
# # EPOCH 127
# #################
# AVERAGE TRAIN LOSS: 0.21483507752418518
# AVERAGE VAL LOSS: 0.3257720172405243
# #################
# # EPOCH 128
# #################
# AVERAGE TRAIN LOSS: 0.21027597784996033
# AVERAGE VAL LOSS: 0.3207421898841858
# #################
# # EPOCH 129
# #################
# AVERAGE TRAIN LOSS: 0.2061876505613327
# AVERAGE VAL LOSS: 0.31724783778190613
# #################
# # EPOCH 130
# #################
# AVERAGE TRAIN LOSS: 0.2032913863658905
# AVERAGE VAL LOSS: 0.3149351477622986
# #################
# # EPOCH 131
# #################
# AVERAGE TRAIN LOSS: 0.20184102654457092
# AVERAGE VAL LOSS: 0.31336748600006104
# #################
# # EPOCH 132
# #################
# AVERAGE TRAIN LOSS: 0.2016684114933014
# AVERAGE VAL LOSS: 0.3123328685760498
# #################
# # EPOCH 133
# #################
# AVERAGE TRAIN LOSS: 0.2023821771144867
# AVERAGE VAL LOSS: 0.31179165840148926
# #################
# # EPOCH 134
# #################
# AVERAGE TRAIN LOSS: 0.20353369414806366
# AVERAGE VAL LOSS: 0.31179893016815186
# #################
# # EPOCH 135
# #################
# AVERAGE TRAIN LOSS: 0.20471243560314178
# AVERAGE VAL LOSS: 0.31250685453414917
# #################
# # EPOCH 136
# #################
# AVERAGE TRAIN LOSS: 0.20562370121479034
# AVERAGE VAL LOSS: 0.31417256593704224
# #################
# # EPOCH 137
# #################
# AVERAGE TRAIN LOSS: 0.20616665482521057
# AVERAGE VAL LOSS: 0.317056268453598
# #################
# # EPOCH 138
# #################
# AVERAGE TRAIN LOSS: 0.20645275712013245
# AVERAGE VAL LOSS: 0.32107505202293396
# #################
# # EPOCH 139
# #################
# AVERAGE TRAIN LOSS: 0.206650048494339
# AVERAGE VAL LOSS: 0.32522156834602356
# #################
# # EPOCH 140
# #################
# AVERAGE TRAIN LOSS: 0.2066323310136795
# AVERAGE VAL LOSS: 0.3273499608039856
# #################
# # EPOCH 141
# #################
# AVERAGE TRAIN LOSS: 0.20575955510139465
# AVERAGE VAL LOSS: 0.32527926564216614
# #################
# # EPOCH 142
# #################
# AVERAGE TRAIN LOSS: 0.2032407820224762
# AVERAGE VAL LOSS: 0.3189513087272644
# #################
# # EPOCH 143
# #################
# AVERAGE TRAIN LOSS: 0.19890229403972626
# AVERAGE VAL LOSS: 0.31112927198410034
# #################
# # EPOCH 144
# #################
# AVERAGE TRAIN LOSS: 0.19356243312358856
# AVERAGE VAL LOSS: 0.3048930764198303
# #################
# # EPOCH 145
# #################
# AVERAGE TRAIN LOSS: 0.18862274289131165
# AVERAGE VAL LOSS: 0.3010982871055603
# #################
# # EPOCH 146
# #################
# AVERAGE TRAIN LOSS: 0.1852383017539978
# AVERAGE VAL LOSS: 0.2989356815814972
# #################
# # EPOCH 147
# #################
# AVERAGE TRAIN LOSS: 0.18380247056484222
# AVERAGE VAL LOSS: 0.29760685563087463
# #################
# # EPOCH 148
# #################
# AVERAGE TRAIN LOSS: 0.18405550718307495
# AVERAGE VAL LOSS: 0.2968885898590088
# #################
# # EPOCH 149
# #################
# AVERAGE TRAIN LOSS: 0.18545134365558624
# AVERAGE VAL LOSS: 0.2968488037586212
# #################
# # EPOCH 150
# #################
# AVERAGE TRAIN LOSS: 0.18739230930805206
# AVERAGE VAL LOSS: 0.2975519299507141
# #################
# # EPOCH 151
# #################
# AVERAGE TRAIN LOSS: 0.18931089341640472
# AVERAGE VAL LOSS: 0.29909780621528625
# #################
# # EPOCH 152
# #################
# AVERAGE TRAIN LOSS: 0.19078005850315094
# AVERAGE VAL LOSS: 0.3017590045928955
# #################
# # EPOCH 153
# #################
# AVERAGE TRAIN LOSS: 0.1916612982749939
# AVERAGE VAL LOSS: 0.30587655305862427
# #################
# # EPOCH 154
# #################
# AVERAGE TRAIN LOSS: 0.19216719269752502
# AVERAGE VAL LOSS: 0.3113265335559845
# #################
# # EPOCH 155
# #################
# AVERAGE TRAIN LOSS: 0.19266648590564728
# AVERAGE VAL LOSS: 0.3166796565055847
# #################
# # EPOCH 156
# #################
# AVERAGE TRAIN LOSS: 0.1931115984916687
# AVERAGE VAL LOSS: 0.3189995288848877
# #################
# # EPOCH 157
# #################
# AVERAGE TRAIN LOSS: 0.19256731867790222
# AVERAGE VAL LOSS: 0.31562069058418274
# #################
# # EPOCH 158
# #################
# AVERAGE TRAIN LOSS: 0.18977674841880798
# AVERAGE VAL LOSS: 0.30723869800567627
# #################
# # EPOCH 159
# #################
# AVERAGE TRAIN LOSS: 0.18457162380218506
# AVERAGE VAL LOSS: 0.29817843437194824
# #################
# # EPOCH 160
# #################
# AVERAGE TRAIN LOSS: 0.17842987179756165
# AVERAGE VAL LOSS: 0.2920341193675995
# #################
# # EPOCH 161
# #################
# AVERAGE TRAIN LOSS: 0.17340093851089478
# AVERAGE VAL LOSS: 0.28887316584587097
# #################
# # EPOCH 162
# #################
# AVERAGE TRAIN LOSS: 0.17065604031085968
# AVERAGE VAL LOSS: 0.2872292995452881
# #################
# # EPOCH 163
# #################
# AVERAGE TRAIN LOSS: 0.1701556146144867
# AVERAGE VAL LOSS: 0.2863065004348755
# #################
# # EPOCH 164
# #################
# AVERAGE TRAIN LOSS: 0.17124906182289124
# AVERAGE VAL LOSS: 0.28616464138031006
# #################
# # EPOCH 165
# #################
# AVERAGE TRAIN LOSS: 0.17322808504104614
# AVERAGE VAL LOSS: 0.2870422601699829
# #################
# # EPOCH 166
# #################
# AVERAGE TRAIN LOSS: 0.17546236515045166
# AVERAGE VAL LOSS: 0.2889942228794098
# #################
# # EPOCH 167
# #################
# AVERAGE TRAIN LOSS: 0.17742767930030823
# AVERAGE VAL LOSS: 0.29208144545555115
# #################
# # EPOCH 168
# #################
# AVERAGE TRAIN LOSS: 0.1788710057735443
# AVERAGE VAL LOSS: 0.296499639749527
# #################
# # EPOCH 169
# #################
# AVERAGE TRAIN LOSS: 0.1799076795578003
# AVERAGE VAL LOSS: 0.30217623710632324
# #################
# # EPOCH 170
# #################
# AVERAGE TRAIN LOSS: 0.1808590143918991
# AVERAGE VAL LOSS: 0.308009535074234
# #################
# # EPOCH 171
# #################
# AVERAGE TRAIN LOSS: 0.18180938065052032
# AVERAGE VAL LOSS: 0.31147512793540955
# #################
# # EPOCH 172
# #################
# AVERAGE TRAIN LOSS: 0.18206962943077087
# AVERAGE VAL LOSS: 0.3096761405467987
# #################
# # EPOCH 173
# #################
# AVERAGE TRAIN LOSS: 0.18029913306236267
# AVERAGE VAL LOSS: 0.30213797092437744
# #################
# # EPOCH 174
# #################
# AVERAGE TRAIN LOSS: 0.17580294609069824
# AVERAGE VAL LOSS: 0.2924381494522095
# #################
# # EPOCH 175
# #################
# AVERAGE TRAIN LOSS: 0.16968588531017303
# AVERAGE VAL LOSS: 0.2849821150302887
# #################
# # EPOCH 176
# #################
# AVERAGE TRAIN LOSS: 0.16415372490882874
# AVERAGE VAL LOSS: 0.2808895409107208
# #################
# # EPOCH 177
# #################
# AVERAGE TRAIN LOSS: 0.16078609228134155
# AVERAGE VAL LOSS: 0.2788216769695282
# #################
# # EPOCH 178
# #################
# AVERAGE TRAIN LOSS: 0.15979686379432678
# AVERAGE VAL LOSS: 0.2776966989040375
# #################
# # EPOCH 179
# #################
# AVERAGE TRAIN LOSS: 0.16056478023529053
# AVERAGE VAL LOSS: 0.27745628356933594
# #################
# # EPOCH 180
# #################
# AVERAGE TRAIN LOSS: 0.16235291957855225
# AVERAGE VAL LOSS: 0.2784069776535034
# #################
# # EPOCH 181
# #################
# AVERAGE TRAIN LOSS: 0.1645452082157135
# AVERAGE VAL LOSS: 0.2806447148323059
# #################
# # EPOCH 182
# #################
# AVERAGE TRAIN LOSS: 0.16663870215415955
# AVERAGE VAL LOSS: 0.2841637134552002
# #################
# # EPOCH 183
# #################
# AVERAGE TRAIN LOSS: 0.16836977005004883
# AVERAGE VAL LOSS: 0.2890569567680359
# #################
# # EPOCH 184
# #################
# AVERAGE TRAIN LOSS: 0.16981641948223114
# AVERAGE VAL LOSS: 0.29517805576324463
# #################
# # EPOCH 185
# #################
# AVERAGE TRAIN LOSS: 0.17123490571975708
# AVERAGE VAL LOSS: 0.3014219105243683
# #################
# # EPOCH 186
# #################
# AVERAGE TRAIN LOSS: 0.17265665531158447
# AVERAGE VAL LOSS: 0.3053300976753235
# #################
# # EPOCH 187
# #################
# AVERAGE TRAIN LOSS: 0.17340274155139923
# AVERAGE VAL LOSS: 0.3039502203464508
# #################
# # EPOCH 188
# #################
# AVERAGE TRAIN LOSS: 0.17210343480110168
# AVERAGE VAL LOSS: 0.29647839069366455
# #################
# # EPOCH 189
# #################
# AVERAGE TRAIN LOSS: 0.1678796112537384
# AVERAGE VAL LOSS: 0.2862927317619324
# #################
# # EPOCH 190
# #################
# AVERAGE TRAIN LOSS: 0.16171345114707947
# AVERAGE VAL LOSS: 0.2781580984592438
# #################
# # EPOCH 191
# #################
# AVERAGE TRAIN LOSS: 0.1559504121541977
# AVERAGE VAL LOSS: 0.27361252903938293
# #################
# # EPOCH 192
# #################
# AVERAGE TRAIN LOSS: 0.1523713767528534
# AVERAGE VAL LOSS: 0.27133357524871826
# #################
# # EPOCH 193
# #################
# AVERAGE TRAIN LOSS: 0.1512441635131836
# AVERAGE VAL LOSS: 0.27012205123901367
# #################
# # EPOCH 194
# #################
# AVERAGE TRAIN LOSS: 0.15190857648849487
# AVERAGE VAL LOSS: 0.2699500024318695
# #################
# # EPOCH 195
# #################
# AVERAGE TRAIN LOSS: 0.1536206156015396
# AVERAGE VAL LOSS: 0.27122196555137634
# #################
# # EPOCH 196
# #################
# AVERAGE TRAIN LOSS: 0.1558000147342682
# AVERAGE VAL LOSS: 0.2740525007247925
# #################
# # EPOCH 197
# #################
# AVERAGE TRAIN LOSS: 0.15798404812812805
# AVERAGE VAL LOSS: 0.2783619165420532
# #################
# # EPOCH 198
# #################
# AVERAGE TRAIN LOSS: 0.15995337069034576
# AVERAGE VAL LOSS: 0.28409314155578613
# #################
# # EPOCH 199
# #################
# AVERAGE TRAIN LOSS: 0.16179291903972626
# AVERAGE VAL LOSS: 0.2908421754837036
# #################
# # EPOCH 200
# #################
# AVERAGE TRAIN LOSS: 0.16366901993751526
# AVERAGE VAL LOSS: 0.2971961498260498
# #################
# # EPOCH 201
# #################
# AVERAGE TRAIN LOSS: 0.165434330701828
# AVERAGE VAL LOSS: 0.30046921968460083
# #################
# # EPOCH 202
# #################
# AVERAGE TRAIN LOSS: 0.16622315347194672
# AVERAGE VAL LOSS: 0.29780590534210205
# #################
# # EPOCH 203
# #################
# AVERAGE TRAIN LOSS: 0.16458876430988312
# AVERAGE VAL LOSS: 0.2890361547470093
# #################
# # EPOCH 204
# #################
# AVERAGE TRAIN LOSS: 0.15984883904457092
# AVERAGE VAL LOSS: 0.2783415615558624
# #################
# # EPOCH 205
# #################
# AVERAGE TRAIN LOSS: 0.15340062975883484
# AVERAGE VAL LOSS: 0.27048829197883606
# #################
# # EPOCH 206
# #################
# AVERAGE TRAIN LOSS: 0.14780516922473907
# AVERAGE VAL LOSS: 0.26637569069862366
# #################
# # EPOCH 207
# #################
# AVERAGE TRAIN LOSS: 0.14464101195335388
# AVERAGE VAL LOSS: 0.2643328607082367
# #################
# # EPOCH 208
# #################
# AVERAGE TRAIN LOSS: 0.14387038350105286
# AVERAGE VAL LOSS: 0.26332879066467285
# #################
# # EPOCH 209
# #################
# AVERAGE TRAIN LOSS: 0.1447334736585617
# AVERAGE VAL LOSS: 0.2636473774909973
# #################
# # EPOCH 210
# #################
# AVERAGE TRAIN LOSS: 0.1465795338153839
# AVERAGE VAL LOSS: 0.2657944858074188
# #################
# # EPOCH 211
# #################
# AVERAGE TRAIN LOSS: 0.14889350533485413
# AVERAGE VAL LOSS: 0.2697739899158478
# #################
# # EPOCH 212
# #################
# AVERAGE TRAIN LOSS: 0.15126287937164307
# AVERAGE VAL LOSS: 0.2754008173942566
# #################
# # EPOCH 213
# #################
# AVERAGE TRAIN LOSS: 0.1535467803478241
# AVERAGE VAL LOSS: 0.282381147146225
# #################
# # EPOCH 214
# #################
# AVERAGE TRAIN LOSS: 0.15585514903068542
# AVERAGE VAL LOSS: 0.2898205518722534
# #################
# # EPOCH 215
# #################
# AVERAGE TRAIN LOSS: 0.15817907452583313
# AVERAGE VAL LOSS: 0.2955147624015808
# #################
# # EPOCH 216
# #################
# AVERAGE TRAIN LOSS: 0.16000811755657196
# AVERAGE VAL LOSS: 0.2962592840194702
# #################
# # EPOCH 217
# #################
# AVERAGE TRAIN LOSS: 0.16002757847309113
# AVERAGE VAL LOSS: 0.289821594953537
# #################
# # EPOCH 218
# #################
# AVERAGE TRAIN LOSS: 0.15680798888206482
# AVERAGE VAL LOSS: 0.27846625447273254
# #################
# # EPOCH 219
# #################
# AVERAGE TRAIN LOSS: 0.15061675012111664
# AVERAGE VAL LOSS: 0.2680079936981201
# #################
# # EPOCH 220
# #################
# AVERAGE TRAIN LOSS: 0.14396129548549652
# AVERAGE VAL LOSS: 0.2619748115539551
# #################
# # EPOCH 221
# #################
# AVERAGE TRAIN LOSS: 0.13932375609874725
# AVERAGE VAL LOSS: 0.2591788172721863
# #################
# # EPOCH 222
# #################
# AVERAGE TRAIN LOSS: 0.13741707801818848
# AVERAGE VAL LOSS: 0.2577100992202759
# #################
# # EPOCH 223
# #################
# AVERAGE TRAIN LOSS: 0.13752245903015137
# AVERAGE VAL LOSS: 0.25740811228752136
# #################
# # EPOCH 224
# #################
# AVERAGE TRAIN LOSS: 0.1390172243118286
# AVERAGE VAL LOSS: 0.25917667150497437
# #################
# # EPOCH 225
# #################
# AVERAGE TRAIN LOSS: 0.14133238792419434
# AVERAGE VAL LOSS: 0.26320353150367737
# #################
# # EPOCH 226
# #################
# AVERAGE TRAIN LOSS: 0.1440383493900299
# AVERAGE VAL LOSS: 0.2693691551685333
# #################
# # EPOCH 227
# #################
# AVERAGE TRAIN LOSS: 0.14673548936843872
# AVERAGE VAL LOSS: 0.27699536085128784
# #################
# # EPOCH 228
# #################
# AVERAGE TRAIN LOSS: 0.14958623051643372
# AVERAGE VAL LOSS: 0.2855525314807892
# #################
# # EPOCH 229
# #################
# AVERAGE TRAIN LOSS: 0.1524168699979782
# AVERAGE VAL LOSS: 0.2921246290206909
# #################
# # EPOCH 230
# #################
# AVERAGE TRAIN LOSS: 0.15482614934444427
# AVERAGE VAL LOSS: 0.29398977756500244
# #################
# # EPOCH 231
# #################
# AVERAGE TRAIN LOSS: 0.15535582602024078
# AVERAGE VAL LOSS: 0.28709232807159424
# #################
# # EPOCH 232
# #################
# AVERAGE TRAIN LOSS: 0.15237191319465637
# AVERAGE VAL LOSS: 0.275179922580719
# #################
# # EPOCH 233
# #################
# AVERAGE TRAIN LOSS: 0.14599928259849548
# AVERAGE VAL LOSS: 0.26291462779045105
# #################
# # EPOCH 234
# #################
# AVERAGE TRAIN LOSS: 0.1389847695827484
# AVERAGE VAL LOSS: 0.2569482922554016
# #################
# # EPOCH 235
# #################
# AVERAGE TRAIN LOSS: 0.13385434448719025
# AVERAGE VAL LOSS: 0.2550622820854187
# #################
# # EPOCH 236
# #################
# AVERAGE TRAIN LOSS: 0.13296625018119812
# AVERAGE VAL LOSS: 0.25320908427238464
# #################
# # EPOCH 237
# #################
# AVERAGE TRAIN LOSS: 0.13196122646331787
# AVERAGE VAL LOSS: 0.25297293066978455
# #################
# # EPOCH 238
# #################
# AVERAGE TRAIN LOSS: 0.1344333440065384
# AVERAGE VAL LOSS: 0.2543890178203583
# #################
# # EPOCH 239
# #################
# AVERAGE TRAIN LOSS: 0.1362803727388382
# AVERAGE VAL LOSS: 0.25789251923561096
# #################
# # EPOCH 240
# #################
# AVERAGE TRAIN LOSS: 0.14004454016685486
# AVERAGE VAL LOSS: 0.26489782333374023
# #################
# # EPOCH 241
# #################
# AVERAGE TRAIN LOSS: 0.1422829031944275
# AVERAGE VAL LOSS: 0.27165624499320984
# #################
# # EPOCH 242
# #################
# AVERAGE TRAIN LOSS: 0.14633074402809143
# AVERAGE VAL LOSS: 0.28298938274383545
# #################
# # EPOCH 243
# #################
# AVERAGE TRAIN LOSS: 0.14902076125144958
# AVERAGE VAL LOSS: 0.28549832105636597
# #################
# # EPOCH 244
# #################
# AVERAGE TRAIN LOSS: 0.15239210426807404
# AVERAGE VAL LOSS: 0.29277846217155457
# #################
# # EPOCH 245
# #################
# AVERAGE TRAIN LOSS: 0.15415862202644348
# AVERAGE VAL LOSS: 0.27900558710098267
# #################
# # EPOCH 246
# #################
# AVERAGE TRAIN LOSS: 0.15382802486419678
# AVERAGE VAL LOSS: 0.27544066309928894
# #################
# # EPOCH 247
# #################
# AVERAGE TRAIN LOSS: 0.14723263680934906
# AVERAGE VAL LOSS: 0.26070883870124817
# #################
# # EPOCH 248
# #################
# AVERAGE TRAIN LOSS: 0.14370420575141907
# AVERAGE VAL LOSS: 0.2712285816669464
# #################
# # EPOCH 249
# #################
# AVERAGE TRAIN LOSS: 0.1361255794763565
# AVERAGE VAL LOSS: 0.26005297899246216
# #################
# # EPOCH 250
# #################
# AVERAGE TRAIN LOSS: 0.135391503572464
# AVERAGE VAL LOSS: 0.27602648735046387
# #################
# # EPOCH 251
# #################
# AVERAGE TRAIN LOSS: 0.13251282274723053
# AVERAGE VAL LOSS: 0.25553005933761597
# #################
# # EPOCH 252
# #################
# AVERAGE TRAIN LOSS: 0.13470163941383362
# AVERAGE VAL LOSS: 0.2726132571697235
# #################
# # EPOCH 253
# #################
# AVERAGE TRAIN LOSS: 0.1350112110376358
# AVERAGE VAL LOSS: 0.2637925148010254
# #################
# # EPOCH 254
# #################
# AVERAGE TRAIN LOSS: 0.13960835337638855
# AVERAGE VAL LOSS: 0.2845664918422699
# #################
# # EPOCH 255
# #################
# AVERAGE TRAIN LOSS: 0.14185504615306854
# AVERAGE VAL LOSS: 0.2852412462234497
# #################
# # EPOCH 256
# #################
# AVERAGE TRAIN LOSS: 0.14661811292171478
# AVERAGE VAL LOSS: 0.29758766293525696
# #################
# # EPOCH 257
# #################
# AVERAGE TRAIN LOSS: 0.14867043495178223
# AVERAGE VAL LOSS: 0.28877073526382446
# #################
# # EPOCH 258
# #################
# AVERAGE TRAIN LOSS: 0.14785358309745789
# AVERAGE VAL LOSS: 0.27629441022872925
# #################
# # EPOCH 259
# #################
# AVERAGE TRAIN LOSS: 0.1407139152288437
# AVERAGE VAL LOSS: 0.25808554887771606
# #################
# # EPOCH 260
# #################
# AVERAGE TRAIN LOSS: 0.1310330033302307
# AVERAGE VAL LOSS: 0.24929630756378174
# #################
# # EPOCH 261
# #################
# AVERAGE TRAIN LOSS: 0.12419728189706802
# AVERAGE VAL LOSS: 0.24669679999351501
# #################
# # EPOCH 262
# #################
# AVERAGE TRAIN LOSS: 0.12072428315877914
# AVERAGE VAL LOSS: 0.24479013681411743
# #################
# # EPOCH 263
# #################
# AVERAGE TRAIN LOSS: 0.12072409689426422
# AVERAGE VAL LOSS: 0.24500419199466705
# #################
# # EPOCH 264
# #################
# AVERAGE TRAIN LOSS: 0.12261960655450821
# AVERAGE VAL LOSS: 0.2477393001317978
# #################
# # EPOCH 265
# #################
# AVERAGE TRAIN LOSS: 0.12567345798015594
# AVERAGE VAL LOSS: 0.25629934668540955
# #################
# # EPOCH 266
# #################
# AVERAGE TRAIN LOSS: 0.12975835800170898
# AVERAGE VAL LOSS: 0.26605021953582764
# #################
# # EPOCH 267
# #################
# AVERAGE TRAIN LOSS: 0.134266197681427
# AVERAGE VAL LOSS: 0.2791852355003357
# #################
# # EPOCH 268
# #################
# AVERAGE TRAIN LOSS: 0.13862283527851105
# AVERAGE VAL LOSS: 0.2860121428966522
# #################
# # EPOCH 269
# #################
# AVERAGE TRAIN LOSS: 0.14229898154735565
# AVERAGE VAL LOSS: 0.28887978196144104
# #################
# # EPOCH 270
# #################
# AVERAGE TRAIN LOSS: 0.1432407945394516
# AVERAGE VAL LOSS: 0.27492013573646545
# #################
# # EPOCH 271
# #################
# AVERAGE TRAIN LOSS: 0.13818691670894623
# AVERAGE VAL LOSS: 0.262228786945343
# #################
# # EPOCH 272
# #################
# AVERAGE TRAIN LOSS: 0.13056707382202148
# AVERAGE VAL LOSS: 0.2479894608259201
# #################
# # EPOCH 273
# #################
# AVERAGE TRAIN LOSS: 0.12337660789489746
# AVERAGE VAL LOSS: 0.24683988094329834
# #################
# # EPOCH 274
# #################
# AVERAGE TRAIN LOSS: 0.11852683871984482
# AVERAGE VAL LOSS: 0.2425869107246399
# #################
# # EPOCH 275
# #################
# AVERAGE TRAIN LOSS: 0.1186891570687294
# AVERAGE VAL LOSS: 0.24564430117607117
# #################
# # EPOCH 276
# #################
# AVERAGE TRAIN LOSS: 0.11960134655237198
# AVERAGE VAL LOSS: 0.24184265732765198
# #################
# # EPOCH 277
# #################
# AVERAGE TRAIN LOSS: 0.12275818735361099
# AVERAGE VAL LOSS: 0.2531217336654663
# #################
# # EPOCH 278
# #################
# AVERAGE TRAIN LOSS: 0.1260717213153839
# AVERAGE VAL LOSS: 0.25566622614860535
# #################
# # EPOCH 279
# #################
# AVERAGE TRAIN LOSS: 0.1318681687116623
# AVERAGE VAL LOSS: 0.27740854024887085
# #################
# # EPOCH 280
# #################
# AVERAGE TRAIN LOSS: 0.1361134648323059
# AVERAGE VAL LOSS: 0.27650612592697144
# #################
# # EPOCH 281
# #################
# AVERAGE TRAIN LOSS: 0.1412157416343689
# AVERAGE VAL LOSS: 0.2964208126068115
# #################
# # EPOCH 282
# #################
# AVERAGE TRAIN LOSS: 0.14365075528621674
# AVERAGE VAL LOSS: 0.27295470237731934
# #################
# # EPOCH 283
# #################
# AVERAGE TRAIN LOSS: 0.14108715951442719
# AVERAGE VAL LOSS: 0.28138768672943115
# #################
# # EPOCH 284
# #################
# AVERAGE TRAIN LOSS: 0.13269028067588806
# AVERAGE VAL LOSS: 0.24976558983325958
# #################
# # EPOCH 285
# #################
# AVERAGE TRAIN LOSS: 0.12318415939807892
# AVERAGE VAL LOSS: 0.2568594813346863
# #################
# # EPOCH 286
# #################
# AVERAGE TRAIN LOSS: 0.11719991266727448
# AVERAGE VAL LOSS: 0.23767879605293274
# #################
# # EPOCH 287
# #################
# AVERAGE TRAIN LOSS: 0.11310499906539917
# AVERAGE VAL LOSS: 0.24403029680252075
# #################
# # EPOCH 288
# #################
# AVERAGE TRAIN LOSS: 0.11502397060394287
# AVERAGE VAL LOSS: 0.2396538406610489
# #################
# # EPOCH 289
# #################
# AVERAGE TRAIN LOSS: 0.11653067916631699
# AVERAGE VAL LOSS: 0.24951091408729553
# #################
# # EPOCH 290
# #################
# AVERAGE TRAIN LOSS: 0.11996839195489883
# AVERAGE VAL LOSS: 0.25895920395851135
# #################
# # EPOCH 291
# #################
# AVERAGE TRAIN LOSS: 0.1255289912223816
# AVERAGE VAL LOSS: 0.27096301317214966
# #################
# # EPOCH 292
# #################
# AVERAGE TRAIN LOSS: 0.12952280044555664
# AVERAGE VAL LOSS: 0.27881208062171936
# #################
# # EPOCH 293
# #################
# AVERAGE TRAIN LOSS: 0.13280324637889862
# AVERAGE VAL LOSS: 0.27729031443595886
# #################
# # EPOCH 294
# #################
# AVERAGE TRAIN LOSS: 0.133457213640213
# AVERAGE VAL LOSS: 0.2679934799671173
# #################
# # EPOCH 295
# #################
# AVERAGE TRAIN LOSS: 0.12854135036468506
# AVERAGE VAL LOSS: 0.24990886449813843
# #################
# # EPOCH 296
# #################
# AVERAGE TRAIN LOSS: 0.12023527920246124
# AVERAGE VAL LOSS: 0.24038071930408478
# #################
# # EPOCH 297
# #################
# AVERAGE TRAIN LOSS: 0.1135464683175087
# AVERAGE VAL LOSS: 0.23476119339466095
# #################
# # EPOCH 298
# #################
# AVERAGE TRAIN LOSS: 0.10945411771535873
# AVERAGE VAL LOSS: 0.23400993645191193
# #################
# # EPOCH 299
# #################
# AVERAGE TRAIN LOSS: 0.10854289680719376
# AVERAGE VAL LOSS: 0.23341049253940582
# #################
# # EPOCH 300
# #################
# AVERAGE TRAIN LOSS: 0.10977499186992645
# AVERAGE VAL LOSS: 0.239109605550766
# #################
# # EPOCH 301
# #################
# AVERAGE TRAIN LOSS: 0.11310408264398575
# AVERAGE VAL LOSS: 0.24570690095424652
# #################
# # EPOCH 302
# #################
# AVERAGE TRAIN LOSS: 0.11717814207077026
# AVERAGE VAL LOSS: 0.25959739089012146
# #################
# # EPOCH 303
# #################
# AVERAGE TRAIN LOSS: 0.12217654287815094
# AVERAGE VAL LOSS: 0.26785561442375183
# #################
# # EPOCH 304
# #################
# AVERAGE TRAIN LOSS: 0.12656433880329132
# AVERAGE VAL LOSS: 0.27900534868240356
# #################
# # EPOCH 305
# #################
# AVERAGE TRAIN LOSS: 0.13049422204494476
# AVERAGE VAL LOSS: 0.2712981104850769
# #################
# # EPOCH 306
# #################
# AVERAGE TRAIN LOSS: 0.12952004373073578
# AVERAGE VAL LOSS: 0.26619231700897217
# #################
# # EPOCH 307
# #################
# AVERAGE TRAIN LOSS: 0.12638013064861298
# AVERAGE VAL LOSS: 0.2436009794473648
# #################
# # EPOCH 308
# #################
# AVERAGE TRAIN LOSS: 0.1191045492887497
# AVERAGE VAL LOSS: 0.241961270570755
# #################
# # EPOCH 309
# #################
# AVERAGE TRAIN LOSS: 0.11259648948907852
# AVERAGE VAL LOSS: 0.2350677102804184
# #################
# # EPOCH 310
# #################
# AVERAGE TRAIN LOSS: 0.11225404590368271
# AVERAGE VAL LOSS: 0.23872750997543335
# #################
# # EPOCH 311
# #################
# AVERAGE TRAIN LOSS: 0.10944227129220963
# AVERAGE VAL LOSS: 0.22994151711463928
# #################
# # EPOCH 312
# #################
# AVERAGE TRAIN LOSS: 0.11099765449762344
# AVERAGE VAL LOSS: 0.23946627974510193
# #################
# # EPOCH 313
# #################
# AVERAGE TRAIN LOSS: 0.1122683510184288
# AVERAGE VAL LOSS: 0.2374400496482849
# #################
# # EPOCH 314
# #################
# AVERAGE TRAIN LOSS: 0.11772499233484268
# AVERAGE VAL LOSS: 0.2667468786239624
# #################
# # EPOCH 315
# #################
# AVERAGE TRAIN LOSS: 0.12317290157079697
# AVERAGE VAL LOSS: 0.27119699120521545
# #################
# # EPOCH 316
# #################
# AVERAGE TRAIN LOSS: 0.1302870661020279
# AVERAGE VAL LOSS: 0.3046726584434509
# #################
# # EPOCH 317
# #################
# AVERAGE TRAIN LOSS: 0.1362452208995819
# AVERAGE VAL LOSS: 0.28264427185058594
# #################
# # EPOCH 318
# #################
# AVERAGE TRAIN LOSS: 0.13486194610595703
# AVERAGE VAL LOSS: 0.2829512357711792
# #################
# # EPOCH 319
# #################
# AVERAGE TRAIN LOSS: 0.1277352273464203
# AVERAGE VAL LOSS: 0.24032114446163177
# #################
# # EPOCH 320
# #################
# AVERAGE TRAIN LOSS: 0.11394238471984863
# AVERAGE VAL LOSS: 0.2342907339334488
# #################
# # EPOCH 321
# #################
# AVERAGE TRAIN LOSS: 0.1044694036245346
# AVERAGE VAL LOSS: 0.2243221402168274
# #################
# # EPOCH 322
# #################
# AVERAGE TRAIN LOSS: 0.10016022622585297
# AVERAGE VAL LOSS: 0.22555029392242432
# #################
# # EPOCH 323
# #################
# AVERAGE TRAIN LOSS: 0.10186264663934708
# AVERAGE VAL LOSS: 0.22838225960731506
# #################
# # EPOCH 324
# #################
# AVERAGE TRAIN LOSS: 0.10333316028118134
# AVERAGE VAL LOSS: 0.23167304694652557
# #################
# # EPOCH 325
# #################
# AVERAGE TRAIN LOSS: 0.10746057331562042
# AVERAGE VAL LOSS: 0.2524881958961487
# #################
# # EPOCH 326
# #################
# AVERAGE TRAIN LOSS: 0.11609306186437607
# AVERAGE VAL LOSS: 0.2657243013381958
# #################
# # EPOCH 327
# #################
# AVERAGE TRAIN LOSS: 0.1216893196105957
# AVERAGE VAL LOSS: 0.2776108384132385
# #################
# # EPOCH 328
# #################
# AVERAGE TRAIN LOSS: 0.1248297467827797
# AVERAGE VAL LOSS: 0.2637728750705719
# #################
# # EPOCH 329
# #################
# AVERAGE TRAIN LOSS: 0.12284722179174423
# AVERAGE VAL LOSS: 0.25188693404197693
# #################
# # EPOCH 330
# #################
# AVERAGE TRAIN LOSS: 0.11503078788518906
# AVERAGE VAL LOSS: 0.2302291840314865
# #################
# # EPOCH 331
# #################
# AVERAGE TRAIN LOSS: 0.10479070991277695
# AVERAGE VAL LOSS: 0.22728365659713745
# #################
# # EPOCH 332
# #################
# AVERAGE TRAIN LOSS: 0.10016758739948273
# AVERAGE VAL LOSS: 0.2220803052186966
# #################
# # EPOCH 333
# #################
# AVERAGE TRAIN LOSS: 0.09785635769367218
# AVERAGE VAL LOSS: 0.22480632364749908
# #################
# # EPOCH 334
# #################
# AVERAGE TRAIN LOSS: 0.09891540557146072
# AVERAGE VAL LOSS: 0.22528573870658875
# #################
# # EPOCH 335
# #################
# AVERAGE TRAIN LOSS: 0.10176931321620941
# AVERAGE VAL LOSS: 0.24161896109580994
# #################
# # EPOCH 336
# #################
# AVERAGE TRAIN LOSS: 0.10810832679271698
# AVERAGE VAL LOSS: 0.2495909184217453
# #################
# # EPOCH 337
# #################
# AVERAGE TRAIN LOSS: 0.11324401199817657
# AVERAGE VAL LOSS: 0.26911038160324097
# #################
# # EPOCH 338
# #################
# AVERAGE TRAIN LOSS: 0.11891844123601913
# AVERAGE VAL LOSS: 0.263284832239151
# #################
# # EPOCH 339
# #################
# AVERAGE TRAIN LOSS: 0.12031242996454239
# AVERAGE VAL LOSS: 0.2673884630203247
# #################
# # EPOCH 340
# #################
# AVERAGE TRAIN LOSS: 0.11992505937814713
# AVERAGE VAL LOSS: 0.23929443955421448
# #################
# # EPOCH 341
# #################
# AVERAGE TRAIN LOSS: 0.11208908259868622
# AVERAGE VAL LOSS: 0.2388249784708023
# #################
# # EPOCH 342
# #################
# AVERAGE TRAIN LOSS: 0.10452450811862946
# AVERAGE VAL LOSS: 0.22299396991729736
# #################
# # EPOCH 343
# #################
# AVERAGE TRAIN LOSS: 0.09983419626951218
# AVERAGE VAL LOSS: 0.23120974004268646
# #################
# # EPOCH 344
# #################
# AVERAGE TRAIN LOSS: 0.09758692234754562
# AVERAGE VAL LOSS: 0.2180730253458023
# #################
# # EPOCH 345
# #################
# AVERAGE TRAIN LOSS: 0.09665113687515259
# AVERAGE VAL LOSS: 0.23741768300533295
# #################
# # EPOCH 346
# #################
# AVERAGE TRAIN LOSS: 0.10231269896030426
# AVERAGE VAL LOSS: 0.23776763677597046
# #################
# # EPOCH 347
# #################
# AVERAGE TRAIN LOSS: 0.10773468017578125
# AVERAGE VAL LOSS: 0.266391396522522
# #################
# # EPOCH 348
# #################
# AVERAGE TRAIN LOSS: 0.11331762373447418
# AVERAGE VAL LOSS: 0.26473313570022583
# #################
# # EPOCH 349
# #################
# AVERAGE TRAIN LOSS: 0.11755003035068512
# AVERAGE VAL LOSS: 0.2751207649707794
# #################
# # EPOCH 350
# #################
# AVERAGE TRAIN LOSS: 0.11919642984867096
# AVERAGE VAL LOSS: 0.25094106793403625
# #################
# # EPOCH 351
# #################
# AVERAGE TRAIN LOSS: 0.11248765885829926
# AVERAGE VAL LOSS: 0.2351260781288147
# #################
# # EPOCH 352
# #################
# AVERAGE TRAIN LOSS: 0.10372277349233627
# AVERAGE VAL LOSS: 0.21990346908569336
# #################
# # EPOCH 353
# #################
# AVERAGE TRAIN LOSS: 0.09599676728248596
# AVERAGE VAL LOSS: 0.2173832654953003
# #################
# # EPOCH 354
# #################
# AVERAGE TRAIN LOSS: 0.09232806414365768
# AVERAGE VAL LOSS: 0.2156616747379303
# #################
# # EPOCH 355
# #################
# AVERAGE TRAIN LOSS: 0.0913330465555191
# AVERAGE VAL LOSS: 0.21796326339244843
# #################
# # EPOCH 356
# #################
# AVERAGE TRAIN LOSS: 0.09361673146486282
# AVERAGE VAL LOSS: 0.22816631197929382
# #################
# # EPOCH 357
# #################
# AVERAGE TRAIN LOSS: 0.09858674556016922
# AVERAGE VAL LOSS: 0.24083667993545532
# #################
# # EPOCH 358
# #################
# AVERAGE TRAIN LOSS: 0.10391394048929214
# AVERAGE VAL LOSS: 0.2551954388618469
# #################
# # EPOCH 359
# #################
# AVERAGE TRAIN LOSS: 0.10912443697452545
# AVERAGE VAL LOSS: 0.259056031703949
# #################
# # EPOCH 360
# #################
# AVERAGE TRAIN LOSS: 0.11162598431110382
# AVERAGE VAL LOSS: 0.25534749031066895
# #################
# # EPOCH 361
# #################
# AVERAGE TRAIN LOSS: 0.11033830791711807
# AVERAGE VAL LOSS: 0.23844826221466064
# #################
# # EPOCH 362
# #################
# AVERAGE TRAIN LOSS: 0.10403726994991302
# AVERAGE VAL LOSS: 0.22606973350048065
# #################
# # EPOCH 363
# #################
# AVERAGE TRAIN LOSS: 0.09741750359535217
# AVERAGE VAL LOSS: 0.21646641194820404
# #################
# # EPOCH 364
# #################
# AVERAGE TRAIN LOSS: 0.09192691743373871
# AVERAGE VAL LOSS: 0.21573227643966675
# #################
# # EPOCH 365
# #################
# AVERAGE TRAIN LOSS: 0.089970164000988
# AVERAGE VAL LOSS: 0.21470433473587036
# #################
# # EPOCH 366
# #################
# AVERAGE TRAIN LOSS: 0.09004402160644531
# AVERAGE VAL LOSS: 0.22231021523475647
# #################
# # EPOCH 367
# #################
# AVERAGE TRAIN LOSS: 0.09329313039779663
# AVERAGE VAL LOSS: 0.22801168262958527
# #################
# # EPOCH 368
# #################
# AVERAGE TRAIN LOSS: 0.096913643181324
# AVERAGE VAL LOSS: 0.24489879608154297
# #################
# # EPOCH 369
# #################
# AVERAGE TRAIN LOSS: 0.10297119617462158
# AVERAGE VAL LOSS: 0.24855566024780273
# #################
# # EPOCH 370
# #################
# AVERAGE TRAIN LOSS: 0.10646401345729828
# AVERAGE VAL LOSS: 0.26237791776657104
# #################
# # EPOCH 371
# #################
# AVERAGE TRAIN LOSS: 0.11154045164585114
# AVERAGE VAL LOSS: 0.2435464859008789
# #################
# # EPOCH 372
# #################
# AVERAGE TRAIN LOSS: 0.11028184741735458
# AVERAGE VAL LOSS: 0.24664539098739624
# #################
# # EPOCH 373
# #################
# AVERAGE TRAIN LOSS: 0.10911782085895538
# AVERAGE VAL LOSS: 0.22347615659236908
# #################
# # EPOCH 374
# #################
# AVERAGE TRAIN LOSS: 0.10717567056417465
# AVERAGE VAL LOSS: 0.2278665155172348
# #################
# # EPOCH 375
# #################
# AVERAGE TRAIN LOSS: 0.09930237382650375
# AVERAGE VAL LOSS: 0.22128164768218994
# #################
# # EPOCH 376
# #################
# AVERAGE TRAIN LOSS: 0.09608152508735657
# AVERAGE VAL LOSS: 0.2362060397863388
# #################
# # EPOCH 377
# #################
# AVERAGE TRAIN LOSS: 0.09315617382526398
# AVERAGE VAL LOSS: 0.21552424132823944
# #################
# # EPOCH 378
# #################
# AVERAGE TRAIN LOSS: 0.09356600046157837
# AVERAGE VAL LOSS: 0.24269314110279083
# #################
# # EPOCH 379
# #################
# AVERAGE TRAIN LOSS: 0.09767657518386841
# AVERAGE VAL LOSS: 0.24896042048931122
# #################
# # EPOCH 380
# #################
# AVERAGE TRAIN LOSS: 0.10799998044967651
# AVERAGE VAL LOSS: 0.2953561544418335
# #################
# # EPOCH 381
# #################
# AVERAGE TRAIN LOSS: 0.11864330619573593
# AVERAGE VAL LOSS: 0.2861892580986023
# #################
# # EPOCH 382
# #################
# AVERAGE TRAIN LOSS: 0.12271801382303238
# AVERAGE VAL LOSS: 0.27230843901634216
# #################
# # EPOCH 383
# #################
# AVERAGE TRAIN LOSS: 0.11660164594650269
# AVERAGE VAL LOSS: 0.22673994302749634
# #################
# # EPOCH 384
# #################
# AVERAGE TRAIN LOSS: 0.10398770868778229
# ...
# AVERAGE VAL LOSS: 0.30181488394737244
# #################
# # EPOCH 473
# #################
# AVERAGE TRAIN LOSS: 0.11592385917901993
# AVERAGE VAL LOSS: 0.23191942274570465
# #################
# # EPOCH 474
# #################
# AVERAGE TRAIN LOSS: 0.09623674303293228
# AVERAGE VAL LOSS: 0.20717105269432068
# #################
# # EPOCH 475
# #################
# AVERAGE TRAIN LOSS: 0.0749661773443222
# AVERAGE VAL LOSS: 0.24111643433570862
# #################
# # EPOCH 476
# #################
# AVERAGE TRAIN LOSS: 0.07690098881721497
# AVERAGE VAL LOSS: 0.21590381860733032
# #################
# # EPOCH 477
# #################
# AVERAGE TRAIN LOSS: 0.07291102409362793
# AVERAGE VAL LOSS: 0.22018863260746002
# #################
# # EPOCH 478
# #################
# AVERAGE TRAIN LOSS: 0.07747818529605865
# AVERAGE VAL LOSS: 0.2559894323348999
# #################
# # EPOCH 479
# #################
# AVERAGE TRAIN LOSS: 0.09778883308172226
# AVERAGE VAL LOSS: 0.2384951263666153
# #################
# # EPOCH 480
# #################
# AVERAGE TRAIN LOSS: 0.09592212736606598
# AVERAGE VAL LOSS: 0.20686781406402588
# #################
# # EPOCH 481
# #################
# AVERAGE TRAIN LOSS: 0.07453456521034241
# AVERAGE VAL LOSS: 0.2112407237291336
# #################
# # EPOCH 482
# #################
# AVERAGE TRAIN LOSS: 0.06690577417612076
# AVERAGE VAL LOSS: 0.20701327919960022
# #################
# # EPOCH 483
# #################
# AVERAGE TRAIN LOSS: 0.0669371634721756
# AVERAGE VAL LOSS: 0.21836844086647034
# #################
# # EPOCH 484
# #################
# AVERAGE TRAIN LOSS: 0.0732889324426651
# AVERAGE VAL LOSS: 0.24527953565120697
# #################
# # EPOCH 485
# #################
# AVERAGE TRAIN LOSS: 0.0850948914885521
# AVERAGE VAL LOSS: 0.2376367598772049
# #################
# # EPOCH 486
# #################
# AVERAGE TRAIN LOSS: 0.08863431215286255
# AVERAGE VAL LOSS: 0.20288485288619995
# #################
# # EPOCH 487
# #################
# AVERAGE TRAIN LOSS: 0.07513238489627838
# AVERAGE VAL LOSS: 0.20174537599086761
# #################
# # EPOCH 488
# #################
# AVERAGE TRAIN LOSS: 0.06353887915611267
# AVERAGE VAL LOSS: 0.2021007537841797
# #################
# # EPOCH 489
# #################
# AVERAGE TRAIN LOSS: 0.06314636021852493
# AVERAGE VAL LOSS: 0.21002574265003204
# #################
# # EPOCH 490
# #################
# AVERAGE TRAIN LOSS: 0.068486288189888
# AVERAGE VAL LOSS: 0.2365414798259735
# #################
# # EPOCH 491
# #################
# AVERAGE TRAIN LOSS: 0.07763920724391937
# AVERAGE VAL LOSS: 0.24155168235301971
# #################
# # EPOCH 492
# #################
# AVERAGE TRAIN LOSS: 0.08545220643281937
# AVERAGE VAL LOSS: 0.21467189490795135
# #################
# # EPOCH 493
# #################
# AVERAGE TRAIN LOSS: 0.07926750183105469
# AVERAGE VAL LOSS: 0.19929595291614532
# #################
# # EPOCH 494
# #################
# AVERAGE TRAIN LOSS: 0.06544535607099533
# AVERAGE VAL LOSS: 0.1996740698814392
# #################
# # EPOCH 495
# #################
# AVERAGE TRAIN LOSS: 0.06057438999414444
# AVERAGE VAL LOSS: 0.2018592208623886
# #################
# # EPOCH 496
# #################
# AVERAGE TRAIN LOSS: 0.06280612200498581
# AVERAGE VAL LOSS: 0.2187194973230362
# #################
# # EPOCH 497
# #################
# AVERAGE TRAIN LOSS: 0.06900133192539215
# AVERAGE VAL LOSS: 0.2368186116218567
# #################
# # EPOCH 498
# #################
# AVERAGE TRAIN LOSS: 0.07803203910589218
# AVERAGE VAL LOSS: 0.23093654215335846
# #################
# # EPOCH 499
# #################
# AVERAGE TRAIN LOSS: 0.08091381937265396
# AVERAGE VAL LOSS: 0.20954205095767975
# #################
# # EPOCH 500
# #################
# AVERAGE TRAIN LOSS: 0.0717785581946373
# AVERAGE VAL LOSS: 0.19768476486206055
# #################
# # EPOCH 501
# #################
# AVERAGE TRAIN LOSS: 0.06243515759706497
# AVERAGE VAL LOSS: 0.1984882354736328
# #################
# # EPOCH 502
# #################
# AVERAGE TRAIN LOSS: 0.059762440621852875
# AVERAGE VAL LOSS: 0.20289821922779083
# #################
# # EPOCH 503
# #################
# AVERAGE TRAIN LOSS: 0.06136268377304077
# AVERAGE VAL LOSS: 0.21656161546707153
# #################
# # EPOCH 504
# #################
# AVERAGE TRAIN LOSS: 0.06702865660190582
# AVERAGE VAL LOSS: 0.22956104576587677
# #################
# # EPOCH 505
# #################
# AVERAGE TRAIN LOSS: 0.07427370548248291
# AVERAGE VAL LOSS: 0.22802917659282684
# #################
# # EPOCH 506
# #################
# AVERAGE TRAIN LOSS: 0.07555019110441208
# AVERAGE VAL LOSS: 0.21234333515167236
# #################
# # EPOCH 507
# #################
# AVERAGE TRAIN LOSS: 0.06985335052013397
# AVERAGE VAL LOSS: 0.20095573365688324
# #################
# # EPOCH 508
# #################
# AVERAGE TRAIN LOSS: 0.06368514150381088
# AVERAGE VAL LOSS: 0.19885432720184326
# #################
# # EPOCH 509
# #################
# AVERAGE TRAIN LOSS: 0.05989687517285347
# AVERAGE VAL LOSS: 0.20117148756980896
# #################
# # EPOCH 510
# #################
# AVERAGE TRAIN LOSS: 0.05959635227918625
# AVERAGE VAL LOSS: 0.20833750069141388
# #################
# # EPOCH 511
# #################
# AVERAGE TRAIN LOSS: 0.06299873441457748
# AVERAGE VAL LOSS: 0.21971970796585083
# #################
# # EPOCH 512
# #################
# AVERAGE TRAIN LOSS: 0.06792044639587402
# AVERAGE VAL LOSS: 0.2252206802368164
# #################
# # EPOCH 513
# #################
# AVERAGE TRAIN LOSS: 0.07084263861179352
# AVERAGE VAL LOSS: 0.22075437009334564
# #################
# # EPOCH 514
# #################
# AVERAGE TRAIN LOSS: 0.07034149020910263
# AVERAGE VAL LOSS: 0.2113097608089447
# #################
# # EPOCH 515
# #################
# AVERAGE TRAIN LOSS: 0.06685393303632736
# AVERAGE VAL LOSS: 0.20446819067001343
# #################
# # EPOCH 516
# #################
# AVERAGE TRAIN LOSS: 0.06295039504766464
# AVERAGE VAL LOSS: 0.20160049200057983
# #################
# # EPOCH 517
# #################
# AVERAGE TRAIN LOSS: 0.06054650619626045
# AVERAGE VAL LOSS: 0.20304670929908752
# #################
# # EPOCH 518
# #################
# AVERAGE TRAIN LOSS: 0.06010344624519348
# AVERAGE VAL LOSS: 0.20743826031684875
# #################
# # EPOCH 519
# #################
# AVERAGE TRAIN LOSS: 0.061601340770721436
# AVERAGE VAL LOSS: 0.21442176401615143
# #################
# # EPOCH 520
# #################
# AVERAGE TRAIN LOSS: 0.06451503932476044
# AVERAGE VAL LOSS: 0.2199736386537552
# #################
# # EPOCH 521
# #################
# AVERAGE TRAIN LOSS: 0.06690968573093414
# AVERAGE VAL LOSS: 0.2211037576198578
# #################
# # EPOCH 522
# #################
# AVERAGE TRAIN LOSS: 0.06767357885837555
# AVERAGE VAL LOSS: 0.21697154641151428
# #################
# # EPOCH 523
# #################
# AVERAGE TRAIN LOSS: 0.06675946712493896
# AVERAGE VAL LOSS: 0.21174734830856323
# #################
# # EPOCH 524
# #################
# AVERAGE TRAIN LOSS: 0.06474338471889496
# AVERAGE VAL LOSS: 0.2070406675338745
# #################
# # EPOCH 525
# #################
# AVERAGE TRAIN LOSS: 0.06235383078455925
# AVERAGE VAL LOSS: 0.20497764647006989
# #################
# # EPOCH 526
# #################
# AVERAGE TRAIN LOSS: 0.06072332710027695
# AVERAGE VAL LOSS: 0.20529478788375854
# #################
# # EPOCH 527
# #################
# AVERAGE TRAIN LOSS: 0.0601634606719017
# AVERAGE VAL LOSS: 0.20849773287773132
# #################
# # EPOCH 528
# #################
# AVERAGE TRAIN LOSS: 0.0609186515212059
# AVERAGE VAL LOSS: 0.21281291544437408
# #################
# # EPOCH 529
# #################
# AVERAGE TRAIN LOSS: 0.06252620369195938
# AVERAGE VAL LOSS: 0.21753112971782684
# #################
# # EPOCH 530
# #################
# AVERAGE TRAIN LOSS: 0.06425566971302032
# AVERAGE VAL LOSS: 0.21931825578212738
# #################
# # EPOCH 531
# #################
# AVERAGE TRAIN LOSS: 0.06513160467147827
# AVERAGE VAL LOSS: 0.21874667704105377
# #################
# # EPOCH 532
# #################
# AVERAGE TRAIN LOSS: 0.06521724164485931
# AVERAGE VAL LOSS: 0.21527738869190216
# #################
# # EPOCH 533
# #################
# AVERAGE TRAIN LOSS: 0.06421297043561935
# AVERAGE VAL LOSS: 0.21193325519561768
# #################
# # EPOCH 534
# #################
# AVERAGE TRAIN LOSS: 0.06273429840803146
# AVERAGE VAL LOSS: 0.20829880237579346
# #################
# # EPOCH 535
# #################
# AVERAGE TRAIN LOSS: 0.061065834015607834
# AVERAGE VAL LOSS: 0.20744779706001282
# #################
# # EPOCH 536
# #################
# AVERAGE TRAIN LOSS: 0.06005194038152695
# AVERAGE VAL LOSS: 0.20739951729774475
# #################
# # EPOCH 537
# #################
# AVERAGE TRAIN LOSS: 0.059545546770095825
# AVERAGE VAL LOSS: 0.21047376096248627
# #################
# # EPOCH 538
# #################
# AVERAGE TRAIN LOSS: 0.060211412608623505
# AVERAGE VAL LOSS: 0.21304963529109955
# #################
# # EPOCH 539
# #################
# AVERAGE TRAIN LOSS: 0.06108902767300606
# AVERAGE VAL LOSS: 0.21755863726139069
# #################
# # EPOCH 540
# #################
# AVERAGE TRAIN LOSS: 0.0624748058617115
# AVERAGE VAL LOSS: 0.21815833449363708
# #################
# # EPOCH 541
# #################
# AVERAGE TRAIN LOSS: 0.06300549954175949
# AVERAGE VAL LOSS: 0.21998780965805054
# #################
# # EPOCH 542
# #################
# AVERAGE TRAIN LOSS: 0.06369630992412567
# AVERAGE VAL LOSS: 0.21610920131206512
# #################
# # EPOCH 543
# #################
# AVERAGE TRAIN LOSS: 0.06272580474615097
# AVERAGE VAL LOSS: 0.21637707948684692
# #################
# # EPOCH 544
# #################
# AVERAGE TRAIN LOSS: 0.0630205050110817
# AVERAGE VAL LOSS: 0.20963925123214722
# #################
# # EPOCH 545
# #################
# AVERAGE TRAIN LOSS: 0.06152286380529404
# AVERAGE VAL LOSS: 0.21539348363876343
# #################
# # EPOCH 546
# #################
# AVERAGE TRAIN LOSS: 0.06484810262918472
# AVERAGE VAL LOSS: 0.2121054232120514
# #################
# # EPOCH 547
# #################
# AVERAGE TRAIN LOSS: 0.06882030516862869
# AVERAGE VAL LOSS: 0.20477323234081268
# #################
# # EPOCH 548
# #################
# AVERAGE TRAIN LOSS: 0.07297748327255249
# AVERAGE VAL LOSS: 0.21513208746910095
# #################
# # EPOCH 549
# #################
# AVERAGE TRAIN LOSS: 0.08216206729412079
# AVERAGE VAL LOSS: 0.23541519045829773
# #################
# # EPOCH 550
# #################
# AVERAGE TRAIN LOSS: 0.09736524522304535
# AVERAGE VAL LOSS: 0.25441983342170715
# #################
# # EPOCH 551
# #################
# AVERAGE TRAIN LOSS: 0.08634930849075317
# AVERAGE VAL LOSS: 0.2473761886358261
# #################
# # EPOCH 552
# #################
# AVERAGE TRAIN LOSS: 0.07482290267944336
# AVERAGE VAL LOSS: 0.23070232570171356
# #################
# # EPOCH 553
# #################
# AVERAGE TRAIN LOSS: 0.07339998334646225
# AVERAGE VAL LOSS: 0.2899952828884125
# #################
# # EPOCH 554
# #################
# AVERAGE TRAIN LOSS: 0.08171696960926056
# AVERAGE VAL LOSS: 0.3334612250328064
# #################
# # EPOCH 555
# #################
# AVERAGE TRAIN LOSS: 0.10529018938541412
# AVERAGE VAL LOSS: 0.36359864473342896
# #################
# # EPOCH 556
# #################
# AVERAGE TRAIN LOSS: 0.11695142090320587
# AVERAGE VAL LOSS: 0.3062046766281128
# #################
# # EPOCH 557
# #################
# AVERAGE TRAIN LOSS: 0.11374814808368683
# AVERAGE VAL LOSS: 0.2522146701812744
# #################
# # EPOCH 558
# #################
# AVERAGE TRAIN LOSS: 0.09129070490598679
# AVERAGE VAL LOSS: 0.2430334985256195
# #################
# # EPOCH 559
# #################
# AVERAGE TRAIN LOSS: 0.09141826629638672
# AVERAGE VAL LOSS: 0.26019519567489624
# #################
# # EPOCH 560
# #################
# AVERAGE TRAIN LOSS: 0.08286833763122559
# AVERAGE VAL LOSS: 0.2505621016025543
# #################
# # EPOCH 561
# #################
# AVERAGE TRAIN LOSS: 0.07209409773349762
# AVERAGE VAL LOSS: 0.2059442698955536
# #################
# # EPOCH 562
# #################
# AVERAGE TRAIN LOSS: 0.07221094518899918
# AVERAGE VAL LOSS: 0.30295875668525696
# #################
# # EPOCH 563
# #################
# AVERAGE TRAIN LOSS: 0.0946824699640274
# AVERAGE VAL LOSS: 0.3156794607639313
# #################
# # EPOCH 564
# #################
# AVERAGE TRAIN LOSS: 0.10547014325857162
# AVERAGE VAL LOSS: 0.22627925872802734
# #################
# # EPOCH 565
# #################
# AVERAGE TRAIN LOSS: 0.09689667075872421
# AVERAGE VAL LOSS: 0.23765477538108826
# #################
# # EPOCH 566
# #################
# AVERAGE TRAIN LOSS: 0.06693097949028015
# AVERAGE VAL LOSS: 0.23880785703659058
# #################
# # EPOCH 567
# #################
# AVERAGE TRAIN LOSS: 0.06490238755941391
# AVERAGE VAL LOSS: 0.22805412113666534
# #################
# # EPOCH 568
# #################
# AVERAGE TRAIN LOSS: 0.07045548409223557
# AVERAGE VAL LOSS: 0.27016887068748474
# #################
# # EPOCH 569
# #################
# AVERAGE TRAIN LOSS: 0.07991302013397217
# AVERAGE VAL LOSS: 0.22362826764583588
# #################
# # EPOCH 570
# #################
# AVERAGE TRAIN LOSS: 0.08841250836849213
# AVERAGE VAL LOSS: 0.20891384780406952
# #################
# # EPOCH 571
# #################
# AVERAGE TRAIN LOSS: 0.06377170234918594
# AVERAGE VAL LOSS: 0.21745693683624268
# #################
# # EPOCH 572
# #################
# AVERAGE TRAIN LOSS: 0.05533009022474289
# AVERAGE VAL LOSS: 0.21514879167079926
# #################
# # EPOCH 573
# #################
# AVERAGE TRAIN LOSS: 0.0617067813873291
# AVERAGE VAL LOSS: 0.25219225883483887
# #################
# # EPOCH 574
# #################
# AVERAGE TRAIN LOSS: 0.07198093831539154
# AVERAGE VAL LOSS: 0.22772899270057678
# #################
# # EPOCH 575
# #################
# AVERAGE TRAIN LOSS: 0.07533258944749832
# AVERAGE VAL LOSS: 0.20214293897151947
# #################
# # EPOCH 576
# #################
# AVERAGE TRAIN LOSS: 0.06273312121629715
# AVERAGE VAL LOSS: 0.21085771918296814
# #################
# # EPOCH 577
# #################
# AVERAGE TRAIN LOSS: 0.05311506241559982
# AVERAGE VAL LOSS: 0.21144616603851318
# #################
# # EPOCH 578
# #################
# AVERAGE TRAIN LOSS: 0.056368034332990646
# AVERAGE VAL LOSS: 0.24136365950107574
# #################
# # EPOCH 579
# #################
# AVERAGE TRAIN LOSS: 0.06650057435035706
# AVERAGE VAL LOSS: 0.23977427184581757
# #################
# # EPOCH 580
# #################
# AVERAGE TRAIN LOSS: 0.0735057145357132
# AVERAGE VAL LOSS: 0.2040075659751892
# #################
# # EPOCH 581
# #################
# AVERAGE TRAIN LOSS: 0.06294501572847366
# AVERAGE VAL LOSS: 0.207962304353714
# #################
# # EPOCH 582
# #################
# AVERAGE TRAIN LOSS: 0.051550447940826416
# AVERAGE VAL LOSS: 0.20638607442378998
# #################
# # EPOCH 583
# #################
# AVERAGE TRAIN LOSS: 0.052608758211135864
# AVERAGE VAL LOSS: 0.2286313772201538
# #################
# # EPOCH 584
# #################
# AVERAGE TRAIN LOSS: 0.06040630862116814
# AVERAGE VAL LOSS: 0.24685387313365936
# #################
# # EPOCH 585
# #################
# AVERAGE TRAIN LOSS: 0.07052130997180939
# AVERAGE VAL LOSS: 0.21675850450992584
# #################
# # EPOCH 586
# #################
# AVERAGE TRAIN LOSS: 0.06740102916955948
# AVERAGE VAL LOSS: 0.20594269037246704
# #################
# # EPOCH 587
# #################
# AVERAGE TRAIN LOSS: 0.05342558026313782
# AVERAGE VAL LOSS: 0.20826318860054016
# #################
# # EPOCH 588
# #################
# AVERAGE TRAIN LOSS: 0.04969611018896103
# AVERAGE VAL LOSS: 0.21404843032360077
# #################
# # EPOCH 589
# #################
# AVERAGE TRAIN LOSS: 0.05425499752163887
# AVERAGE VAL LOSS: 0.2439325749874115
# #################
# # EPOCH 590
# #################
# AVERAGE TRAIN LOSS: 0.06528040021657944
# AVERAGE VAL LOSS: 0.23777620494365692
# #################
# # EPOCH 591
# #################
# AVERAGE TRAIN LOSS: 0.07078089565038681
# AVERAGE VAL LOSS: 0.20686253905296326
# #################
# # EPOCH 592
# #################
# AVERAGE TRAIN LOSS: 0.06077020242810249
# AVERAGE VAL LOSS: 0.20939494669437408
# #################
# # EPOCH 593
# #################
# AVERAGE TRAIN LOSS: 0.049413569271564484
# AVERAGE VAL LOSS: 0.20731021463871002
# #################
# # EPOCH 594
# #################
# AVERAGE TRAIN LOSS: 0.04972703754901886
# AVERAGE VAL LOSS: 0.2268187403678894
# #################
# # EPOCH 595
# #################
# AVERAGE TRAIN LOSS: 0.05769895389676094
# AVERAGE VAL LOSS: 0.25141119956970215
# #################
# # EPOCH 596
# #################
# AVERAGE TRAIN LOSS: 0.06868260353803635
# AVERAGE VAL LOSS: 0.22386926412582397
# #################
# # EPOCH 597
# #################
# AVERAGE TRAIN LOSS: 0.068779356777668
# AVERAGE VAL LOSS: 0.2077249139547348
# #################
# # EPOCH 598
# #################
# AVERAGE TRAIN LOSS: 0.05525603145360947
# AVERAGE VAL LOSS: 0.21096885204315186
# #################
# # EPOCH 599
# #################
# AVERAGE TRAIN LOSS: 0.048058390617370605
# AVERAGE VAL LOSS: 0.2103426307439804

# %%
# Plot losses
plt.figure(figsize=(12,8))
plt.semilogy(train_loss_log, label='Train loss')
plt.semilogy(val_loss_log, label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Final test

# %% [markdown]
# Iterate the dataloader a single time and save all the outputs (in case you have multiple batches)

# %%
all_inputs = []
all_outputs = []
all_labels = []
net.eval() # Evaluation mode (e.g. disable dropout)
with torch.no_grad(): # Disable gradient tracking
    for sample_batched in test_dataloader:
        # Move data to device
        x_batch = sample_batched[0].to(device)
        label_batch = sample_batched[1].to(device)
        # Forward pass
        out = net(x_batch)
        # Save outputs and labels
        all_inputs.append(x_batch)
        all_outputs.append(out)
        all_labels.append(label_batch)
# Concatenate all the outputs and labels in a single tensor
all_inputs  = torch.cat(all_inputs)
all_outputs = torch.cat(all_outputs)
all_labels  = torch.cat(all_labels)

test_loss = loss_fn(all_outputs, all_labels)
print(f"AVERAGE TEST LOSS: {test_loss}")
# Out:
# AVERAGE TEST LOSS: 0.1917748600244522

# %% [markdown]
# In this case the network has a linear output (for a better stability of the loss function).
# To have probability estimates you can apply a sigmoid to the network output.
#
# Since we just need the most probable class and we have a single output, we can consider the sign of the linear output. Negative output means that the class 0 is the most probable (probability < 50%), otherwise class 1 (probability > 50%).
#
# Essentially this network estimates the probability of the input sample to be of class 1.
#
# > **NOTE**
# >
# > You can (and should, for practice) redefine the problem by defining a network with more than one output, each of them corresponding to a specific class (2 in this case). Since the two classes are mutually exclusive, the loss function should be a CrossEntropyLoss (softmax activation). In a multi-class scenario, a BCE loss is suitable when the classes are NOT mutually exclusive.

# %% [markdown]
# ---
#
#
# Get the most probable class inferred by the network

# %%
# Get the most probable class inferred by the network
all_output_classes = torch.zeros(all_outputs.shape).to(device)
all_output_classes[all_outputs > 0] = 1

# %% [markdown]
# Evaluate the test accuracy

# %%
tot_correct_out = (all_output_classes == all_labels).sum()
test_accuracy = 100 * tot_correct_out / len(all_labels)
print(f"TEST ACCURACY: {test_accuracy:.2f}%")
# Out:
# TEST ACCURACY: 93.75%

# %%
len(all_output_classes)
# Out:
# 400

# %% [markdown]
# Plot the results

# %%
### Plot
x1 = all_inputs.squeeze().cpu().numpy()[:, 0]
x2 = all_inputs.squeeze().cpu().numpy()[:, 1]
y_true = all_labels.squeeze().cpu().numpy()
y_pred = all_output_classes.squeeze().cpu().numpy()

fig, ax = plt.subplots(figsize=(12,8))
# Plot predictions
ax.scatter(x1, x2, c=colors[y_pred.astype(np.uint8)], s=10, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_title('Network Predictions')
# Mark wrong outputs
error_mask = y_pred != y_true
ax.scatter(x1[error_mask], x2[error_mask], color='red', s=100, marker='x', label='MISCLASSIFIED SAMPLES')
plt.legend()
fig.show()

# %% [markdown]
# # (Optional) High-level and Lightweight PyTorch wrapper: PyTorch Lightning

# %% [markdown]
# Lightning forces the following structure to your code which makes it reusable and shareable:
#
# Research code (the LightningModule).
# Engineering code (you delete, and is handled by the Trainer).
# Non-essential research code (logging, etc... this goes in Callbacks).
# Data (use PyTorch DataLoaders or organize them into a LightningDataModule).
# Once you do this, you can train on multiple-GPUs, TPUs, CPUs and even in 16-bit precision without changing your code!

# %%
! pip install pytorch-lightning

import os
import torch
from torch import nn
import torch.nn.functional as F
from torchvision import transforms
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader, random_split
import pytorch_lightning as pl
# Out:
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning) (2.6.0+cu124)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning) (4.67.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2025.3.2)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning)
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning) (24.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning) (4.13.2)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.11.15)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics>=0.7.0->pytorch-lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (3.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.10)
# Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 12.5 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 52.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 26.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 9.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.2 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.1-py3-none-any.whl (961 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 43.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics, pytorch-lightning
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed lightning-utilities-0.14.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pytorch-lightning-2.5.1.post0 torchmetrics-1.7.1

# %%
# Define a LightningModule (nn.Module subclass)
# A LightningModule defines a full system (ie: a GAN, autoencoder, BERT or a simple Image Classifier).
class LitNet(pl.LightningModule):
    def __init__(self, Ni, Nh1, Nh2, No):
        """
        Ni - Input size
        Nh1 - Neurons in the 1st hidden layer
        Nh2 - Neurons in the 2nd hidden layer
        No - Output size
        """
        super().__init__()

        print('Network initialized')
        self.net = nn.Sequential(nn.Linear(in_features=Ni, out_features=Nh1),
                       nn.Sigmoid(),
                       nn.Linear(in_features=Nh1, out_features=Nh2),
                       nn.Sigmoid(),
                       nn.Linear(in_features=Nh2, out_features=No))
        self.val_loss = []
        self.train_loss = []

    # Forward step defines how the LightningModule behaves during inference/prediction.
    def forward(self, x, additional_out=False):
        return self.net(x)

    # Training_step defines the training loop.
    def training_step(self, batch, batch_idx=None):
        # training_step defines the train loop. It is independent of forward
        x_batch = batch[0]
        label_batch = batch[1]
        out = self.net(x_batch)
        loss = F.binary_cross_entropy_with_logits(out, label_batch)
        self.train_loss.append(loss.item())
        return loss

    def validation_step(self, batch, batch_idx=None):
        # validation_step defines the validation loop. It is independent of forward
        x_batch = batch[0]
        label_batch = batch[1]
        out = self.net(x_batch)
        loss = F.binary_cross_entropy_with_logits(out, label_batch)
        self.val_loss.append(loss.item())
        self.log("val_loss", loss.item(), prog_bar=True)

    def configure_optimizers(self):
        optimizer = optim.Adam(self.net.parameters(), lr=1e-2)
        return optimizer

# %%
# TRAIN!
batch_size = 200
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
val_dataloader   = DataLoader(val_dataset,   batch_size=len(val_dataset), shuffle=False, num_workers=0)
test_dataloader  = DataLoader(test_dataset,  batch_size=len(test_dataset), shuffle=False, num_workers=0)

trainer = pl.Trainer(devices=1, max_epochs=20, val_check_interval=1)
litnet = LitNet(Ni, Nh1, Nh2, No)
trainer.fit(litnet, train_dataloader, val_dataloader)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# Network initialized
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name | Type       | Params | Mode
# --------------------------------------------
# 0 | net  | Sequential | 33.7 K | train
# --------------------------------------------
# 33.7 K    Trainable params
# 0         Non-trainable params
# 33.7 K    Total params
# 0.135     Total estimated model params size (MB)
# 6         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/pytorch_lightning/loops/fit_loop.py:310: The number of training batches (5) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=20` reached.

# %%
# Plot losses
plt.figure(figsize=(12,8))
plt.semilogy(litnet.train_loss, label='Train loss')
plt.semilogy(litnet.val_loss, label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # (Optional) Automatic Hyper-parameters Tuning: Optuna

# %% [markdown]
# Optuna is an automatic hyperparameter optimization software framework.
#
# - Lightweight, versatile, and platform agnostic architecture
# - Pythonic search spaces
# - Efficient optimization algorithms
# - Easy parallelization
# - Quick visualization
#
#
# Definitions:
#
# - Study: optimization based on an objective function
# - Trial: a single execution of the objective function
#
# The goal of a study is to find out the optimal set of hyperparameter values (e.g., classifier and svm_c) through multiple trials (e.g., n_trials=100). Optuna is a framework designed for the automation and the acceleration of the optimization studies.
#
# Optuna works with PyTorch, but also with Tensorflow, Keras and PyTorch Lightning! (and many others)

# %%
! pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.1)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 7.2 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 15.1 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.2 colorlog-6.9.0 optuna-4.3.0

# %%
# Before we used:
# Nh1 = 128
# Nh2 = 256

import optuna

def objective(trial):

    # We optimize the number of hidden units in each layer.
    output_dims = [
        trial.suggest_int("n_units_l{}".format(i), 64, 256, log=True) for i in range(2)
    ]

    model = LitNet(Ni, output_dims[0], output_dims[1], No)

    trainer = pl.Trainer(devices=1, max_epochs=20, val_check_interval=1,
                         log_every_n_steps=1)
    hyperparameters = dict(output_dims=output_dims)
    trainer.logger.log_hyperparams(hyperparameters)
    trainer.fit(model, train_dataloader, val_dataloader)
    return trainer.callback_metrics["val_loss"].item()


pruner = optuna.pruners.NopPruner()
# print(pruner) <optuna.pruners._nop.NopPruner object at 0x7f4c2466ed50>
# print(type(pruner)) <class 'optuna.pruners._nop.NopPruner'>

study = optuna.create_study(study_name="myfirstoptimizationstudy", direction="minimize", pruner=pruner)
study.optimize(objective, n_trials=3, timeout=300)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

# %% [markdown]
# # Homework
#
# Try tuning other hyper-parameters, such as the learning rate.
